# %% [markdown]
# ContentSquare Data Science Test
# ===========
# ## Goal
# The goal of the exercise is to predict the category of a webpage based on its URL string and custom variables. The solution should be able to classify pages into categories even for new websites.
#
# ## Instructions
# * You should not spend more than 5 hours working on the test. We're aware that it's not enough to fully answer the
#   problem, but that's OK. This is done on purpose and we don't expect you to finish the exercise
# * To get started using the dataset you can refer to the [getting started notebook](getting_started.ipynb)
# * You're encouraged to use comments to describe the steps you're taking and explain your code
# * If you use external libraries please make sure to list them in a `requirements.txt` file
# * Provide a `README.md` explaining what you did and specifying which code to run to reproduce your results
# * Submission should include all your scripts/notebooks as well as the `requirements.txt` and `README.md` files
#
# ## Assessment
# We will assess the exercise based on the following criteria
# * Depth and quality of the scientific approach
# * Code quality and cleanliness
# * Logic and relevance of your chosen steps
# * Clarity of the comments and README
#
# ## Expectations
# This test is part of a project that we are working on since several months. As a result, we don't expect from you to
# find a working solution. Depending on how you think you will manage your time, you can either:
# * craft an end to end solution (business analysis, training data analysis, modeling and training, results interpretation) and iterate on it
# * or choose some sections only and produce an in-depth analysis.
#
# If you go for the second option, chosen sections must at least include business analysis & training data analysis.
#
# As a result, training a machine learning model is not a requirement to succeed the test. However if you don't train a model, tell us how you would do it or what other system you would implement to solve the problem.
#
# If you have any doubts or questions, do not hesitate to send an email to your contact point at ContentSquare.

# %% [markdown]
# # Solution

# %% [markdown]
# ## Play with data

# %% [markdown]
# Import the data with pandas, see what it looks like, list ideas of features and distribution of the different targets thanks to the code in the tutorial notebook

# %%
import pandas as pd

# Load with pandas and show a few elements

website_df = pd.read_csv('/Users/victormoeneclaey/Downloads/dataset.csv')
website_df.head(10)
# Out:
#                                                  url  \
# 0  https://www.pizzahut.co.uk/order/deals/?cs-pop...
# 1  https://us.pandora.net/on/demandware.store/Sit...
# 2  https://www.oakleysi.com/en-us/my-account/edit...
# 3  https://www.gites-de-france.com/fr/search?depa...
# 4  https://www.hermes.com/us/en/product/candy-san...
# 5  https://www.ralphlauren.fr//emailorderdetails?...
# 6  https://www.travelrepublic.co.uk/holidays/hote...
# 7  https://www.ochsner-shoes.ch/CH/fr/shop/enfant...
# 8  https://www.spacenk.com/uk/home?&cm_mmc=PPC%7c...
# 9  https://www.ikks.com/fr/tee-shirt-blanc-a-impr...
#
#                      prefix category_name
# 0        www.pizzahut.co.uk         Other
# 1            us.pandora.net    My account
# 2          www.oakleysi.com    My account
# 3   www.gites-de-france.com        Search
# 4            www.hermes.com       Product
# 5        www.ralphlauren.fr         Other
# 6  www.travelrepublic.co.uk      Category
# 7      www.ochsner-shoes.ch      Category
# 8           www.spacenk.com          Home
# 9              www.ikks.com       Product

# %%
website_df["url"][0]
# Out:
# 'https://www.pizzahut.co.uk/order/deals/?cs-popin-modal--DealBotModalB$$Device Type=desktop&Login Status=logged-out&Platform Type=website&Screen Type=landing-page&Trace ID=737897fa-effb-4436-ab44-d9dc477340bb'

# %%
# Get size of the dataset

print(website_df.size)
# Out:
# 300000

# %% [markdown]
# The url format is the following: {schema}+{prefix}+{path}?{query}$${custom_variables}

# %%
website_df['c_vars'] = website_df.url.apply(lambda url: url.split('$$')[-1])
website_df['query'] = website_df.url.apply(lambda url: url.split('$$')[0].split('?')[-1])
website_df['path'] = website_df.apply(
    lambda row: row.url.split('$$')[0].split('?')[0].split(row.prefix)[-1], axis=1
)

# %%
website_df[['prefix', 'path', 'query','c_vars', 'category_name']].head(10)
# Out:
#                      prefix  \
# 0        www.pizzahut.co.uk
# 1            us.pandora.net
# 2          www.oakleysi.com
# 3   www.gites-de-france.com
# 4            www.hermes.com
# 5        www.ralphlauren.fr
# 6  www.travelrepublic.co.uk
# 7      www.ochsner-shoes.ch
# 8           www.spacenk.com
# 9              www.ikks.com
#
#                                                 path  \
# 0                                      /order/deals/
# 1  /on/demandware.store/Sites-en-US-Site/en_US/Or...
# 2      /en-us/my-account/edit-address/11813567168535
# 3                                         /fr/search
# 4  /us/en/product/candy-sandal-H211070Zv9G375/mod...
# 5                                //emailorderdetails
# 6  /holidays/hotels/c2f165a2-f433-4703-b721-70edf...
# 7  /CH/fr/shop/enfants/enfants-chaussures/enfants...
# 8                                           /uk/home
# 9  /fr/tee-shirt-blanc-a-imprime-cours-en-all-ove...
#
#                                                query  \
# 0                      cs-popin-modal--DealBotModalB
# 1                            orderNumber=PND11077497
# 2
# 3     department=81&departments=100&destination=Tarn
# 4
# 5  orderEmail=CS_ANONYMIZED_EMAIL&orderID=7000813164
# 6                        fbt=3&fcd=2%7C218701&fstr=4
# 7                                 filter-size=212@26
# 8  &cm_mmc=PPC%7cGoogle%7cUK-_-Brand%7cCore-_-Spa...
# 9
#
#                                               c_vars category_name
# 0  Device Type=desktop&Login Status=logged-out&Pl...         Other
# 1  country=us&customer_login_stat=Logged in&page_...    My account
# 2  Action=US:EN:R::Generic &Page Name=:Generic&Pa...    My account
# 3   pageCategory=resultatsDeRecherche&peopleNumber=2        Search
# 4  category=Z/Z01&clienttype=non-connected&depart...       Product
# 5  Login State=guest&Page Level 1=account&Page Le...         Other
# 6  Page path=/holidays/hotels/c2f165a2-f433-4703-...      Category
# 7         Country ID=ch&Lang ID=fr&Pagetype=CATEGORY      Category
# 8  Currency=GBP&Is Ndulge=Yes&LogStatus=Soft&Page...          Home
# 9  brand=OUTLET&category=Tee-shirt, top, chemise&...       Product

# %%
category_and_proba = website_df.category_name.value_counts(normalize=True) * 100
category_and_proba
# Out:
# Product                   36.928666
# Category                  18.071541
# Search                    12.437898
# Home                       8.970564
# Checkout                   5.570506
# Cart                       3.483895
# Confirmation               3.356587
# My account                 2.639314
# Formations / services      2.628964
# Other                      2.270845
# Brand image                1.360023
# Store locator              0.752463
# Information / legals       0.586859
# Help / support             0.366399
# Press / news               0.307403
# Offers & services          0.154219
# Favorites / wishlist       0.064172
# Form                       0.017595
# Appointments / booking     0.016560
# Careers & applications     0.015525
# Name: category_name, dtype: float64

# %%
# Define useful global variables

from pprint import pprint

ALL_CATEGORIES = list(res.axes[0])
ALL_CATEGORIES_SET = set(ALL_CATEGORIES)
CATEGORY_TO_PRIOR_PROBABILITY = {
    category: proba
    for category, proba in zip(ALL_CATEGORIES, list(category_and_proba))
}
print(ALL_CATEGORIES)
pprint(CATEGORY_TO_PRIOR_PROBABILITY)
# Out:
# ['Product', 'Category', 'Search', 'Home', 'Checkout', 'Cart', 'Confirmation', 'My account', 'Formations / services', 'Other', 'Brand image', 'Store locator', 'Information / legals', 'Help / support', 'Press / news', 'Offers & services', 'Favorites / wishlist', 'Form', 'Appointments / booking', 'Careers & applications']
# {'Appointments / booking': 0.016560404073859402,
#  'Brand image': 1.3600231845657036,
#  'Careers & applications': 0.01552537881924319,
#  'Cart': 3.4838950070381713,
#  'Category': 18.071540945599075,
#  'Checkout': 5.5705059203444565,
#  'Confirmation': 3.356586900720378,
#  'Favorites / wishlist': 0.06417156578620518,
#  'Form': 0.017595429328475617,
#  'Formations / services': 2.6289641467251803,
#  'Help / support': 0.36639894013413926,
#  'Home': 8.970563881758716,
#  'Information / legals': 0.5868593193673926,
#  'My account': 2.6393143992713424,
#  'Offers & services': 0.15421876293781567,
#  'Other': 2.2708454086279706,
#  'Press / news': 0.30740250062101515,
#  'Product': 36.92866605945185,
#  'Search': 12.437898484723027,
#  'Store locator': 0.7524633601059866}

# %% [markdown]
# The dataset is not balanced -> be careful, maybe rebalance some features or carry out some balanced training (sample weight). Is the dataset biased ? If not, there is a prior on the probabiity to belong to a certain class.<br>
# The "Other" category is already in the dataset

# %%
website_df.prefix.value_counts(normalize=True)[:20] * 100
# Out:
# www2.hm.com                    14.790
# www.gites-de-france.com         7.827
# www.pizzahut.co.uk              4.094
# www.cosstores.com               4.069
# www.gucci.com                   3.693
# www.oakley.com                  3.316
# www.travelrepublic.co.uk        3.276
# www.specsavers.co.uk            3.206
# www.spacenk.com                 2.943
# www.funkypigeon.com             2.665
# www.hobbycraft.co.uk            2.491
# uk.pandora.net                  2.380
# www.pecheur.com                 2.240
# us.pandora.net                  2.197
# www.which.co.uk                 2.150
# www.hermes.com                  2.013
# www.bottegaveneta.com           1.584
# app.contentsquare.com           1.583
# www.tomtom.com                  1.517
# www.natureetdecouvertes.com     1.498
# Name: prefix, dtype: float64

# %%
website_df.groupby('path')['path'].count().sort_values(ascending=False)[:20]
# Out:
# path
# /fr/search                     3861
# /                              3171
# /de_de/search-results.html     1707
# /en_us/search-results.html     1199
# /order/deal/                   1088
# /search                        1025
# /en_gb/checkout                 996
# /en/checkout                    851
# /advancedsearchresults.aspx     847
# /order/deals/                   786
# /en/shopping-bag                705
# /en/                            627
# /uk/cart                        612
# /en/search                      585
# /order/pizzas/                  581
# /glasses/all-glasses            538
# /us/en/                         482
# /en                             410
# /en-us/search                   357
# /en-us/cart                     331
# Name: path, dtype: int64

# %% [markdown]
# ## Explore and get some stats

# %% [markdown]
# My first idea was to investigate a given category and watch the most frequent words that those urls handle. We might expect "Search" urls to contain certain keywords that other urls don't contain often, like "search" for instance. Those words can be strong clues towards a given category.<br>
# Similarly, specific websites or actions (c_vars) on those website can helps us guess which category the url belongs to

# %%
# Most frequent path chunks for a given page category. Example with "search" category pages

from collections import Counter

def get_most_occurrent_path_chunks(category):

    category_path_chunks = [
        chunk
        for path, cat in zip(website_df["path"], website_df["category_name"])
        for chunk in path.split("/")
        if cat == category and chunk
    ]

    print(f"Number of different path chunks: {len(set(category_path_chunks))}")
    pprint(sorted(Counter(category_path_chunks).items(), key=lambda x: -x[1]))

get_most_occurrent_path_chunks("Search")
# Out:
# Number of different path chunks: 408
# [('search', 6680),
#  ('fr', 4055),
#  ('search-results.html', 2995),
#  ('de_de', 1724),
#  ('en', 1307),
#  ('en_us', 1198),
#  ('Search', 504),
#  ('us', 434),
#  ('st', 359),
#  ('newsearchpage', 359),
#  ('en-us', 337),
#  ('recherche', 327),
#  ('search.html', 310),
#  ('recherche.asp', 223),
#  ('uk', 210),
#  ('Index', 200),
#  ('de', 111),
#  ('it', 106),
#  ('search-results', 101),
#  ('en_gb', 92),
#  ('en_eur', 87),
#  ('nl', 69),
#  ('en_gbp', 69),
#  ('Cerca', 69),
#  ('ja_jp', 66),
#  ('catalogsearch', 56),
#  ('result', 56),
#  ('en-ca', 55),
#  ('jp', 50),
#  ('cs', 49),
#  ('vyhledavani', 49),
#  ('en-gb', 40),
#  ('kr', 40),
#  ('es_us', 39),
#  ('ja', 38),
#  ('Recherche', 38),
#  ('en_usd', 37),
#  ('CH', 36),
#  ('shop', 36),
#  ('ko', 35),
#  ('eu', 35),
#  ('au', 32),
#  ('en_au', 31),
#  ('pl', 29),
#  ('fr_fr', 29),
#  ('particulieren', 28),
#  ('zoek.html', 28),
#  ('es', 27),
#  ('SearchDisplay', 23),
#  ('sk', 21),
#  ('vyhladavanie', 21),
#  ('10', 21),
#  ('de-de', 16),
#  ('Zoeken', 15),
#  ('zh', 14),
#  ('gb', 14),
#  ('it-it', 13),
#  ('fr-ca', 12),
#  ('site-search', 12),
#  ('fr-fr', 12),
#  ('men', 12),
#  ('en_de', 11),
#  ('nl_nl', 11),
#  ('hk', 10),
#  ('en_dkk', 10),
#  ('be', 10),
#  ('en_sek', 10),
#  ('us_en', 10),
#  ('cn', 10),
#  ('ch', 10),
#  ('search-box', 9),
#  ('show_search', 9),
#  ('en-en', 9),
#  ('ko-kr', 8),
#  ('uk_en', 8),
#  ('sv', 8),
#  ('Suche.asp', 8),
#  ('ondernemen', 8),
#  ('es_es', 7),
#  ('ricerca.asp', 6),
#  ('ja-jp', 6),
#  ('zh_hk', 6),
#  ('pt', 6),
#  ('en_eu', 6),
#  ('20', 6),
#  ('search.asp', 6),
#  ('en-se', 5),
#  ('holidays-in-maldives', 4),
#  ('ie', 4),
#  ('it-en', 4),
#  ('1-262-2-1', 4),
#  ('holidays-in-tenerife', 4),
#  ('busqueda.asp', 4),
#  ('de_ch', 4),
#  ('dk', 4),
#  ('en_nok', 4),
#  ('1-14-2-13', 3),
#  ('all-inclusive-holidays-in-dominican-republic', 3),
#  ('search-flow', 3),
#  ('en-ie', 3),
#  ('zoeken.asp', 3),
#  ('herren', 3),
#  ('s', 3),
#  ('rose-gold', 3),
#  ('hommes', 3),
#  ('fr_ch', 3),
#  ('women', 3),
#  ('1-20-2-0', 3),
#  ('holidays-in-greece', 3),
#  ('1-262-1-0', 2),
#  ('hotels-in-tenerife', 2),
#  ('1-65-2-224', 2),
#  ('couples-holidays-in-maldives', 2),
#  ('1-230-2-0', 2),
#  ('holidays-in-gran-canaria', 2),
#  ('1-200-1-0', 2),
#  ('hotels-in-hurghada', 2),
#  ('en-nl', 2),
#  ('silver', 2),
#  ('1-17-2-0', 2),
#  ('holidays-in-spain', 2),
#  ('1-486-2-0', 2),
#  ('hombre', 2),
#  ('1-282-2-16', 2),
#  ('self-catering-holidays-in-rhodes', 2),
#  ('en-sg', 2),
#  ('gr', 2),
#  ('en-GB', 2),
#  ('1-16-2-0', 2),
#  ('holidays-in-egypt', 2),
#  ('de_at', 2),
#  ('jewellery', 2),
#  ('1-61-2-0', 2),
#  ('holidays-in-barbados', 2),
#  ('1-246-2-1', 2),
#  ('holidays-in-majorca', 2),
#  ('1-36-2-0', 2),
#  ('holidays-in-mexico', 2),
#  ('1-2392-2-0', 2),
#  ('holidays-in-playa-den-bossa', 2),
#  ('r', 2),
#  ('1-63968-2-0', 2),
#  ('holidays-in-krakow', 2),
#  ('1-5179-2-0', 2),
#  ('holidays-in-benidorm', 2),
#  ('en-dk', 2),
#  ('1-246-2-13', 2),
#  ('all-inclusive-holidays-in-majorca', 2),
#  ('1-241-2-13', 2),
#  ('all-inclusive-holidays-in-lanzarote', 2),
#  ('at', 2),
#  ('mujer', 2),
#  ('1-584-2-0', 2),
#  ('holidays-in-abu-dhabi', 2),
#  ('en-hk', 2),
#  ('ii', 2),
#  ('en-kr', 2),
#  ('1-10-2-179', 2),
#  ('family-holidays-in-cyprus', 2),
#  ('eu_en', 2),
#  ('en_ch', 2),
#  ('hu', 2),
#  ('earrings', 2),
#  ('pearl-earrings', 2),
#  ('1-272-2-179', 2),
#  ('family-holidays-in-corfu', 2),
#  ('retail', 2),
#  ('femmes', 2),
#  ('1-65-2-0', 2),
#  ('1-24056-2-0', 1),
#  ('holidays-in-rome', 1),
#  ('1-387-1-0', 1),
#  ('hotels-in-dalaman', 1),
#  ('search.html;jsessionid=8723705BF28A486B9F24A13D4F9B36FF.appserver75t3', 1),
#  ('super-search', 1),
#  ('1-10-2-13', 1),
#  ('all-inclusive-holidays-in-cyprus', 1),
#  ('weston', 1),
#  ('1-119-2-0', 1),
#  ('holidays-in-peru', 1),
#  ('1-133-2-0', 1),
#  ('holidays-in-fiji', 1),
#  ('1-2299-2-16', 1),
#  ('self-catering-holidays-in-estepona', 1),
#  ('1-5179-2-16', 1),
#  ('self-catering-holidays-in-benidorm', 1),
#  ('se', 1),
#  ('1-95-2-0', 1),
#  ('holidays-in-israel', 1),
#  ('1-241-2-224', 1),
#  ('couples-holidays-in-lanzarote', 1),
#  ('1-629-2-0', 1),
#  ('holidays-in-pattaya', 1),
#  ('1-24-2-0', 1),
#  ('holidays-in-ireland', 1),
#  ('suche', 1),
#  ('1-81-2-0', 1),
#  ('holidays-in-hong-kong', 1),
#  ('1-32-2-0', 1),
#  ('holidays-in-latvia', 1),
#  ('en-mx', 1),
#  ('tr', 1),
#  ('love', 1),
#  ('1-211-2-0', 1),
#  ('holidays-in-barcelona', 1),
#  ('search.html;jsessionid=1284EBEF46E229542339D9D07764E8B4.appserver25t1', 1),
#  ('en-ee', 1),
#  ('featured', 1),
#  ('sale', 1),
#  ('1-3174-2-0', 1),
#  ('holidays-in-aegina-island', 1),
#  ('uomo', 1),
#  ('cz', 1),
#  ('en-gr', 1),
#  ('1-795-2-0', 1),
#  ('holidays-in-west-sussex', 1),
#  ('1-2968-1-0', 1),
#  ('hotels-in-lara', 1),
#  ('en-AU', 1),
#  ('1-123-2-0', 1),
#  ('holidays-in-aruba', 1),
#  ('1-49-2-0', 1),
#  ('holidays-in-turkey', 1),
#  ('1-202-2-224', 1),
#  ('couples-holidays-in-sharm-el-sheikh', 1),
#  ('tw', 1),
#  ('marken', 1),
#  ('skechers.cat', 1),
#  ('white', 1),
#  ('brown', 1),
#  ('1-2253-2-0', 1),
#  ('holidays-in-playa-de-aro', 1),
#  ('1-384-2-179', 1),
#  ('family-holidays-in-istanbul', 1),
#  ('corporate', 1),
#  ('zoeken.html', 1),
#  ('1-320-2-0', 1),
#  ('holidays-in-cancun', 1),
#  ('search.html;jsessionid=8F4F8FD9C12B1F389145EEEE54A1B332.appserver76t3', 1),
#  ('purely-pandora', 1),
#  ('1-287-2-13', 1),
#  ('all-inclusive-holidays-in-zante-zakynthos', 1),
#  ('1-2955-2-0', 1),
#  ('holidays-in-alanya', 1),
#  ('entreprendre', 1),
#  ('chercher.html', 1),
#  ('1-382-2-1', 1),
#  ('holidays-in-antalya', 1),
#  ('tr_tr', 1),
#  ('es-es', 1),
#  ('1-65-2-13', 1),
#  ('all-inclusive-holidays-in-maldives', 1),
#  ('sg', 1),
#  ('en-ch', 1),
#  ('1-63869-2-0', 1),
#  ('holidays-in-disneyland-california', 1),
#  ('maps-ios-sdk', 1),
#  ('autocomplete-search-1', 1),
#  ('1-464-2-0', 1),
#  ('holidays-in-budapest', 1),
#  ('1-130-2-0', 1),
#  ('holidays-in-guadeloupe', 1),
#  ('1-2124-2-0', 1),
#  ('holidays-in-torrevieja', 1),
#  ('en-ae', 1),
#  ('1-89-2-0', 1),
#  ('holidays-in-cape-verde-islands', 1),
#  ('en_hk', 1),
#  ('1-23421-2-0', 1),
#  ('holidays-near-disneyland-r-paris', 1),
#  ('search.html;jsessionid=5AAFA8C7AB840DC1B7B8C0F1BB322895.appserver76t2', 1),
#  ('ch_de', 1),
#  ('ie_en', 1),
#  ('1-630-2-0', 1),
#  ('holidays-in-koh-phi-phi', 1),
#  ('1-275-2-179', 1),
#  ('family-holidays-in-halkidiki', 1),
#  ('1-314-2-0', 1),
#  ('holidays-in-marrakech', 1),
#  ('1-282-2-1', 1),
#  ('holidays-in-rhodes', 1),
#  ('1-144-2-0', 1),
#  ('holidays-in-iraq', 1),
#  ('pesquisa.asp', 1),
#  ('service--consommateurs', 1),
#  ('veelgestelde-vragen', 1),
#  ('cs_cz', 1),
#  ('1-63952-2-0', 1),
#  ('holidays-in-kuredu-island', 1),
#  ('1-4537-2-0', 1),
#  ('holidays-in-vis-island', 1),
#  ('no_no', 1),
#  ('sa', 1),
#  ('1-22627-1-0', 1),
#  ('hotels-in-sorrento-coast', 1),
#  ('pages', 1),
#  ('search.aspx', 1),
#  ('1-241-2-0', 1),
#  ('holidays-in-lanzarote', 1),
#  ('pt_br', 1),
#  ('1-170-2-224', 1),
#  ('couples-holidays-in-dubai', 1),
#  ('1-3060-2-0', 1),
#  ('holidays-in-porto-heli', 1),
#  ('1-353-1-0', 1),
#  ('hotels-in-algarve', 1),
#  ('1-383-1-0', 1),
#  ('hotels-in-bodrum', 1),
#  ('1-14-2-0', 1),
#  ('holidays-in-dominican-republic', 1),
#  ('en_za', 1),
#  ('1-47-2-13', 1),
#  ('all-inclusive-holidays-in-thailand', 1),
#  ('en_gr', 1),
#  ('1-2718-2-0', 1),
#  ('holidays-in-valencia-city', 1),
#  ('1-63972-2-0', 1),
#  ('holidays-in-las-vegas', 1),
#  ('ca', 1),
#  ('1-39377-2-0', 1),
#  ('holidays-in-biarritz', 1),
#  ('1-942-2-0', 1),
#  ('holidays-in-borneo-malaysia', 1),
#  ('sieraden', 1),
#  ('medaillons', 1),
#  ('1-828-2-0', 1),
#  ('holidays-in-ras-al-khaimah', 1),
#  ('1-284-2-13', 1),
#  ('all-inclusive-holidays-in-santorini', 1),
#  ('en-at', 1),
#  ('1-228-2-179', 1),
#  ('family-holidays-in-fuerteventura', 1),
#  ('1-246-2-179', 1),
#  ('family-holidays-in-majorca', 1),
#  ('pt_pt', 1),
#  ('ae', 1),
#  ('discover', 1),
#  ('stories-experiences', 1),
#  ('christmas-gift-guide', 1),
#  ('en-sk', 1),
#  ('1-116-2-0', 1),
#  ('holidays-in-moldova', 1),
#  ('1-246-1-0', 1),
#  ('hotels-in-majorca', 1),
#  ('disney-x-pandora', 1),
#  ('1-278-1-0', 1),
#  ('hotels-in-kos', 1),
#  ('en-be', 1),
#  ('ww_en', 1),
#  ('blue_clear', 1),
#  ('1-603-2-0', 1),
#  ('holidays-in-didim', 1),
#  ('home', 1),
#  ('50', 1),
#  ('1-387-2-13', 1),
#  ('all-inclusive-holidays-in-dalaman', 1),
#  ('1-22713-2-0', 1),
#  ('holidays-in-venice', 1),
#  ('rings', 1),
#  ('stackable-rings', 1),
#  ('1-2993-2-0', 1),
#  ('holidays-in-dalyan', 1),
#  ('1-280-2-0', 1),
#  ('holidays-in-mykonos', 1),
#  ('1-5-2-0', 1),
#  ('holidays-in-bulgaria', 1),
#  ('en-de', 1),
#  ('1-278-2-1', 1),
#  ('holidays-in-kos', 1),
#  ('inspiration', 1),
#  ('1-199-2-0', 1),
#  ('holidays-in-cairo', 1),
#  ('pl_pl', 1),
#  ('1-438-2-0', 1),
#  ('holidays-in-prague', 1),
#  ('1-1661-2-0', 1),
#  ('holidays-in-denizli', 1),
#  ('1-7006-2-0', 1),
#  ('holidays-in-copacabana', 1),
#  ('1-284-2-1', 1),
#  ('holidays-in-santorini', 1),
#  ('soldes', 1),
#  ('voir-tout', 1),
#  ('100421', 1),
#  ('1-22627-2-0', 1),
#  ('holidays-in-sorrento-coast', 1),
#  ('it_it', 1),
#  ('en-no', 1),
#  ('1-2690-2-0', 1),
#  ('holidays-in-playa-de-las-americas', 1),
#  ('1-626-2-0', 1),
#  ('holidays-in-koh-samui', 1),
#  ('1-170-2-13', 1),
#  ('all-inclusive-holidays-in-dubai', 1),
#  ('1-23154-2-0', 1),
#  ('holidays-in-hvar-island', 1),
#  ('1-228-2-1', 1),
#  ('holidays-in-fuerteventura', 1),
#  ('1-453-2-0', 1),
#  ('holidays-in-berlin', 1),
#  ('en_in', 1),
#  ('searchresults', 1),
#  ('index.html', 1),
#  ('1-273-1-0', 1),
#  ('hotels-in-crete', 1),
#  ('de-at', 1),
#  ('1-2082-2-0', 1),
#  ('holidays-in-hurghada', 1)]

# %% [markdown]
# We see a mixture of relevant words like "search" "recherche" and non-relevant words like language ones, that should appear in all categories. TF-IDF should solve that

# %%
# Same for "Product"

get_most_occurrent_path_chunks("Product")
# Out:
# Number of different path chunks: 34343
# [('fr', 4718),
#  ('en', 3178),
#  ('de_de', 2796),
#  ('en_us', 2569),
#  ('product', 2565),
#  ('women', 2550),
#  ('us', 2279),
#  ('pr', 1556),
#  ('womenswear', 1493),
#  ('uk', 1443),
#  ('en_eur', 1326),
#  ('en-us', 1291),
#  ('__', 957),
#  ('men', 941),
#  ('order', 940),
#  ('card', 919),
#  ('de', 893),
#  ('analyze', 782),
#  ('deal', 759),
#  ('auvergne-rhone-alpes', 630),
#  ('bretagne', 599),
#  ('model-selection', 585),
#  ('eu', 511),
#  ('ja_jp', 507),
#  ('personalized-products', 497),
#  ('video', 470),
#  ('nouvelle-aquitaine', 460),
#  ('it', 447),
#  ('pages', 447),
#  ('zoning-v2', 444),
#  ('occitanie', 437),
#  ('es', 417),
#  ('skincare', 414),
#  ('menswear', 405),
#  ('zh', 397),
#  ('dresses', 388),
#  ('hotels', 380),
#  ('normandie', 376),
#  ('v3', 371),
#  ('shop', 355),
#  ('jp', 344),
#  ('accessories', 342),
#  ('en_gb', 340),
#  ('tops', 336),
#  ('customisecards.aspx', 330),
#  ('makeup', 307),
#  ('CH', 289),
#  ('editor', 289),
#  ('en_usd', 289),
#  ('en_gbp', 289),
#  ('nl', 286),
#  ('preview', 284),
#  ('knitwear', 280),
#  ('en-ca', 275),
#  ('trousers', 266),
#  ('provence-alpes-cote-dazur', 263),
#  ('fr_fr', 248),
#  ('kr', 236),
#  ('enfant', 233),
#  ('en-gb', 228),
#  ('p', 228),
#  ('az-magazines', 222),
#  ('cs', 222),
#  ('coats-and-jackets', 209),
#  ('ready-to-wear', 207),
#  ('cotes-darmor', 206),
#  ('es_us', 202),
#  ('handbags', 194),
#  ('bourgogne-franche-comte', 194),
#  ('au', 191),
#  ('cn', 185),
#  ('finistere', 181),
#  ('sunglasses', 178),
#  ('pages-comparator', 176),
#  ('pizzas', 172),
#  ('current-offers', 170),
#  ('treatment', 167),
#  ('shirts', 166),
#  ('grand-est', 165),
#  ('navigation-path', 162),
#  ('osobni-finance', 162),
#  ('gb', 160),
#  ('Pages', 160),
#  ('complexion', 156),
#  ('bien-etre', 154),
#  ('glasses', 150),
#  ('accessories-for-women', 142),
#  ('session-replay', 141),
#  ('fragrance', 140),
#  ('children', 138),
#  ('jewelry-watches', 135),
#  ('pays-de-la-loire', 134),
#  ('ko', 134),
#  ('it-it', 131),
#  ('us_en', 131),
#  ('hauts-de-france', 130),
#  ('occasions', 130),
#  ('bags', 126),
#  ('morbihan', 126),
#  ('be', 126),
#  ('deco-maison', 126),
#  ('ja', 124),
#  ('t-shirts', 121),
#  ('damen', 121),
#  ('carconfigurator', 115),
#  ('workflow', 115),
#  ('accessories-for-men', 113),
#  ('en_au', 112),
#  ('calvados', 112),
#  ('de-de', 111),
#  ('centre-val-de-loire', 109),
#  ('moisturisers', 109),
#  ('woman', 109),
#  ('haircare', 107),
#  ('fr-fr', 107),
#  ('haute-savoie', 107),
#  ('savoie', 104),
#  ('CustomiseCards.aspx', 103),
#  ('shoes-for-women', 103),
#  ('hk', 102),
#  ('day-moisturiser', 101),
#  ('en_sek', 101),
#  ('manche', 100),
#  ('bath-body', 98),
#  ('en_dkk', 96),
#  ('pujcky', 96),
#  ('pujcka', 96),
#  ('sweatshirts', 95),
#  ('jumpers', 94),
#  ('options', 93),
#  ('drive', 93),
#  ('ca', 93),
#  ('shoes', 92),
#  ('pyrenees-atlantiques', 91),
#  ('seine-maritime', 89),
#  ('proace-city-business-promo', 89),
#  ('pt', 88),
#  ('new-arrivals', 87),
#  ('ille-et-vilaine', 86),
#  ('customisecardsmobile.aspx', 85),
#  ('en_de', 85),
#  ('holidays', 85),
#  ('c', 84),
#  ('fr-ca', 80),
#  ('ardeche', 80),
#  ('used-car-details', 78),
#  ('damen-schuhe', 76),
#  ('coats', 73),
#  ('lips', 71),
#  ('vaucluse', 71),
#  ('charente-maritime', 71),
#  ('jackets', 70),
#  ('corse', 70),
#  ('shoulder-bags-for-women', 70),
#  ('en_nok', 70),
#  ('hats-scarves-and-gloves', 69),
#  ('l', 69),
#  ('jeans', 67),
#  ('serums', 67),
#  ('puy-de-dome', 66),
#  ('ch', 65),
#  ('models', 64),
#  ('jardin', 64),
#  ('eyes', 63),
#  ('cantal', 62),
#  ('customize', 62),
#  ('new-cars', 61),
#  ('ja-jp', 60),
#  ('somme', 58),
#  ('ready-to-wear-for-women', 58),
#  ('cleansers', 58),
#  ('voiture', 58),
#  ('bijoux', 57),
#  ('outdoor', 57),
#  ('at', 57),
#  ('article', 57),
#  ('landes', 56),
#  ('eyeglasses', 56),
#  ('sk', 56),
#  ('kinder-schuhe', 56),
#  ('lens-selector', 56),
#  ('herren', 56),
#  ('ie', 55),
#  ('drome', 55),
#  ('lot', 54),
#  ('bouches-du-rhone', 54),
#  ('maps-services', 54),
#  ('bracelets', 53),
#  ('aveyron', 53),
#  ('pl', 53),
#  ('custom-product', 53),
#  ('lost-my-name-book', 53),
#  ('underwear', 53),
#  ('products', 52),
#  ('masks', 52),
#  ('new-sibling-for-you-book', 52),
#  ('foundation', 52),
#  ('cleanser', 52),
#  ('jouets-eveil', 51),
#  ('jura', 51),
#  ('puericulture', 51),
#  ('shoulder-bags', 50),
#  ('bags-for-men', 50),
#  ('hautes-pyrenees', 50),
#  ('decoration', 50),
#  ('dordogne', 50),
#  ('personal-fragrance', 50),
#  ('hautes-alpes', 50),
#  ('vendee', 50),
#  ('cardigans', 49),
#  ('ready-to-wear-for-men', 49),
#  ('thes-epicerie', 49),
#  ('pyrenees-orientales', 49),
#  ('silver-jewelry', 49),
#  ('livres-loisirs', 48),
#  ('kinder', 48),
#  ('crossbody-bags-for-women', 48),
#  ('loire-atlantique', 48),
#  ('massage', 48),
#  ('index.html', 48),
#  ('%E6%8A%A4%E8%82%A4%E5%93%81', 47),
#  ('uk_en', 46),
#  ('haut-rhin', 46),
#  ('player', 46),
#  ('de_ch', 46),
#  ('gr', 46),
#  ('10', 45),
#  ('home-fragrance', 45),
#  ('man', 44),
#  ('where-are-you-book', 44),
#  ('bedtime-for-name-book', 44),
#  ('search', 43),
#  ('hypoteky', 43),
#  ('huiles-essentielles-diffuseur', 43),
#  ('relaxation-sommeil', 43),
#  ('se', 43),
#  ('shoes-for-men', 43),
#  ('hypoteka', 42),
#  ('cote-dor', 42),
#  ('lozere', 42),
#  ('wallets-and-small-accessories-for-women', 42),
#  ('hair-treatment', 42),
#  ('en-au', 42),
#  ('ile-de-france', 41),
#  ('donna', 41),
#  ('correze', 41),
#  ('saone-et-loire', 41),
#  ('body-moisturiser-oils', 41),
#  ('femme', 41),
#  ('savings', 41),
#  ('isere', 41),
#  ('corse-du-sud', 40),
#  ('body-cleanser', 40),
#  ('eure', 40),
#  ('jeux-societe', 40),
#  ('W0OO9102', 39),
#  ('belts-for-women', 39),
#  ('select-engine', 39),
#  ('vosges', 39),
#  ('silver-rings', 39),
#  ('gironde', 39),
#  ('brillen', 39),
#  ('tours', 38),
#  ('ludia', 37),
#  ('coats-jackets', 37),
#  ('boots', 37),
#  ('alpes-de-haute-provence', 37),
#  ('cz', 37),
#  ('skirts', 37),
#  ('yoga-gym-douce', 36),
#  ('uomo', 36),
#  ('hats', 36),
#  ('mini-bags-for-women', 35),
#  ('orne', 35),
#  ('cosmetiques-maquillage', 35),
#  ('dossier', 35),
#  ('lipstick', 35),
#  ('ko-kr', 35),
#  ('suits', 34),
#  ('shampoo', 34),
#  ('pageview', 34),
#  ('aude', 34),
#  ('en_eu', 34),
#  ('pobocky-a-bankomaty', 34),
#  ('objednani', 34),
#  ('concealer', 34),
#  ('happy-birthday-to-you-book', 33),
#  ('jeux-plein-air', 33),
#  ('pas-de-calais', 33),
#  ('bekleidung', 33),
#  ('gers', 33),
#  ('b', 33),
#  ('the-wondrous-road-book', 33),
#  ('f2', 32),
#  ('blazers', 32),
#  ('baby', 32),
#  ('sneakers', 32),
#  ('indre-et-loire', 31),
#  ('homme', 31),
#  ('eyeshadow', 31),
#  ('herault', 31),
#  ('wallets-and-small-accessories-for-men', 31),
#  ('eu_en', 31),
#  ('ru-ru', 30),
#  ('W0OO9188', 30),
#  ('shampoos', 30),
#  ('womens-handbags', 30),
#  ('librairie', 30),
#  ('herren-schuhe', 30),
#  ('beauty', 30),
#  ('eyecare', 30),
#  ('eye-treatment', 30),
#  ('en_ch', 30),
#  ('haute-corse', 30),
#  ('optique-astronomie', 30),
#  ('colliers', 30),
#  ('girls', 30),
#  ('candle', 30),
#  ('chambre-bebe-enfant', 30),
#  ('bas-rhin', 29),
#  ('zh_hk', 29),
#  ('watches', 29),
#  ('jewellery', 29),
#  ('jeu', 29),
#  ('chain-bags-for-women', 28),
#  ('bags-woman', 28),
#  ('es-es', 28),
#  ('rhone', 28),
#  ('styling', 28),
#  ('tarn', 28),
#  ('define', 28),
#  ('mappings', 28),
#  ('powder', 28),
#  ('car', 28),
#  ('abc-for-you-book', 28),
#  ('thats-my-cake-book', 28),
#  ('en-US', 27),
#  ('es_es', 27),
#  ('loisirs-creatifs', 27),
#  ('silver-jewellery', 27),
#  ('sg', 27),
#  ('swimwear', 27),
#  ('tw', 27),
#  ('in-dash-navigation', 27),
#  ('shorts', 27),
#  ('diffuseur-huiles-essentielles', 26),
#  ('sun-tan', 26),
#  ('W0OO9208', 26),
#  ('parfums-interieur', 26),
#  ('car-models', 26),
#  ('dk', 26),
#  ('var', 26),
#  ('comparison', 26),
#  ('enduro', 26),
#  ('haute-vienne', 25),
#  ('alpes-maritimes', 25),
#  ('gifts', 25),
#  ('fr_ch', 25),
#  ('finance_calculator', 24),
#  ('fc_workflow', 24),
#  ('mode', 24),
#  ('i-love-you-book', 24),
#  ('activewear', 23),
#  ('belts-for-men', 23),
#  ('haute-loire', 23),
#  ('fine-rings', 23),
#  ('sessions', 23),
#  ('origin', 23),
#  ('skincare-set', 23),
#  ('skincare-sets', 23),
#  ('ain', 23),
#  ('damen-sneaker', 23),
#  ('ae', 23),
#  ('archive-sale', 23),
#  ('lot-et-garonne', 23),
#  ('en-nl', 23),
#  ('travelwear', 23),
#  ('sneakers-for-men', 23),
#  ('%D0%BE%D0%B4%D0%B5%D0%B6%D0%B4%D0%B0', 22),
#  ('kids', 22),
#  ('casual-belts-for-men', 22),
#  ('allier', 22),
#  ('seine-et-marne', 22),
#  ('cart', 22),
#  ('indre', 22),
#  ('%E5%8C%96%E5%A6%86%E5%93%81', 22),
#  ('unisex', 22),
#  ('jeux-educatifs', 22),
#  ('hu', 21),
#  ('produkte', 21),
#  ('en-sg', 21),
#  ('fine-jewelry', 21),
#  ('jumelles-longues-vues', 21),
#  ('gard', 21),
#  ('femmes', 21),
#  ('choose-pages', 21),
#  ('tools', 21),
#  ('small-wallets', 21),
#  ('wide-belts-for-women', 21),
#  ('fr-be', 21),
#  ('face-oils', 20),
#  ('charente', 20),
#  ('cher', 20),
#  ('marken', 20),
#  ('en-dk', 20),
#  ('slides-and-thong-sandals-for-women', 20),
#  ('sneakers-for-women', 20),
#  ('silver-necklaces', 20),
#  ('socks', 20),
#  ('hamacs', 20),
#  ('woman-bags', 20),
#  ('mini-bags', 20),
#  ('compare-savings-account-rates', 20),
#  ('kinder-sneaker', 19),
#  ('loire', 19),
#  ('de-at', 19),
#  ('programme', 19),
#  ('lumiere-ambiance', 19),
#  ('ariege', 19),
#  ('wx', 19),
#  ('jumelles', 19),
#  ('jumpsuits', 19),
#  ('materiel-montessori', 19),
#  ('watches-for-women', 19),
#  ('Yaris', 19),
#  ('%D0%B6%D0%B5%D0%BD%D1%89%D0%B8%D0%BD%D1%8B', 18),
#  ('travel-map', 18),
#  ('cheeks', 18),
#  ('used-ford-focus', 18),
#  ('a-faire-soi-meme', 18),
#  ('womens', 18),
#  ('en-ch', 18),
#  ('nouveaut%C3%A9s', 18),
#  ('en-en', 18),
#  ('en-hk', 18),
#  ('fashion-jewelry', 18),
#  ('nord', 18),
#  ('jardinage', 18),
#  ('femmes-chaussures', 18),
#  ('%E6%B6%A6%E8%82%A4%E4%B9%B3', 18),
#  ('%E6%97%A5%E9%97%B4%E6%B6%A6%E8%82%A4%E4%B9%B3', 18),
#  ('camping-bivouac', 18),
#  ('tinted-moisturiser', 17),
#  ('maine-et-loire', 17),
#  ('bouillottes-coussins-chauffants', 17),
#  ('%E3%82%A6%E3%82%A3%E3%83%A1%E3%83%B3%E3%82%BA', 17),
#  ('suncare', 17),
#  ('subscription', 17),
#  ('tiger-t-shirt', 17),
#  ('messengers-bags-for-men', 17),
#  ('silks-and-scarves-for-women', 17),
#  ('%E3%82%A6%E3%82%A7%E3%82%A2', 17),
#  ('couteaux-pinces', 17),
#  ('skinny-belts-for-women', 16),
#  ('accessoires', 16),
#  ('denim', 16),
#  ('redirect', 16),
#  ('top-handle-bags-for-women', 16),
#  ('card-cases', 16),
#  ('luminotherapie-reveils', 16),
#  ('nievre', 16),
#  ('brands', 16),
#  ('s', 16),
#  ('space-nk', 16),
#  ('leisurewear', 16),
#  ('hats-and-gloves-for-men', 16),
#  ('loir-et-cher', 16),
#  ('configure-product', 16),
#  ('nl_nl', 16),
#  ('en-se', 16),
#  ('ii', 16),
#  ('ties', 16),
#  ('index', 16),
#  ('deux-sevres', 15),
#  ('par-brume', 15),
#  ('jewellery-watches', 15),
#  ('bucket-bags-for-women', 15),
#  ('used-ford-fiesta', 15),
#  ('sale', 15),
#  ('vienne', 15),
#  ('world', 15),
#  ('tiger-sweatshirt', 15),
#  ('crossbody-bags', 15),
#  ('bol-accessoires-relaxation', 15),
#  ('appareils-sommeil', 15),
#  ('en-pl', 15),
#  ('az-single-issues', 15),
#  ('bi-fold-wallets-for-men', 15),
#  ('haute-garonne', 15),
#  ('taschen', 15),
#  ('meteo-appareils-mesure', 15),
#  ('doubs', 15),
#  ('horen', 15),
#  ('%E9%A6%99%E6%B0%B4%E9%A6%99%E6%B0%9B', 15),
#  ('%E3%83%A1%E3%83%B3%E3%82%BA', 15),
#  ('W0OO7064S', 15),
#  ('yonne', 15),
#  ('pants', 15),
#  ('body-wash', 15),
#  ('ee', 15),
#  ('girl', 15),
#  ('sacs', 14),
#  ('decouverte-apprentissage', 14),
#  ('ucty-karty', 14),
#  ('lipcare', 14),
#  ('loiret', 14),
#  ('productpage.0948428002.html', 14),
#  ('W0OO7105S', 14),
#  ('creuse', 14),
#  ('11', 14),
#  ('knitted-tops-and-vests', 14),
#  ('toner', 14),
#  ('hair-accessories', 14),
#  ('earrings', 14),
#  ('prices-and-costs', 14),
#  ('station-meteo', 14),
#  ('plantes-interieur', 14),
#  ('spray-diffuser', 14),
#  ('casse-tete', 14),
#  ('makeup-brushes', 14),
#  ('%E6%8A%A4%E7%90%86%E4%BA%A7%E5%93%81', 14),
#  ('habillement', 14),
#  ('select-model', 14),
#  ('most-popular', 14),
#  ('where-are-you-2-book', 14),
#  ('4-stroke', 14),
#  ('de-ch', 14),
#  ('mascara', 13),
#  ('borse', 13),
#  ('librairie-nature-science', 13),
#  ('peels', 13),
#  ('decor', 13),
#  ('dared-to-dream-book', 13),
#  ('productpage.0941666003.html', 13),
#  ('scrubs-exfoliants', 13),
#  ('CustomiseCardsMobile.aspx', 13),
#  ('scarves', 13),
#  ('you-love-mummy-book', 13),
#  ('huiles-essentielles', 13),
#  ('womens-small-leather-goods', 13),
#  ('pr%C3%AAt-%C3%A0-porter', 13),
#  ('mens-shoes', 13),
#  ('sandals-for-women', 13),
#  ('hand-feet', 13),
#  ('kingdom-of-you-book', 13),
#  ('heart-ring-with-gucci-trademark-p-223867J84008106', 13),
#  ('C-HR', 13),
#  ('boys', 13),
#  ('nuovi-arrivi', 13),
#  ('chaise-hamac-simple', 13),
#  ('biznis', 13),
#  ('primer', 13),
#  ('sarthe', 13),
#  ('bags-and-wallets', 12),
#  ('enfants', 12),
#  ('enfants-chaussures', 12),
#  ('mens', 12),
#  ('W0OO9440', 12),
#  ('lip-balm', 12),
#  ('landing-pages', 12),
#  ('speed-camera-updates', 12),
#  ('chain-wallets-for-women', 12),
#  ('body-lotion', 12),
#  ('tables-tapis-massage', 12),
#  ('W0OO7070S', 12),
#  ('nonpersonalisedproduct.aspx', 12),
#  ('iphone', 12),
#  ('mx', 12),
#  ('W0OO9406', 12),
#  ('product.fine-roll-neck-wool-top-black.0145839005.html', 12),
#  ('womens-small-leathergoods', 12),
#  ('1', 12),
#  ('aygo-promo', 12),
#  ('ready-to-wear-man', 12),
#  ('productpage.0978872001.html', 12),
#  ('marne', 12),
#  ('airbrush-flawless-finish-powder-MUK200024651.html', 12),
#  ('smartphone-ricondizionato.html', 12),
#  ('en-ae', 12),
#  ('make-up', 12),
#  ('used-ford-kuga', 12),
#  ('W0OO9013', 12),
#  ('04150000', 12),
#  ('low-top-sneakers-for-men', 12),
#  ('face-suncream', 12),
#  ('eyeliner', 11),
#  ('debetne-karty', 11),
#  ('vlastna-karta', 11),
#  ('corolla-ts', 11),
#  ('sunglasses-for-men', 11),
#  ('damen-ubergrossen', 11),
#  ('vests', 11),
#  ('soins-visage', 11),
#  ('911545', 11),
#  ('body-creme-butter', 11),
#  ('ucty', 11),
#  ('en-no', 11),
#  ('eye-t-shirt', 11),
#  ('reveils-horloges', 11),
#  ('chapeaux', 11),
#  ('footwear-and-accessories-clearance', 11),
#  ('toners', 11),
#  ('sandals', 11),
#  ('nl-be', 11),
#  ('veilleuses', 11),
#  ('gucci-decor', 11),
#  ('contact-lenses', 11),
#  ('ux', 11),
#  ('aisne', 11),
#  ('en-gr', 11),
#  ('other-accessories', 11),
#  ('Proace', 11),
#  ('mens-accessories', 11),
#  ('plaids-chaussettes', 11),
#  ('conditioner', 11),
#  ('conditioners', 11),
#  ('W0OO9265', 11),
#  ('womens-hobos-shoulder-bags', 11),
#  ('uvery', 11),
#  ('en-cz', 11),
#  ('fragrances', 11),
#  ('2-stroke', 11),
#  ('W0OO9263', 11),
#  ('chr-hybride-promo', 11),
#  ('bagues', 11),
#  ('scarves-for-women', 11),
#  ('tapis-coussins', 10),
#  ('swimsuits', 10),
#  ('product.oversized-trench-coat-beige.0891555003.html', 10),
#  ('slippers-for-women', 10),
#  ('sets-palettes', 10),
#  ('hairspray', 10),
#  ('piquenique-lunchbox', 10),
#  ('wallets-small-accessories', 10),
#  ('belts-and-belt-bags', 10),
#  ('linge-de-maison', 10),
#  ('linge-de-lit', 10),
#  ('iphone-11-pro-256-go-grigio-siderale-sbloccato-da-tutti-gli-operatori-miglior-prezzo',
#   10),
#  ('290037.html', 10),
#  ('decoration-jardin', 10),
#  ('creme-de-la-mer-moisturizing-cream-MUK200020070.html', 10),
#  ('en-be', 10),
#  ('productpage.0941666009.html', 10),
#  ('contactlenzen', 10),
#  ('daily-disposables', 10),
#  ('fashion-jewelry-woman', 10),
#  ('fauteuil-suspendu-avec-support-longchi-52150920', 10),
#  ('nouvelle-yaris-essence-promo', 10),
#  ('jeux-construction', 10),
#  ('%E4%BA%AE%E8%82%A4', 10),
#  ('model-filter', 10),
#  ('damen-schuhe-boots', 10),
#  ('hombre', 10),
#  ('product.html', 10),
#  ('bikinis', 10),
#  ('oise', 10),
#  ('haute-saone', 10),
#  ('%E5%AE%B6%E7%94%A8%E9%A6%99%E6%B0%B4%E9%A6%99%E6%B0%9B', 10),
#  ('10000000', 10),
#  ('W0OO9295', 10),
#  ('tote-bags-for-women', 10),
#  ('petits-jardiniers', 10),
#  ('W0OO4141', 10),
#  ('a-faire-pousser', 10),
#  ('essentials', 10),
#  ('shoes-for-girls', 10),
#  ('RAV4', 10),
#  ('spotrebny-uver-na-cokolvek', 10),
#  ('%EC%97%AC%EC%84%B1', 10),
#  ('herren-schuhe-sneaker', 10),
#  ('travel', 10),
#  ('ru', 10),
#  ('Corolla-HB', 10),
#  ('mens-small-leathergoods', 10),
#  ('maroquinerie', 10),
#  ('en-pt', 10),
#  ('%E5%A5%B3%E5%A3%AB', 10),
#  ('skincare-tools', 10),
#  ('en-bg', 10),
#  ('contes-histoires', 10),
#  ('experimentations', 10),
#  ('schultertaschen', 10),
#  ('outerwear', 10),
#  ('leather-belt-with-double-g-buckle-p-409417AP00T1000', 9),
#  ('0OO9208CP', 9),
#  ('fr-en', 9),
#  ('fashion-jewellery', 9),
#  ('quotation-confirmed', 9),
#  ('my', 9),
#  ('moselle', 9),
#  ('product.oversized-scuba-hoodie-green.0971959001.html', 9),
#  ('%E3%83%90%E3%83%83%E3%82%B0', 9),
#  ('product.hooded-sweatshirt-dress-blue.0952981001.html', 9),
#  ('watches-for-men', 9),
#  ('th', 9),
#  ('ie_en', 9),
#  ('mens-ready-to-wear', 9),
#  ('taie-d-oreiller-en-soie-ivoire-15212820', 9),
#  ('%E5%A5%B3%E8%A3%9D', 9),
#  ('ready-to-wear-woman', 9),
#  ('t-shirt-tigre', 9),
#  ('W1OO9188A0L', 9),
#  ('hair-cream', 9),
#  ('jeux-nature-observation', 9),
#  ('nouvelle-yaris-hybride-promo-2', 9),
#  ('tanning', 9),
#  ('sunglasses-for-women', 9),
#  ('kits-coffrets-creatifs', 9),
#  ('mujer', 9),
#  ('en-lt', 9),
#  ('%E8%9C%A1%E7%83%9B', 9),
#  ('aube', 9),
#  ('product.relaxed-long-sleeve-t-shirt-blue.0958346002.html', 9),
#  ('couteaux', 9),
#  ('boots-and-booties-for-women', 9),
#  ('schuhe', 9),
#  ('strickwaren', 9),
#  ('complements-alimentaires', 9),
#  ('navigation-voices', 9),
#  ('corolla-promo', 9),
#  ('randonnee', 9),
#  ('baguette', 9),
#  ('34207711', 9),
#  ('external-brands', 9),
#  ('form_workflow', 9),
#  ('productpage.0966287003.html', 9),
#  ('face', 9),
#  ('alerts', 9),
#  ('notifications', 9),
#  ('campaigns', 9),
#  ('W0OO9244', 8),
#  ('necklaces', 8),
#  ('iphone-xr-64-go-nero-compatibile-con-tutti-gli-operatori-miglior-prezzo', 8),
#  ('161659.html', 8),
#  ('en-hu', 8),
#  ('wallpapers', 8),
#  ('materiel-exercice', 8),
#  ('highlighter', 8),
#  ('en-tr', 8),
#  ('recherche', 8),
#  ('node', 8),
#  ('re', 8),
#  ('%D0%BC%D1%83%D0%B6%D1%87%D0%B8%D0%BD%D1%8B', 8),
#  ('womens-mini-bags', 8),
#  ('6942884', 8),
#  ('book-of-mars-2nd-edition.thtml', 8),
#  ('hair-mask', 8),
#  ('night-moisturiser', 8),
#  ('%E7%88%BD%E8%82%A4%E6%B0%B4', 8),
#  ('t-shirts-tops', 8),
#  ('womens-shoes', 8),
#  ('tarn-et-garonne', 8),
#  ('morphee-box-meditation-et-sophrologie-15204880', 8),
#  ('mens-bags', 8),
#  ('womens-ready-to-wear', 8),
#  ('34207706', 8),
#  ('womans-weekly-subscription.thtml', 8),
#  ('%E3%83%AC%E3%83%87%E3%82%A3%E3%83%BC%E3%82%B9', 8),
#  ('instruments-musique', 8),
#  ('soho-small-leather-disco-bag-p-308364A7M0G1000', 8),
#  ('silver-bracelets', 8),
#  ('encens-accessoires', 8),
#  ('headbands-for-women', 8),
#  ('W0OO9416', 8),
#  ('gwp-category', 8),
#  ('cadeaux-naissance', 8),
#  ('cadeau-bebe', 8),
#  ('sport', 8),
#  ('17', 8),
#  ('W0OO9014', 8),
#  ('imaginefx-magazine-subscription.thtml', 8),
#  ('ardennes', 8),
#  ('cuisine-arts-table', 8),
#  ('en-kr', 8),
#  ('just-skin-tinted-moisturizer-spf15-MUK200001587.html', 8),
#  ('product.wide-neck-long-sleeve-t-shirt-blue.0947727003.html', 8),
#  ('you-love-grandma-book', 8),
#  ('femmes-sneaker', 8),
#  ('top-handles', 8),
#  ('W0OO4123', 8),
#  ('polo-shirts', 8),
#  ('europe', 8),
#  ('electronic', 8),
#  ('skincare-devices', 8),
#  ('it-IT', 8),
#  ('mens-sneakers', 8),
#  ('product.pleated-shirt-dress-white.0973697002.html', 8),
#  ('backpacks-for-men', 8),
#  ('jeux-plateau', 8),
#  ('34248031', 8),
#  ('product.regular-fit-t-shirt-white.0753391001.html', 8),
#  ('skirts-for-women', 8),
#  ('t-shirts-polos', 8),
#  ('mens-bifold-wallets', 8),
#  ('go-navigation', 8),
#  ('usa', 8),
#  ('guadeloupe', 8),
#  ('iphone-8-64-go-grigio-siderale-sbloccato-da-tutti-gli-operatori-miglior-prezzo',
#   8),
#  ('36827.html', 8),
#  ('en-fr', 8),
#  ('lifestyle', 8),
#  ('espadrilles-and-wedges', 8),
#  ('%E3%82%B3%E3%83%BC%E3%83%88%EF%BC%86%E3%82%B8%E3%83%A3%E3%82%B1%E3%83%83%E3%83%88',
#   8),
#  ('woman-and-home-subscription.thtml', 8),
#  ('test_drive_nm_hybrid', 8),
#  ('contact-details', 8),
#  ('W0OO9264', 8),
#  ('en-ie', 8),
#  ('moccasins-and-loafers-for-women', 8),
#  ('sat-nav', 8),
#  ('soho-small-leather-disco-bag-p-308364A7M0G2754', 8),
#  ('product.zip-up-denim-boilersuit-turquoise.0938391001.html', 8),
#  ('gg-marmont-matelasse-mini-bag-p-446744DTDIT1000', 8),
#  ('augen', 7),
#  ('val-doise', 7),
#  ('productpage.0932911004.html', 7),
#  ('lip-tint', 7),
#  ('jouets-empilement', 7),
#  ('jeux-volants', 7),
#  ('iphone-xs-64-go-grigio-siderale-sbloccato-miglior-prezzo', 7),
#  ('178592.html', 7),
#  ('no', 7),
#  ('ballon-de-pilates-a-base-de-cafe-15214920', 7),
#  ('fi', 7),
#  ('teint', 7),
#  ('damen-chelseaboots', 7),
#  ('W0OO9397', 7),
#  ('your-colors-book', 7),
#  ('gg-marmont-matelasse-mini-chain-bag-p-443447DTD1T1000', 7),
#  ('meurthe-et-moselle', 7),
#  ('%E6%89%8B%E8%A2%8B', 7),
#  ('materiel-accessoires', 7),
#  ('productpage.0962975003.html', 7),
#  ('W0OO7050S', 7),
#  ('telescopes', 7),
#  ('telescopes-lunettes', 7),
#  ('W0OO7099S', 7),
#  ('tableware', 7),
#  ('01000000', 7),
#  ('setting-spray', 7),
#  ('wide-leather-belt-with-double-g-buckle-p-400593AP00T1000', 7),
#  ('terrariums', 7),
#  ('wallets', 7),
#  ('6936559', 7),
#  ('go-premium-x', 7),
#  ('product.knitted-t-shirt-orange.0851533008.html', 7),
#  ('librairie-bien-etre', 7),
#  ('self-tanning', 7),
#  ('c-hr', 7),
#  ('productpage.0954327001.html', 7),
#  ('tr', 7),
#  ('baseball-caps-for-men', 7),
#  ('productpage.0971350001.html', 7),
#  ('blemish-acne-treatment', 7),
#  ('multi-use', 7),
#  ('valentina-3-seater-clic-clac-corner-sofa-bed', 7),
#  ('product.wool-mix-relaxed-belted-coat-beige.0931564002.html', 7),
#  ('bb-cc-cream', 7),
#  ('product.asymmetric-knitted-wrap-dress-black.0961417001.html', 7),
#  ('par-nebulisation', 7),
#  ('sports', 7),
#  ('sports-app', 7),
#  ('mortgages', 7),
#  ('land-cruiser', 7),
#  ('matte-revolution-lipstick-MUK200024716.html', 7),
#  ('the-moisturizing-soft-cream-MUK200020072.html', 7),
#  ('damen-sale', 7),
#  ('real-time-traffic', 7),
#  ('476432KHNRN8642', 7),
#  ('t.l.c.-sukari-babyfacial-UK200028777.html', 7),
#  ('%EA%B0%80%EB%B0%A9', 7),
#  ('02000000', 7),
#  ('interlocking-g-pendant-necklace-p-455535J84000811', 7),
#  ('productpage.0928143001.html', 7),
#  ('rav4-promo-2', 7),
#  ('mens-wallets', 7),
#  ('hobo-bags-for-women', 7),
#  ('pierres-et-mineraux', 7),
#  ('en-fi', 7),
#  ('sa', 7),
#  ('%E6%88%90%E8%A1%A3', 7),
#  ('homeware', 7),
#  ('prescription-sunglasses', 7),
#  ('belts', 7),
#  ('lip-gloss', 7),
#  ('pojisteni', 7),
#  ('homes-and-gardens-subscription.thtml', 7),
#  ('ten-reasons-book', 7),
#  ('W0OO7104S', 7),
#  ('gourdes-termos', 7),
#  ('theieres-accessoires', 7),
#  ('kids-and-baby', 7),
#  ('all-kids', 7),
#  ('maintien-dos', 7),
#  ('stock', 6),
#  ('index_v31.asp', 6),
#  ('productpage.0954574001.html', 6),
#  ('fashion-necklaces', 6),
#  ('creme-de-la-mer-moisturizing-cream-UK200020070.html', 6),
#  ('chaussures', 6),
#  ('sylvie-medium-crocodile-top-handle-bag-p-431665EV4CG6473', 6),
#  ('product.checked-wool-dress-blue.0938341001.html', 6),
#  ('product.hooded-sweatshirt-dress-black.0925824005.html', 6),
#  ('paniers-piquenique', 6),
#  ('handwash', 6),
#  ('product.technical-curved-panel-sweatshirt-dress-green.0930686004.html', 6),
#  ('sweaters-cardigans-for-women', 6),
#  ('the-essential-box-for-her-MUK200029831.html', 6),
#  ('jeux-imagination-imitation', 6),
#  ('thes', 6),
#  ('product.gathered-shirt-dress-orange.0972080002.html', 6),
#  ('iphone-x-256-go-grigio-siderale-sbloccato-da-tutti-gli-operatori-miglior-prezzo',
#   6),
#  ('36834.html', 6),
#  ('haircare-sets', 6),
#  ('hair-sets', 6),
#  ('product.wool-teddy-fleece-coat-blue.0916512001.html', 6),
#  ('hair-oil', 6),
#  ('eclairage-exterieur', 6),
#  ('la-reunion', 6),
#  ('product.wool-mix-pea-coat-blue.0919405001.html', 6),
#  ('product.wool-hybrid-cardigan-grey.0936257001.html', 6),
#  ('socks-tights', 6),
#  ('product.long-knitted-vest-blue.0974178001.html', 6),
#  ('it-en', 6),
#  ('W0OO9440ODC', 6),
#  ('gg-marmont-matelasse-leather-super-mini-bag-p-476433DTDCT1000', 6),
#  ('kenzo-logo-sweatshirt', 6),
#  ('hello', 6),
#  ('iphone-accessories', 6),
#  ('fragrance-sets', 6),
#  ('yvelines', 6),
#  ('the-essential-box-for-her---international-MUK200029839.html', 6),
#  ('masseur-dos-cervical', 6),
#  ('productpage.0944619002.html', 6),
#  ('533-00312', 6),
#  ('W0OO4079', 6),
#  ('womens-ace-sneaker-with-bee-p-43194202JP09064', 6),
#  ('blusher', 6),
#  ('hoortoestellen', 6),
#  ('kinder-hausschuhe', 6),
#  ('essonne', 6),
#  ('lawn-and-garden', 6),
#  ('product.wrap-shirt-dress-beige.0973713002.html', 6),
#  ('corolla-hatchback', 6),
#  ('the-radiant-hydration-collection-MUK200028767.html', 6),
#  ('home', 6),
#  ('product.boxy-breton-striped-top-blue.0997258001.html', 6),
#  ('product.longline-quilted-coat-black.0928601006.html', 6),
#  ('icon-ring-with-gemstones-p-527095J8F778522', 6),
#  ('sacs-porte-epaule', 6),
#  ('highlights', 6),
#  ('6936509', 6),
#  ('guitarist-magazine-subscription.thtml', 6),
#  ('W0OO9384', 6),
#  ('en-tw', 6),
#  ('da_dk', 6),
#  ('marque', 6),
#  ('W0OO0036AC', 6),
#  ('FOF100189', 6),
#  ('product.oversized-denim-shirt-dress-blue.0974534002.html', 6),
#  ('essence', 6),
#  ('bain-douche', 6),
#  ('eu_fr', 6),
#  ('eure-et-loir', 6),
#  ('papeterie', 6),
#  ('p-8bt346abvlf0k7e', 6),
#  ('extracteurs-jus', 6),
#  ('%D1%82%D1%80%D0%B8%D0%BA%D0%BE%D1%82%D0%B0%D0%B6', 6),
#  ('decoration-murale', 6),
#  ('womens-hats-soft-accessories', 6),
#  ('product.oversized-cashmere-vest-grey.0950598002.html', 6),
#  ('W0OO9181R', 6),
#  ('W1OO9102A0L', 6),
#  ('mayenne', 6),
#  ('maglieria', 6),
#  ('scarves-for-men', 6),
#  ('sneakers-for-girls', 6),
#  ('%E7%B2%BE%E5%8D%8E%E6%B6%B2', 6),
#  ('lala-retro-whipped-cream-MUK200024529.html', 6),
#  ('productpage.0964564001.html', 6),
#  ('tisanes-infusions', 6),
#  ('live-services', 6),
#  ('card-holders-coin-cases-for-women', 6),
#  ('reliability-and-warranty', 6),
#  ('luxury-divan-base', 6),
#  ('neo-vintage-gg-supreme-messenger-bag-p-476466K9GVT8856', 6),
#  ('zaciname-podnikat', 6),
#  ('obsolete-products', 6),
#  ('fontaines', 6),
#  ('6936419', 6),
#  ('34207256', 6),
#  ('truck', 6),
#  ('11190', 6),
#  ('ch_de', 6),
#  ('bags-man', 6),
#  ('hats-soft-accessories', 6),
#  ('soins-corps', 6),
#  ('kenzo-logo-t-shirt', 6),
#  ('t-shirts-and-polo-shirts-for-men', 6),
#  ('furniture', 6),
#  ('hair-tools', 6),
#  ('bambini', 5),
#  ('sweatshirt-tigre', 5),
#  ('camicie', 5),
#  ('en-ro', 5),
#  ('gloves', 5),
#  ('aviator-sunglasses-for-men', 5),
#  ('womens-crossbody-bags', 5),
#  ('outerwear_cod16003752mq.html', 5),
#  ('serie', 5),
#  ('mantel-jacken', 5),
#  ('ucet-plus', 5),
#  ('%E6%B2%90%E6%B5%B4%E5%92%8C%E7%BE%8E%E4%BD%93', 5),
#  ('W0OO9009R', 5),
#  ('enfants-sneaker', 5),
#  ('abc-for-you-book-op492', 5),
#  ('vetyver-hand-scrub-MUK200020137.html', 5),
#  ('osobny-ucet', 5),
#  ('wilson-upholstered-ottoman-bed-frame', 5),
#  ('product.knitted-lambswool-top-green.0967702001.html', 5),
#  ('haute-marne', 5),
#  ('ten-little-yous-book', 5),
#  ('body-suncream', 5),
#  ('bouquet-parfume', 5),
#  ('product.gathered-midi-dress-black.0947458001.html', 5),
#  ('mobilier-jardin', 5),
#  ('productpage.0805942001.html', 5),
#  ('W0OO9451', 5),
#  ('product.straight-leg-chinos-beige.0978194001.html', 5),
#  ('product.belted-leather-dress-grey.0900509001.html', 5),
#  ('gucci-jordaan-leather-loafer-p-404069BLM001000', 5),
#  ('product.long-sleeved-merino-wool-top-black.0896359001.html', 5),
#  ('meuble', 5),
#  ('bag', 5),
#  ('rx', 5),
#  ('product.draped-cotton-shirt-dress-white.0967700002.html', 5),
#  ('en-sa', 5),
#  ('you-love-daddy-this-much-book', 5),
#  ('cardigans-for-women', 5),
#  ('product.knitted-tunic-shirt-beige.0961682001.html', 5),
#  ('product.fitted-leather-top-black.0977060001.html', 5),
#  ('kinder-outdoorschuhe', 5),
#  ('fr-ch', 5),
#  ('sport-schuhe', 5),
#  ('gallway-3-seater-clic-clac-sofa-bed', 5),
#  ('W0OO9401', 5),
#  ('productpage.0874952003.html', 5),
#  ('womens-small-wallets', 5),
#  ('productpage.0961968001.html', 5),
#  ('W0OO4124', 5),
#  ('socks-and-tights-for-women', 5),
#  ('plantes-atypiques', 5),
#  ('bath-body-set', 5),
#  ('bath-body-sets', 5),
#  ('original-gg-canvas-baseball-hat-with-web-p-200035KQWBG1060', 5),
#  ('fine-jewellery', 5),
#  ('hyaluronic-happikiss-MUK200029150.html', 5),
#  ('custom-slim-fit-soft-cotton-polo-shirt-505220.html', 5),
#  ('ropa', 5),
#  ('en-wx', 5),
#  ('W0OO9146PPE', 5),
#  ('yardley-upholstered-ottoman-bed-frame', 5),
#  ('mens-ties', 5),
#  ('flawless-fusion-ultra-longwear-concealer-MUK200020458.html', 5),
#  ('sleepwear', 5),
#  ('peinture-coloriage', 5),
#  ('canvas-tiger-espadrilles', 5),
#  ('sieges-massant', 5),
#  ('best-mum-ever-book', 5),
#  ('isas', 5),
#  ('W0OO9417', 5),
#  ('scarves-and-silks-for-women', 5),
#  ('productpage.0498629001.html', 5),
#  ('product.organic-cotton-oversized-sweatshirt-dress-pink.0918865002.html', 5),
#  ('oiseaux', 5),
#  ('boucles-oreille', 5),
#  ('if-you-were-a-book', 5),
#  ('product.boxy-sweatshirt-turquoise.0974242003.html', 5),
#  ('Proace Verso', 5),
#  ('elektronicke-bankovnictvo', 5),
#  ('business24', 5),
#  ('womens-folded-wallets', 5),
#  ('textile-accessories-woman', 5),
#  ('japan-exclusive-grip-watch-38mm-p-632060I86007010', 5),
#  ('antimoustiques', 5),
#  ('bougies-parfumees', 5),
#  ('accessori-tessili-donna', 5),
#  ('features-and-specs', 5),
#  ('gucci-guilty', 5),
#  ('travel-bags-for-men', 5),
#  ('hk-en', 5),
#  ('product.wrap-shirt-white.0970764002.html', 5),
#  ('en-lu', 5),
#  ('eye-sweatshirt', 5),
#  ('womens-card-cases-coin-cases', 5),
#  ('en-AU', 5),
#  ('livres-pour-parents', 5),
#  ('couteau-suisse-multifonction', 5),
#  ('iphone-8-256-go-productred-compatibile-con-tutti-gli-operatori-miglior-prezzo',
#   5),
#  ('129008.html', 5),
#  ('productpage.0948649001.html', 5),
#  ('W0OO9102R', 5),
#  ('bath-oils', 5),
#  ('product.regular-fit-t-shirt-grey.0753391023.html', 5),
#  ('FA62SW8244XA.99.L.html', 5),
#  ('lip-liner', 5),
#  ('%E7%9C%BC%E9%83%A8%E6%8A%A4%E7%90%86', 5),
#  ('%E7%9C%BC%E9%83%A8%E6%8A%A4%E7%90%86%E4%BA%A7%E5%93%81', 5),
#  ('W0OO9146RSI', 5),
#  ('iphone-x-64-go-grigio-siderale-sbloccato-da-tutti-gli-operatori-miglior-prezzo',
#   5),
#  ('36833.html', 5),
#  ('herren-slipper', 5),
#  ('kits-materiel-creatifs', 5),
#  ('product.parachute-skater-dress-black.0971659001.html', 5),
#  ('colourcollection', 5),
#  ('body-oil', 5),
#  ('doudous-peluches', 5),
#  ('slides-sandals', 5),
#  ('slides-for-men', 5),
#  ('product.boiled-wool-zip-up-jacket-black.0792636009.html', 5),
#  ('zh-tw', 5),
#  ('product.oversized-trench-coat-black.0891555002.html', 5),
#  ('puzzles', 5),
#  ('iphone-se-64-go-grigio-siderale-sbloccato-miglior-prezzo', 5),
#  ('10744.html', 5),
#  ('crossbody-and-belt-bags_cod45494425ek.html', 5),
#  ('bolsos', 5),
#  ('black-leather-biker-boots', 5),
#  ('34207496', 5),
#  ('tv-times-subscription.thtml', 5),
#  ('gg-marmont-small-matelasse-shoulder-bag-p-443497DTDIT1000', 5),
#  ('W0OO7046M', 5),
#  ('cosmetiques-maison', 5),
#  ('product.windbreaker-top-blue.0958182001.html', 5),
#  ('promenade-sortie', 5),
#  ('eveil-sensoriel', 5),
#  ('porteurs-chariots', 5),
#  ('product.boxy-sweatshirt-orange.0974242002.html', 5),
#  ('6936789', 5),
#  ('total-guitar-magazine-subscription.thtml', 5),
#  ('it_it', 5),
#  ('ophidia-gg-small-shoulder-bag-p-5981259IK3T8745', 5),
#  ('amenagement-jardin', 5),
#  ('jeux-adresse', 5),
#  ('6936439', 5),
#  ('digital-photographer-magazine-subscription.thtml', 5),
#  ('W0OO9343', 5),
#  ('petit-morphee-box-meditation-enfant-30168290', 5),
#  ('hats-gloves-for-women', 5),
#  ('peekaboo', 5),
#  ('autres-jouets-eveil', 5),
#  ('%E9%9D%A2%E8%86%9C', 5),
#  ('W0OO4142', 5),
#  ('product.padded-hooded-cape-green.0964696001.html', 5),
#  ('special-daughter-birthday-card', 5),
#  ('165021', 5),
#  ('you-are-extraordinary-book', 5),
#  ('proace-verso', 5),
#  ('livingetc', 5),
#  ('livingetc.thtml', 5),
#  ('W0OO9417R', 5),
#  ('corolla-touring-sports', 5),
#  ('vie-pratique', 5),
#  ('girl-shoes-27-33', 5),
#  ('product.gathered-shirt-dress-black.0972080001.html', 5),
#  ('product.relaxed-ribbed-cardigan-black.0900573003.html', 5),
#  ('computer-music-magazine-subscription.thtml', 5),
#  ('W0OO9290R', 5),
#  ('W0OO9374', 5),
#  ('%E7%9C%BC%E9%83%A8', 5),
#  ('ophidia-gg-medium-tote-p-63168596IWB8745', 5),
#  ('product.regular-fit-t-shirt-orange-', 5),
#  ('-white.0753391025.html', 5),
#  ('casquette-coton-noire-a-logo-blanc-ahha21000kbla09.html', 5),
#  ('productpage.0922987008.html', 5),
#  ('ch_fr', 5),
#  ('mugs', 5),
#  ('product.straight-cropped-jeans-blue.0952527001.html', 5),
#  ('en-sk', 5),
#  ('belt-bags-for-men', 5),
#  ('6936709', 5),
#  ('prog-magazine-subscription.thtml', 5),
#  ('es-ES', 5),
#  ('found-my-friends-book', 5),
#  ('%E6%96%B0%E4%BD%9C', 5),
#  ('mens-hats-soft-accessories', 5),
#  ('mens-hats-gloves', 5),
#  ('W0OJ9001', 5),
#  ('vegane-produkte', 5),
#  ('6936539', 5),
#  ('gucci-horsebit-1955-mini-bag-p-6256150YK0G1000', 5),
#  ('fashion-rings', 5),
#  ('Hilux', 5),
#  ('the-feline-flick-eyeliner-MUK200024558.html', 4),
#  ('product.boxy-sweatshirt-white.0974242001.html', 4),
#  ('iberia', 4),
#  ('dry-shampoo', 4),
#  ('FB5COXIIMTRE.01.TU.html', 4),
#  ('product.leather-crossbody-bag-black.0969585001.html', 4),
#  ('RB3025%20UNISEX%20aviator%20classic-gold', 4),
#  ('product.wool-oversized-hoodie-grey.0946964001.html', 4),
#  ('FOF100136', 4),
#  ('product.striped-v-neck-vest-blue.0968280003.html', 4),
#  ('W0OO9182R', 4),
#  ('t-shirts-for-women', 4),
#  ('online-exclusive', 4),
#  ('outerwear-for-women', 4),
#  ('%E6%B2%90%E6%B5%B4%E9%9C%B2', 4),
#  ('lampe-veilleuse-galaxie-feerique-92061220', 4),
#  ('macbook-ricondizionato.html', 4),
#  ('t-shirts-polo-shirts-for-men', 4),
#  ('productpage.0975383001.html', 4),
#  ('cheek', 4),
#  ('productpage.0870530048.html', 4),
#  ('W0OO9308', 4),
#  ('mini-bags_cod45521299fg.html', 4),
#  ('abbigliamento-donna', 4),
#  ('W0OO9440FJ', 4),
#  ('product.a-line-cotton-dress-beige.0939721001.html', 4),
#  ('product.contrast-panel-shirt-beige.0984395002.html', 4),
#  ('iphone-8-64-go-productred-compatibile-con-tutti-gli-operatori-miglior-prezzo',
#   4),
#  ('127776.html', 4),
#  ('nails', 4),
#  ('W0OO4142SI', 4),
#  ('gemmae', 4),
#  ('RB3548N%20UNISEX%20hexagonal%20flat%20lenses-gold', 4),
#  ('product.merino-wool-roll-neck-zip-up-jacket-beige.0923872001.html', 4),
#  ('6936699', 4),
#  ('product.pull-on-barrel-trousers-blue.0958183001.html', 4),
#  ('product.high-waisted-barrel-jeans-blue.0969093003.html', 4),
#  ('product.long-sleeved-merino-wool-top-yellow.0896359009.html', 4),
#  ('chaise-fauteuil-canape', 4),
#  ('product.organic-cotton-straight-jeans-blue.0848210001.html', 4),
#  ('anti-stress', 4),
#  ('sparkling-swimsuit-with-gucci-logo-p-501899XJANM1082', 4),
#  ('mobile', 4),
#  ('15205', 4),
#  ('kleider', 4),
#  ('used-ford-mondeo', 4),
#  ('ateliers-box-sejours', 4),
#  ('box-sejours', 4),
#  ('lampe-en-cristal-de-sel-15131650', 4),
#  ('womens-gg-rhyton-sneaker-p-62018599WF04371', 4),
#  ('W0OO9424', 4),
#  ('veilleuse-tortue-aquatique-30148530', 4),
#  ('hats-and-gloves-for-women', 4),
#  ('en-es', 4),
#  ('customisecardsmobile_wc.aspx', 4),
#  ('musique-son', 4),
#  ('coffrets-cadeaux-beaute', 4),
#  ('coffrets-cadeaux-femme', 4),
#  ('denim-campaign', 4),
#  ('422407', 4),
#  ('renault', 4),
#  ('W0OO7103S', 4),
#  ('gg-canvas-fedora-p-5765874HG622564', 4),
#  ('gg-marmont-small-matelasse-shoulder-bag-p-447632DTD1T1000', 4),
#  ('%E8%B2%A1%E5%B8%83%EF%BC%86%E5%B0%8F%E7%89%A9-%E3%82%A6%E3%82%A3%E3%83%A1%E3%83%B3%E3%82%B9%E3%82%99',
#   4),
#  ('bolas', 4),
#  ('productpage.0668381001.html', 4),
#  ('product.leather-phone-pouch-beige.0809150006.html', 4),
#  ('accessoires-visage', 4),
#  ('long-sky-blue-dress-with-short-sleeves-frob22016kblu01.html', 4),
#  ('productpage.0872901001.html', 4),
#  ('WA494C', 4),
#  ('the-littles-kit-4.0-MUK200026691.html', 4),
#  ('borse-a-spalla', 4),
#  ('maquettes', 4),
#  ('borse-mini', 4),
#  ('en-hr', 4),
#  ('W0OO7116M', 4),
#  ('%E5%94%87%E9%83%A8', 4),
#  ('W0OO9301', 4),
#  ('99505', 4),
#  ('6936729', 4),
#  ('retro-gamer-magazine-subscription.thtml', 4),
#  ('used-ford-ecosport', 4),
#  ('hollywood-flawless-filter-MUK200024604.html', 4),
#  ('creme-de-la-mer-moisturizing-cream-UK200020044.html', 4),
#  ('productpage.0757903026.html', 4),
#  ('product.oversized-shirt-dress-turquoise.0984571002.html', 4),
#  ('product.teddy-zip-up-jacket-orange.0935368001.html', 4),
#  ('productpage.0812748001.html', 4),
#  ('product.patch-pocket-cardigan-green.0960249001.html', 4),
#  ('6936669', 4),
#  ('playstation-official-magazine-subscription.thtml', 4),
#  ('mathematiques', 4),
#  ('pf', 4),
#  ('W0OO9334', 4),
#  ('99470', 4),
#  ('boys-0-36m', 4),
#  ('portefeuilles-et-petits-accessoires', 4),
#  ('W0OO4123OSI', 4),
#  ('demande-essai', 4),
#  ('wellness', 4),
#  ('supplements', 4),
#  ('elefanten', 4),
#  ('lawnmowers', 4),
#  ('trousers-and-shorts-for-men', 4),
#  ('W0OO9438', 4),
#  ('biologie-geographie', 4),
#  ('decoration-exterieur', 4),
#  ('qa', 4),
#  ('black-rose-skin-infusion-cream-MUK200019244.html', 4),
#  ('sandals-for-girl', 4),
#  ('childrens-rubber-slides-with-web-p-503220GIB101098', 4),
#  ('capospalla-giacche', 4),
#  ('ecru-long-sleeved-lace-dress-frob21042kecr01.html', 4),
#  ('6745127', 4),
#  ('vanishing-deals-ricondizionato.html', 4),
#  ('leather-ankle-boot-with-belt-p-550036DKS001000', 4),
#  ('herren-schuhe-schnuerschuhe', 4),
#  ('ecologie-developpement-durable', 4),
#  ('cy', 4),
#  ('W0OO9271', 4),
#  ('34207731', 4),
#  ('wallpaper-subscription.thtml', 4),
#  ('skechers', 4),
#  ('product.cashmere-oversized-jumper-pink.0925862002.html', 4),
#  ('featherweight-mesh-shirt-470975.html', 4),
#  ('product.silk-regular-fit-t-shirt-green.0962760003.html', 4),
#  ('travel-bags', 4),
#  ('tote-bags', 4),
#  ('911498', 4),
#  ('stretch-cotton-trunk-3-pack-266853.html', 4),
#  ('productpage.0763988004.html', 4),
#  ('99474MP', 4),
#  ('en-it', 4),
#  ('p-8bs010afisf1e3l', 4),
#  ('product.organic-cotton-jersey-shirt-blue.0799941005.html', 4),
#  ('hommes', 4),
#  ('hommes-chaussures', 4),
#  ('tapis-eveil-arche', 4),
#  ('dresses-for-women', 4),
#  ('long-dresses-midi-dresses-for-women', 4),
#  ('sel-boules-bain', 4),
#  ('mazda', 4),
#  ('W0OO9421', 4),
#  ('product.chunky-leather-chelsea-boots-black.0946477001.html', 4),
#  ('868084', 4),
#  ('duffle-bags-for-men', 4),
#  ('jackets-for-men', 4),
#  ('articles-en-maille', 4),
#  ('soflens', 4),
#  ('product.boxy-long-sleeve-top-purple.0975879002.html', 4),
#  ('product.utility-style-denim-overshirt-turquoise.0918942002.html', 4),
#  ('what-kind-of-name-book', 4),
#  ('ties-for-men', 4),
#  ('animalier-leather-wallet-p-523664DJ20T1000', 4),
#  ('carnets', 4),
#  ('roadtrips', 4),
#  ('trip', 4),
#  ('productpage.0899885001.html', 4),
#  ('productpage.0924243002.html', 4),
#  ('product.cropped-knitted-jacket-brown.0950328007.html', 4),
#  ('W0OX3217', 4),
#  ('last-chance', 4),
#  ('iphone-xs-256-go-oro-sbloccato-miglior-prezzo', 4),
#  ('161655.html', 4),
#  ('productpage.0928133001.html', 4),
#  ('montres-de-luxe-femme-et-homme-fendi%3Cbr-%3E', 4),
#  ('categori%C3%A8s', 4),
#  ('coffret-detoximix-mini-2-bouteilles-15200110', 4),
#  ('W1OO9417A0L', 4),
#  ('34206691', 4),
#  ('W0OO9009', 4),
#  ('eye', 4),
#  ('pots-jardinieres', 4),
#  ('W0OO9144R', 4),
#  ('coffret-complet-decouverte-cyanotype-50170090', 4),
#  ('product.wrap-vest-top-green.0970710002.html', 4),
#  ('mens-low-top-sneakers', 4),
#  ('reviews', 4),
#  ('sandals_cod11746635wb.html', 4),
#  ('farbige-sneaker', 4),
#  ('W0OX8090', 4),
#  ('dionysus-gg-supreme-super-mini-bag-p-476432KHNRN8642', 4),
#  ('heart-bracelet-with-gucci-trademark-p-223513J84008106', 4),
#  ('womens-card-cases', 4),
#  ('jeux-memoire-observation', 4),
#  ('gg-marmont-mini-bucket-bag-p-575163DTDRT1000', 4),
#  ('product.longline-lambswool-cardigan-green.0947052001.html', 4),
#  ('dresses-for-girl', 4),
#  ('activewear-for-men', 4),
#  ('product.cropped-knitted-jacket-yellow.0950328005.html', 4),
#  ('p-fxq200a2npf17i9', 4),
#  ('black-leather-bag', 4),
#  ('99430', 4),
#  ('vetements-yoga', 4),
#  ('W0OO9008R', 4),
#  ('iphone-se-2020-64-go-nero-sbloccato-miglior-prezzo', 4),
#  ('347172.html', 4),
#  ('W0OO9448', 4),
#  ('mens-ace-embroidered-sneaker-p-42944602JP09064', 4),
#  ('apprendre-a-bien-manger', 4),
#  ('94263', 4),
#  ('protini-polypeptide-cream-MUK200021928.html', 4),
#  ('keychains-keycases-for-women', 4),
#  ('41487616', 4),
#  ('decanter-subscription.thtml', 4),
#  ('sweatshirt-kenzo-logo', 4),
#  ('productpage.0805946002.html', 4),
#  ('W0OO9442', 4),
#  ('product.round-neck-t-shirt-white.0164609001.html', 4),
#  ('0OJ9001CP', 4),
#  ('you-love-daddy-book', 4),
#  ('productpage.0864216017.html', 4),
#  ('features', 4),
#  ('masseur-pied', 4),
#  ('productpage.0894668003.html', 4),
#  ('productpage.0889901001.html', 4),
#  ('AYGO', 4),
#  ('luminotherapie', 4),
#  ('customise.aspx', 4),
#  ('productpage.0763988006.html', 4),
#  ('productpage.0668382003.html', 4),
#  ('repas-bebe', 4),
#  ('6022041DB0G9022', 4),
#  ('secours-et-survie', 4),
#  ('territoire-de-belfort', 4),
#  ('hair-serum', 4),
#  ('card-holders-and-coin-cases-for-men', 4),
#  ('autres', 4),
#  ('mydrive', 4),
#  ('product.pleated-shirt-dress-blue.0973697001.html', 4),
#  ('cs_cz', 4),
#  ('product.merino-yak-wool-mix-cable-knit-jumper-white.0924669001.html', 4),
#  ('W1OO4123A0L', 4),
#  ('rady-tipy', 4),
#  ('chelsea-boots', 4),
#  ('pantaloni', 4),
#  ('product.straight-belted-jumpsuit-green.0928250001.html', 4),
#  ('chemise-habillee-bleu-marine-a-volants-fccc19056knav01.html', 4),
#  ('dresses-and-skirts', 4),
#  ('best-husband-ever-book', 4),
#  ('sac-a-dos-mode', 4),
#  ('childrens-leather-double-g-belt-p-432707B960X1000', 4),
#  ('grip-watch-35mm-p-584272I86008740', 4),
#  ('W0OX3227', 4),
#  ('borse-donna', 4),
#  ('product.relaxed-hoodie-with-side-slits-orange.0856262008.html', 4),
#  ('cable-knit-cotton-jumper-559570.html', 4),
#  ('womens-tote-bags', 4),
#  ('productpage.0461935002.html', 4),
#  ('sweaters-and-cardigans-for-women', 4),
#  ('product.belted-wool-trench-coat-black.0916608001.html', 4),
#  ('pl_pl', 4),
#  ('home-studio', 4),
#  ('costa-rica', 4),
#  ('productpage.0685814001.html', 4),
#  ('girl-clothing-4-12-years', 4),
#  ('high-heel-sandals', 4),
#  ('%E3%83%8F%E3%82%99%E3%83%83%E3%82%AF%E3%82%99-%E3%82%A6%E3%82%A3%E3%83%A1%E3%83%B3%E3%82%B9%E3%82%99',
#   4),
#  ('product.voluminous-shirt-with-gathered-sleeves-black.0873234003.html', 4),
#  ('denim-for-men', 4),
#  ('jumelle-nikon-prostaff-10x42-75-0825-7-91298710', 4),
#  ('product.oversized-cashmere-vest-blue.0950598001.html', 4),
#  ('italy', 4),
#  ('vn', 4),
#  ('product.wrap-shirt-dress-grey.0973713001.html', 4),
#  ('product.relaxed-sweatshirt-dress-brown.0974792002.html', 4),
#  ('clothes-for-baby-girls', 4),
#  ('product.regular-fit-t-shirt-orange.0753391025.html', 4),
#  ('productpage.0820753001.html', 4),
#  ('W0OO9428', 4),
#  ('productpage.0924411001.html', 4),
#  ('astronomie-enfant', 4),
#  ('product.denim-chino-trousers-blue.0857497002.html', 4),
#  ('embroidered-leather-ankle-boot-with-belt-p-557735AYO101000', 4),
#  ('jeux-reflexe-adresse', 4),
#  ('body-treatment', 4),
#  ('body-treatments', 4),
#  ('01010000', 4),
#  ('0OO9102CP', 4),
#  ('%E6%8A%A4%E8%82%A4%E5%A5%97%E8%A3%85', 4),
#  ('kelly-classique-to-go-wallet-H080253CC89', 4),
#  ('product.wool-mix-shirt-dress-orange.0918069004.html', 4),
#  ('W0OO9295R', 4),
#  ('slingbacks_cod82673811910068.html', 4),
#  ('product.zip-up-puffer-vest-black.0774326001.html', 4),
#  ('FOA500015', 4),
#  ('W0OO9398', 4),
#  ('smartphone-ios-ricondizionato.html', 4),
#  ('accessori', 4),
#  ('es-mx', 4),
#  ('iphone-xr-128-go-bianco-sbloccato-da-tutti-gli-operatori-miglior-prezzo', 4),
#  ('198831.html', 4),
#  ('00002001617894', 4),
#  ('montres-pour-femme', 4),
#  ('shoulder-bag_cod45530862gr.html', 4),
#  ('mens-small-leather-goods', 4),
#  ('t-shirts-for-men', 4),
#  ('long-skirts-midi-skirts-for-women', 4),
#  ('productpage.0949864002.html', 4),
#  ('product.sheer-knitted-top-black.0970676001.html', 4),
#  ('W0OO9377', 4),
#  ('how-it-works-magazine-subscription.thtml', 4),
#  ('chairs-armchairs', 4),
#  ('%E7%B2%89', 4),
#  ('product.ribbed-collar-wool-alpaca-top-beige.0924913002.html', 4),
#  ('textile-accessories-man', 4),
#  ('productpage.0944900005.html', 4),
#  ('W0OO7112S', 4),
#  ('dionysus-gg-supreme-chain-wallet-p-401231KHNSN8642', 4),
#  ('product.relaxed-scuba-sweatshirt-brown.0959804003.html', 4),
#  ('Land Cruiser 150', 4),
#  ('co', 4),
#  ('product.washed-sweatshirt-green.0872666014.html', 4),
#  ('bronzer', 4),
#  ('productpage.0963087002.html', 4),
#  ('product.cowl-neck-long-sleeve-top-black.0973768002.html', 4),
#  ('soins', 4),
#  ('capospalla', 4),
#  ('auto', 4),
#  ('hochets-anneaux', 4),
#  ('martinique', 4),
#  ('W0OO9212R', 4),
#  ('product.wool-mix-fair-isle-knit-jumper-beige.0934573003.html', 4),
#  ('envelope-medium-bag-in-mix-matelasse-grain-de-poudre-embossed-leather-600185BOW921000.html',
#   3),
#  ('p-8br600af2vf1dsv', 3),
#  ('cotton-mesh-quarter-zip-jumper-446820.html', 3),
#  ('the-stars-and-the-sky-anniversary-card-made-for-each-other-photo-upload', 3),
#  ('134153', 3),
#  ('eyeliner-kajal', 3),
#  ('iphone-x%2Fxs-case', 3),
#  ('ken-scott-print-dionysus-small-shoulder-bag-p-400249UAG0N8464', 3),
#  ('W0OO9275', 3),
#  ('tiger-crest-jumper', 3),
#  ('productpage.0237347066.html', 3),
#  ('BS13025-11.html', 3),
#  ('product.sleeveless-knitted-top-blue.0973739005.html', 3),
#  ('jouets-tirer-pousser', 3),
#  ('productpage.0902388001.html', 3),
#  ('product.organic-cotton-tapered-leg-jeans-blue.0746272016.html', 3),
#  ('product.button-down-collar-shirt-blue.0833397005.html', 3),
#  ('damen-gummistiefel', 3),
#  ('product.relaxed-cotton-linen-trousers-blue.0721226009.html', 3),
#  ('ophidia-gg-small-shoulder-bag-p-499621K05NG8745', 3),
#  ('iphone-12-pro-max-case', 3),
#  ('product.corduroy-overshirt-blue.0979647001.html', 3),
#  ('jackie-1961-mini-shoulder-bag-p-63709110O0G1000', 3),
#  ('805289178323', 3),
#  ('polo-bear-fleece-sweatshirt-563874.html', 3),
#  ('oran-sandal-H202272Zv94350', 3),
#  ('oversized-kenzo-sport--triple-x--t-shirt', 3),
#  ('soins-jour', 3),
#  ('product.cotton-buttoned-bib-dress-brown.0900520001.html', 3),
#  ('customisepen.aspx', 3),
#  ('lippen', 3),
#  ('product.merino-wool-deep-v-neck-cardigan-black.0923909001.html', 3),
#  ('customisephotoblock.aspx', 3),
#  ('buttoned-placket-wool-turtleneck-567878.html', 3),
#  ('productpage.0964928007.html', 3),
#  ('nz', 3),
#  ('your-birthday-party-book', 3),
#  ('6936689', 3),
#  ('practical-motorhome-magazine-subscription.thtml', 3),
#  ('productpage.0928070002.html', 3),
#  ('classic-divan-base', 3),
#  ('kenzo-logo-pool-flip-flops', 3),
#  ('fimo-soft-white-modelling-clay-57g', 3),
#  ('565212-1022', 3),
#  ('purple-photo-upload-sympathy-card-heaven-in-your-home', 3),
#  ('139092', 3),
#  ('product.straight-loose-trousers-black-', 3),
#  ('-khaki-green.0967517003.html', 3),
#  ('%D1%80%D1%83%D0%B1%D0%B0%D1%88%D0%BA%D0%B8', 3),
#  ('polo-shirts-for-men', 3),
#  ('W1OO9408A0L', 3),
#  ('product.wool-mix-knitted-long-sleeve-bodysuit-white.0930954001.html', 3),
#  ('-tiger-sweatshirt', 3),
#  ('dionysus-leather-super-mini-bag-p-476432CAOGN8176', 3),
#  ('productpage.0685813037.html', 3),
#  ('g-timeless-watch-38mm-p-530236I16001402', 3),
#  ('product.relaxed-hoodie-with-side-slits-black.0856262007.html', 3),
#  ('W0OO7093S', 3),
#  ('hyaluronic-hydra-foundation-spf30-MUK200026358.html', 3),
#  ('product.leather-phone-pouch-orange.0809150003.html', 3),
#  ('nautical-polo-bear-jumper-563999.html', 3),
#  ('iphone-11-64-go-nero-sbloccato-miglior-prezzo', 3),
#  ('290057.html', 3),
#  ('productpage.0962556002.html', 3),
#  ('productpage.0691264001.html', 3),
#  ('eyebrows', 3),
#  ('productpage.0954586002.html', 3),
#  ('productpage.0948769003.html', 3),
#  ('base-top-coat', 3),
#  ('productpage.0938663010.html', 3),
#  ('1844005', 3),
#  ('FOA401554', 3),
#  ('6936329', 3),
#  ('3d-world-magazine-subscription.thtml', 3),
#  ('en-nz', 3),
#  ('purifiant', 3),
#  ('the-earth-polo-515240.html', 3),
#  ('W0OO9460', 3),
#  ('womens-zip-around-wallets', 3),
#  ('product.oversized-belted-wool-coat-black.0768687001.html', 3),
#  ('product.cropped-twill-trousers-grey.0961013001.html', 3),
#  ('mens-sweatshirts', 3),
#  ('samsung-galaxy-s9-64-go-viola-ultra-violet-compatibile-con-tutti-gli-operatori-miglior-prezzo',
#   3),
#  ('156677.html', 3),
#  ('womens-accessories', 3),
#  ('product.batwing-knitted-midi-dress-black.0947044001.html', 3),
#  ('outerwear-leather-jackets', 3),
#  ('chemises', 3),
#  ('julia-s-melody-box-zid9318480001', 3),
#  ('wool-hat-with-web-p-4297534G2061000', 3),
#  ('tapis-d-acupression-en-coton-et-lin-15215200', 3),
#  ('product.oversized-wool-mix-coat-grey.0836835002.html', 3),
#  ('mens-backpacks', 3),
#  ('backpacks-for-women', 3),
#  ('product.recycled-nylon-drawstring-swimsuit-yellow.0878402001.html', 3),
#  ('W0OO9144C', 3),
#  ('sandales-a-talons-hauts-argentees-lacees-afch22032ksil06.html', 3),
#  ('coffrets-the', 3),
#  ('product.leather-overshirt-black.0953932002.html', 3),
#  ('multi-photo-10-years-anniversary-card', 3),
#  ('153445', 3),
#  ('product.wool-moulded-bucket-hat-blue.0925733001.html', 3),
#  ('luxury-eye-palette-MUK200024565.html', 3),
#  ('makeup-removers', 3),
#  ('tech', 3),
#  ('dont-have-to-share-your-cake-personalised-card', 3),
#  ('169804', 3),
#  ('productpage.0954462007.html', 3),
#  ('productpage.0812789001.html', 3),
#  ('productpage.0861167003.html', 3),
#  ('product.high-neck-hemp-jacket-blue.0884831001.html', 3),
#  ('femmes-soldes', 3),
#  ('customisealcohol.aspx', 3),
#  ('product.short-sleeve-jumpsuit-black.0958181001.html', 3),
#  ('W1OO9416A0L', 3),
#  ('product.cable-knit-roll-neck-belted-vest-beige.0925923002.html', 3),
#  ('makeup-tools', 3),
#  ('womens-sneakers', 3),
#  ('%D1%81%D1%83%D0%BC%D0%BA%D0%B8', 3),
#  ('polo-cotton-oxford-cloth-mask-563254.html', 3),
#  ('kit-biere', 3),
#  ('blind-for-love-necklace-in-silver-p-455542J84000701', 3),
#  ('product.checked-wool-shirt-beige.0925786002.html', 3),
#  ('product.speckled-wool-silk-socks-blue.0656503014.html', 3),
#  ('W0OO9096R', 3),
#  ('15030', 3),
#  ('00002001965052', 3),
#  ('W0OO6042', 3),
#  ('best-dad-ever-book', 3),
#  ('chaussures-femme_3', 3),
#  ('iphone-xs-max-case', 3),
#  ('real-homes-magazine-subscription.thtml', 3),
#  ('W1OO4124A0L', 3),
#  ('calvi-verso-card-holder-H078476CKAF', 3),
# ...
#  ('MQ12523-46.html', 1),
#  ('collier-mars-calcedoine-bleue-71145840', 1),
#  ('eyelashes', 1),
#  ('eyelash-curler-UK200024495.html', 1),
#  ('colorblock-mohair-jumper', 1),
#  ('acquisto-canna-surfcasting-telescopica-italcanna-miura-112878.html', 1),
#  ('productpage.0954589001.html', 1),
#  ('wishing-you-a-speedy-recovery-card', 1),
#  ('120840', 1),
#  ('abacus-four-year-old-birthday-card-dinosaur-4th-birthday', 1),
#  ('129030', 1),
#  ('productpage.0337991010.html', 1),
#  ('productpage.0888331024.html', 1),
#  ('le-tilleul-24g77', 1),
#  ('bellevue-17g65011', 1),
#  ('slim-tapered-fit-polo-prepster-trouser-565505.html', 1),
#  ('heure-h-watch-strap-double-tour-26-x-26mm-short-W218ISWWK18', 1),
#  ('oak-effect-memory-box-frame-15cm-x-15cm', 1),
#  ('590539-1004', 1),
#  ('366-00822', 1),
#  ('34257816', 1),
#  ('womans-own-subscription.thtml', 1),
#  ('productpage.0727666002.html', 1),
#  ('product.oversized-shirt-dress-green.0970488002.html', 1),
#  ('skinny-stretchjeans-eldridge-553380.html', 1),
#  ('achat-turlutte-yo-zuri-aurie-q-rs-10cm-77600.html', 1),
#  ('productpage.0702368020.html', 1),
#  ('ma-petite-routine-97055580', 1),
#  ('backpack-202BPBRGB004.html', 1),
#  ('la-maison-bleue-35g11025', 1),
#  ('classic-stretch-cotton-trunk-3-pack-573845.html', 1),
#  ('44f45311-2efc-4046-981c-02bcec64d053', 1),
#  ('boat-shoes-211MZUCCLQ804.html', 1),
#  ('vol-en-helicoptere-a-la-rochelle', 1),
#  ('les-noisettes-42g3269', 1),
#  ('RX8415%20MALE%20rb8415-black', 1),
#  ('8053672358216', 1),
#  ('a-passioni-retinol-cream-MUK200029215.html', 1),
#  ('leather-briefcase-314291.html', 1),
#  ('fotocamera-nikon-ricondizionata.html', 1),
#  ('le-petit-pommier-22g122020', 1),
#  ('camicia-in-lino-e-madras-slim-fit-555581.html', 1),
#  ('productpage.0972616005.html', 1),
#  ('knitwear_cod48235090pg.html', 1),
#  ('sorro-gaina-64g152052', 1),
#  ('rayure-club-tie-H906211Tv07', 1),
#  ('chelsea-boots-noires-cuir-effet-vieilli-ahch21018kbla01.html', 1),
#  ('en-AE', 1),
#  ('les-embruns-50g568', 1),
#  ('achat-waders-sert-outlaw-bottes-caoutchouc-33611.html', 1),
#  ('danslatoile', 1),
#  ('200035KQWBG9791', 1),
#  ('linen-shirt-565494.html', 1),
#  ('t-shirts-polo-shirts-for-boys', 1),
#  ('baumwollpullover-mit-zopfmuster-509882.html', 1),
#  ('la-parrachee-73g287128', 1),
#  ('productpage.0870877001.html', 1),
#  ('au-jardin-27g880', 1),
#  ('productpage.0942840004.html', 1),
#  ('productpage.0628805001.html', 1),
#  ('qulabiry-chez-st-jean-64g142021', 1),
#  ('chargeurs-batterie', 1),
#  ('chargeur-nomade-6000mah-53149360', 1),
#  ('f67f1d4c-4d2d-401e-bdec-6de7566dc457', 1),
#  ('1445544', 1),
#  ('boathouse-29g30270', 1),
#  ('sandalias', 1),
#  ('sandalias-planas-cassandra-de-piel-lisa-con-logotipo-dorado-632446DWETT6023.html',
#   1),
#  ('pride-cotton-mesh-polo-shirt-3616413367738.html', 1),
#  ('product.lenzing%20-ecovero%20-oversized-parka-black.0935129001.html', 1),
#  ('%E9%A6%99%E6%B0%9B_cod62000537fd.html', 1),
#  ('especially-for-you-personalised-card', 1),
#  ('169780', 1),
#  ('dionysus-small-shoulder-bag-p-400249CAOGN8176', 1),
#  ('pantalon-en-crepe-imprime-palm-jungle-femme', 1),
#  ('BQ22225-57.html', 1),
#  ('product.relaxed-ribbed-cardigan-beige.0900573002.html', 1),
#  ('productpage.0955461001.html', 1),
#  ('villa-galli-89g429', 1),
#  ('achat-rallonge-kit-coupelle-garbolino-k2-r-pour-canne-au-coup-18683.html',
#   1),
#  ('purrfect-princess-yellow-dress-baby-pu', 1),
#  ('8848', 1),
#  ('product.padded-parka-green.0919186002.html', 1),
#  ('soutien-gorge-corbeille-berry-surprenante.html', 1),
#  ('W0OO9421R', 1),
#  ('80-s-vanity-bag-in-carre-quilted-grain-de-poudre-embossed-leather-649779DME271000.html',
#   1),
#  ('productpage.0911863002.html', 1),
#  ('productpage.0886347003.html', 1),
#  ('productpage.0884883002.html', 1),
#  ('sealy-avery-traditional-spring-mattress', 1),
#  ('115-00209', 1),
#  ('gite-la-croisette-74g193001', 1),
#  ('forty-multi-photo-card', 1),
#  ('155143', 1),
#  ('doudoune-glacier-chauffante-467690.html', 1),
#  ('childrens-gg-wool-cardigan-p-638323XKBNH4632', 1),
#  ('le-gite-de-conforgien-21g2064', 1),
#  ('295180', 1),
#  ('rock-n-kohl-eyeliner-MUK200024573.html', 1),
#  ('RB4210UNISEX007-wayfarerlightray-transparent', 1),
#  ('8053672301199', 1),
#  ('becky-tasche-mit-doppeltem-reissverschluss-aus-gestepptem--mattem-leder-6089411UQ031000.html',
#   1),
#  ('new-look-womens-dress-sewing-pattern-n6617', 1),
#  ('651632-1000', 1),
#  ('changing-bag-7vb00968ef0787', 1),
#  ('blouse-en-voile-jacquard-imprime-volutes-metallise-femme', 1),
#  ('BR13175-67-36.html', 1),
#  ('gite-du-coucou-h67g013592', 1),
#  ('single-handle-bags_cod31432202864704408.html', 1),
#  ('8053672977196', 1),
#  ('the-iconic-rugby-shirt-3616419543907.html', 1),
#  ('tee-shirt-blanc-casse-visuel-chatte-rockeuse-fille', 1),
#  ('XS10212-19.html', 1),
#  ('mojave-ghost-body-lotion-MUS300026168.html', 1),
#  ('442230B', 1),
#  ('chemise-leisure-fit-202ME6454008.html', 1),
#  ('productpage.0966458001.html', 1),
#  ('slim-fit-gingham-oxford-shirt-580994.html', 1),
#  ('product.stand-collar-wool-coat-blue.0768689003.html', 1),
#  ('leather-espadrille-sandal-p-573028BKO001000', 1),
#  ('the-face-illuminating-tan-drops-MUK200017364.html', 1),
#  ('les-tilleuls-73g190108', 1),
#  ('sunglasses_cod46695488ra.html', 1),
#  ('e28d7ddb-abb8-422a-b0ef-85a279f4cfb5', 1),
#  ('lecole-buissonniere-60g158', 1),
#  ('%E8%B4%AD%E7%89%A9%E8%A2%8B_cod45192759hh.html', 1),
#  ('pastel-designed-paper-pad-a4-16-sheets', 1),
#  ('650573-1005', 1),
#  ('revell-german-submarine-type-vii-c41-model-kit-172', 1),
#  ('646491-1000', 1),
#  ('lion-foil-engraving-kit-a4', 1),
#  ('606205-1009', 1),
#  ('스몰-사이즈-지갑_cod22009349ou.html', 1),
#  ('beauclair-63g63444', 1),
#  ('compra-carrete-dam-quick-5-fd-183112.html', 1),
#  ('leisure-fit-five-pocket-trousers-202M277PX2340.html', 1),
#  ('p-8br783af2ef1dsb', 1),
#  ('shampooing-ayurvedique-amla-volume-et-brillance-khadi.html', 1),
#  ('depart-en-vacances-the-rich-morning-show', 1),
#  ('productpage.0718777001.html', 1),
#  ('hohe-sandalen', 1),
#  ('la-16-pantoletten-aus-glattleder-und-nerz-650762E0E001000.html', 1),
#  ('productpage.0874704002.html', 1),
#  ('women-s-jacquard-shirt-with-frills-fccl20006kred01.html', 1),
#  ('miniatures-et-bijoux-de-sacs', 1),
#  ('p-7ar946afd5f1dzh', 1),
#  ('huawei-huawei-p30-128-go-arancione-amber-sunrise-compatibile-con-tutti-gli-operatori-miglior-prezzo',
#   1),
#  ('415155.html', 1),
#  ('masque-protecteur-nourrissant-peel-off-secrets-des-fees.html', 1),
#  ('versaya-73g54180', 1),
#  ('mascara-lavera.html', 1),
#  ('productpage.0921275002.html', 1),
#  ('productpage.0640021026.html', 1),
#  ('le-haut-cice-61g527', 1),
#  ('petite-maison-dans-la-vallee-22g521311', 1),
#  ('card-case_cod46729276rw.html', 1),
#  ('le-memise-74g279021', 1),
#  ('productpage.0858306003.html', 1),
#  ('280017', 1),
#  ('productpage.0916274001.html', 1),
#  ('524631A3N001000', 1),
#  ('product.lyocell-draped-capped-sleeve-top-white.0931623001.html', 1),
#  ('constance-belt-buckle-reversible-leather-strap-38mm-U_BELT_38_HOMMEpH074562CP2KpH077971CAAG080',
#   1),
#  ('292754', 1),
#  ('ceinture-jean-en-cuir-camel-clous-bijoux-femme', 1),
#  ('BS91025-61-T2.html', 1),
#  ('hp-compaq-elite-8300-core-i7-34-ghz-ssd-512-gb-ram-16-gb-miglior-prezzo', 1),
#  ('338287.html', 1),
#  ('clutch_cod45453575io.html', 1),
#  ('les-yeux-dans-les-yeux-le-respect-des-differences', 1),
#  ('productpage.0909345006.html', 1),
#  ('high-heel-pumps_cod2204324140577282.html', 1),
#  ('la-maison-du-cluzel-46g12688', 1),
#  ('achat-moulinet-fin-nor-bait-teaser-fs-216067.html', 1),
#  ('W0OX3142', 1),
#  ('le-chardonneret-74g33038', 1),
#  ('productpage.0935897002.html', 1),
#  ('le-gite-de-sencet-32g600270', 1),
#  ('b687b26e-0d8f-49f0-8c62-01990c6c7840', 1),
#  ('2212532', 1),
#  ('sweatshirt-black-cotton-sweatshirt', 1),
#  ('p-fy0178afrnf0gme', 1),
#  ('flickering-taper-led-candles-2-pack', 1),
#  ('643564-1000', 1),
#  ('00002001850888', 1),
#  ('Rieker*Damen*Schn%C3%BCrboot*Cognac.prod', 1),
#  ('productpage.0722151002.html', 1),
#  ('achat-station-browning-xi-box-30-superlight-200294.html', 1),
#  ('product.leather-hat-with-wide-brim-brown.0917324001.html', 1),
#  ('productpage.0923643001.html', 1),
#  ('les-glycines-26g256454', 1),
#  ('a0c5677e-16e7-431f-8914-455c338a3d8d', 1),
#  ('2836185', 1),
#  ('cintur%C3%B3n-de-piel-negra', 1),
#  ('p-7c0400a9xsf0r2a', 1),
#  ('6496364G0014178', 1),
#  ('clos-du-mont-rouge-h51h000489', 1),
#  ('baumwoll-t-shirt-mit-v-ausschnitt-3615734107368.html', 1),
#  ('productpage.0657394004.html', 1),
#  ('sac-de-jour-north-south-tote-in-grained-leather-480583DTI0E1112.html', 1),
#  ('productpage.0869766005.html', 1),
#  ('productpage.0845917004.html', 1),
#  ('productpage.0908897001.html', 1),
#  ('%ED%8B%B0%EC%85%94%EC%B8%A0_cod17957409490182907.html', 1),
#  ('buy-bait-bowl-browning-40585.html', 1),
#  ('productpage.0952231001.html', 1),
#  ('productpage.0763988003.html', 1),
#  ('t-shirts_cod3983529957800641.html', 1),
#  ('51e6e715-b4c5-43ee-8df7-20ba5d28b8b3', 1),
#  ('226911', 1),
#  ('카드-케이스_cod46729263ch.html', 1),
#  ('achat-trousse-a-accessoires-trakker-nxg-pva-pouch-147432.html', 1),
#  ('flat-sandals_cod2204324140586623.html', 1),
#  ('metallic-oberteil-mit-u-boot-ausschnitt-561006.html', 1),
#  ('daler-rowney-system-3-acrylic-starter-set', 1),
#  ('573050-1000', 1),
#  ('gite-du-domaine-de-laubertrie-33g4267', 1),
#  ('le-presbytere-35g131082', 1),
#  ('product.wool-mix-fair-isle-knit-jumper-blue.0934573001.html', 1),
#  ('gg-marmont-card-case-p-443127DTD1P5815', 1),
#  ('galahad-09g11009', 1),
#  ('product.merino-wool-line-detail-jumper-blue.0954166001.html', 1),
#  ('productpage.0936261001.html', 1),
#  ('womens-hobo-bags', 1),
#  ('achat-moulinet-casting-abu-garcia-black-max-130361.html', 1),
#  ('custom-fit-double-faced-chambray-shirt-3616419636074.html', 1),
#  ('la-laicite', 1),
#  ('outerwear-con-cintura-211M0PCL9450.html', 1),
#  ('mors-h-belt-buckle-reversible-leather-strap-24mm-U_BELT_24pH077922CC06pH052150CADY075',
#   1),
#  ('501-constance-vermillon-rouge-a-levres-mat-lipstick-p-6112349PL129501', 1),
#  ('W1OO9440A0L', 1),
#  ('anello_cod50249696wt.html', 1),
#  ('la-maison-bleue-68g5838', 1),
#  ('campille-66g112503', 1),
#  ('caramel-les-congeres-74g160060', 1),
#  ('productpage.0845917006.html', 1),
#  ('de-gaulle-et-le-soutien-sans-faille-de-sa-femme-1', 1),
#  ('portfolios-for-men', 1),
#  ('gg-black-mens-bag-p-495562K5RLN1095', 1),
#  ('FA62ES180F70.76.36.html', 1),
#  ('product.knitted-paper-dress-grey.0906060001.html', 1),
#  ('constance-belt-buckle-reversible-leather-strap-38mm-U_BELT_38_HOMMEpH074562CK05pH077971CAAL080',
#   1),
#  ('du-pre-59g3843', 1),
#  ('productpage.0907277009.html', 1),
#  ('coin-purses-card-cases_cod343549805755134.html', 1),
#  ('productpage.0944619001.html', 1),
#  ('nevada-cap-H201045Nv1159', 1),
#  ('gg-jacquard-shawl-p-5582743GC461088', 1),
#  ('productpage.0713922028.html', 1),
#  ('hippy-pink-by-lorena-canals-tapis-120x1-91476970', 1),
#  ('le-chataignier-30g12750', 1),
#  ('la-chappiniere-73g98137', 1),
#  ('product.cocoon-shape-joggers-black.0964690001.html', 1),
#  ('mouseloft-stitchlets-green-camper-van-cross-stitch-kit', 1),
#  ('572862-1070', 1),
#  ('productpage.0699923119.html', 1),
#  ('product.knitted-long-sleeve-polo-shirt-black.0907368001.html', 1),
#  ('sk-14649844119371742408,10', 1),
#  ('21', 1),
#  ('bon-repos-22g541709', 1),
#  ('productpage.0588422002.html', 1),
#  ('W0OY8010', 1),
#  ('liquitex-professional-matte-gel-237ml', 1),
#  ('634847-1000', 1),
#  ('go-5100-europe', 1),
#  ('W0OO7008M', 1),
#  ('productpage.0939948001.html', 1),
#  ('ndeg1-la-grande-periale-84g4092', 1),
#  ('%E3%83%AA%E3%83%B3%E3%82%B0_cod50249683vw.html', 1),
#  ('jean-droit-premier-483577.html', 1),
#  ('819e65d1-53e9-4a5d-9efd-94618e9125b5', 1),
#  ('126034', 1),
#  ('la-parenthese-normande-76g24015', 1),
#  ('p-7ar844aeugf1dgx', 1),
#  ('productpage.0589520013.html', 1),
#  ('la-renaissance', 1),
#  ('les-lauriers-31g101377', 1),
#  ('rico-aqua-confetti-baby-dream-dk-yarn-50g', 1),
#  ('622272-1004', 1),
#  ('W0OO7035SIAR', 1),
#  ('cotton-v-neck-jumper-521044.html', 1),
#  ('le-dotchu-73g6133', 1),
#  ('productpage.0801890001.html', 1),
#  ('waverly-high-rise-crop-jean-555364.html', 1),
#  ('down-anorak-coat-3616412862883.html', 1),
#  ('achat-bille-percee-sensas-verte-139759.html', 1),
#  ('lagrange-vacances-cap-green-sables-d-or-les-pins', 1),
#  ('L25401', 1),
#  ('productpage.0869142001.html', 1),
#  ('product.elasticated-barrel-leg-trousers-beige.0742719020.html', 1),
#  ('printed-black-shirt-with-classic-collar-hccl21005kbla92.html', 1),
#  ('%EB%8F%84%ED%81%90%EB%A8%BC%ED%8A%B8-%EC%BC%80%EC%9D%B4%EC%8A%A4_cod22009343oe.html',
#   1),
#  ('pantalons-et-shorts_cod13531811gu.html', 1),
#  ('productpage.0962960002.html', 1),
#  ('chemise-blanche-habillee-a-volants-fccc19056kwhi01.html', 1),
#  ('f9654e52-c126-4841-a456-62f6bde1f3aa', 1),
#  ('achat-leurre-souple-megabass-super-spindle-worm-4-10cm-par-6-155817.html',
#   1),
#  ('product.slim-fit-t-shirt-dusty-pink.0964339003.html', 1),
#  ('p-8n0178ac9lf0qvk', 1),
#  ('47908288', 1),
#  ('productpage.0878794004.html', 1),
#  ('sciences-explosives-15-experiences-92521760', 1),
#  ('schultertaschen_cod16494023980337055.html', 1),
#  ('qu-est-ce-que-ca-change-pour-un-pays-de-gagner-la-coupe-du-monde-de-foot',
#   1),
#  ('product.knitted-t-shirt-black.0851533013.html', 1),
#  ('productpage.0918042001.html', 1),
#  ('productpage.0843793004.html', 1),
#  ('other-accessories_cod25000123lw.html', 1),
#  ('ophidia-small-bucket-bag-p-610846CWG1G1060', 1),
#  ('du-marais-80g201115', 1),
#  ('id-637311876', 1),
#  ('barley-bear-happy-birthday-personalised-card', 1),
#  ('164433', 1),
#  ('gourde-en-aluminium-chullanka-05l-ro-92010140', 1),
#  ('star-wars-a-new-hope-brother-birthday-card', 1),
#  ('136968', 1),
#  ('productpage.0914951001.html', 1),
#  ('portique-axi-1-agres-wall-mount-91422130', 1),
#  ('productpage.0947540001.html', 1),
#  ('tenley-dinner-napkin-506574.html', 1),
#  ('product.fine-roll-neck-wool-top-orange.0145839020.html', 1),
#  ('gite-de-tambourin-40g10284', 1),
#  ('totes-for-women', 1),
#  ('padlock-small-gg-shoulder-bag-p-498156KHNKG9769', 1),
#  ('chaussures-a-plate-forme-8o7069nbkf0xa3', 1),
#  ('productpage.0536310001.html', 1),
#  ('surf-infusion-MUS300024984.html', 1),
#  ('le-cigalon-h12g006106', 1),
#  ('FA62TS8464YB.22.M.html', 1),
#  ('productpage.0579541104.html', 1),
#  ('productpage.0929667003.html', 1),
#  ('productpage.0930350002.html', 1),
#  ('productpage.0664647034.html', 1),
#  ('achat-protege-moulinet-spro-reel-protector-219192.html', 1),
#  ('veste-habillee-noire-a-rayures-grises-hves21006kbla96.html', 1),
#  ('cauhape-64g121073', 1),
#  ('la-cave-jo-11g2575', 1),
#  ('293849', 1),
#  ('productpage.0746518001.html', 1),
#  ('RB3561%20MALE%20general-silver', 1),
#  ('8056597314091', 1),
#  ('herbadetox-bio-aux-12-plantes-actives-91578270', 1),
#  ('mochila-211MBTHU356.html', 1),
#  ('lockdown-birthday-funny-card', 1),
#  ('176917', 1),
#  ('productpage.0955789001.html', 1),
#  ('himbeerfarbenes-herren-t-shirt-mit-v-ausschnitt', 1),
#  ('MQ10013-33-M.html', 1),
#  ('c-est-quoi-le-cyberharcelement', 1),
#  ('productpage.0937280002.html', 1),
#  ('product.recycled-glass-two-tone-pendant-necklace-white-', 1),
#  ('-orange.0926772001.html', 1),
#  ('productpage.0874547004.html', 1),
#  ('le-relais-perche-13g170538', 1),
#  ('productpage.0653275007.html', 1),
#  ('eye-brow', 1),
#  ('all-over-eye-brush-MUK200020436.html', 1),
#  ('shopping-bag-aus-schwarzem-leder-600306CSV0J1000.html', 1),
#  ('top-marine-bi-matiere-bord-cote-fantaisie-femme', 1),
#  ('BS11375-49.html', 1),
#  ('35g121272-35g121272', 1),
#  ('FOF100187', 1),
#  ('pa%C3%B1uelo-de-seda-lisa-537708.html', 1),
#  ('gite-spa-le-montagnard-05g5280', 1),
#  ('pro-collagen-marine-cream-spf-30-MUK200027004.html', 1),
#  ('indigo-dyed-cotton-watch-cap-500495.html', 1),
#  ('citrus-melange-body-cleanser-UK200027470.html', 1),
#  ('product.mulberry-silk-dressing-gown-red.0904889001.html', 1),
#  ('asus-zenbook-duo-ux481fl-bm044t-14-core-i7-18-ghz-ssd-512-gb-16gb-tastiera-spagnolo-miglior-prezzo',
#   1),
#  ('453212.html', 1),
#  ('productpage.0923592004.html', 1),
#  ('royal-belt-buckle-leather-strap-38mm-U_BELT_38_HOMMEpH075370CK05pH079639CA89085',
#   1),
#  ('productpage.0558514022.html', 1),
#  ('BQ12155-02-38.html', 1),
#  ('%E3%83%AA%E3%83%B3%E3%82%B0_cod50249696wt.html', 1),
#  ('aef2cf5b-ac74-42e3-8e08-18d8fe56285a', 1),
#  ('4103102', 1),
#  ('455d6b6e-6416-4617-afd0-94544d39b8be', 1),
#  ('medium-hair-shampoo-MUK200027208.html', 1)]

# %%
# Same for "Confirmation"

get_most_occurrent_path_chunks("Confirmation")
# Out:
# Number of different path chunks: 2702
# [('orderConfirmation', 2327),
#  ('checkout', 2267),
#  ('de_de', 717),
#  ('en_gb', 451),
#  ('en_us', 301),
#  ('on', 287),
#  ('demandware.store', 287),
#  ('nl_nl', 266),
#  ('MCheckout-ThankYouPage', 212),
#  ('sv_se', 159),
#  ('klarna', 125),
#  ('pl_pl', 118),
#  ('en_GB', 114),
#  ('Sites-en-GB-Site', 109),
#  ('confirmation', 109),
#  ('thankyou.aspx', 104),
#  ('en', 104),
#  ('us', 99),
#  ('carconfigurator', 81),
#  ('workflow', 81),
#  ('summary', 81),
#  ('store', 73),
#  ('confirmation.html', 73),
#  ('book', 62),
#  ('Sites-IKKS_COM-Site', 60),
#  ('COSummary-Confirmation', 59),
#  ('fr', 56),
#  ('ru_ru', 54),
#  ('de_at', 47),
#  ('join', 46),
#  ('complete', 46),
#  ('Checkout', 41),
#  ('Confirmation', 41),
#  ('uk', 40),
#  ('en_eur', 39),
#  ('en-us', 38),
#  ('Sites-en-US-Site', 34),
#  ('en_US', 34),
#  ('en_gbp', 33),
#  ('checkout-v2', 27),
#  ('finance_calculator', 27),
#  ('fc_workflow', 27),
#  ('quotation-completed', 27),
#  ('printOrderConfirmation', 25),
#  ('next', 23),
#  ('Sites-fr-FR-Site', 21),
#  ('fr_FR', 21),
#  ('Sites-de-DE-Site', 20),
#  ('de_DE', 20),
#  ('order', 18),
#  ('amend', 16),
#  ('downpayment', 16),
#  ('ja_jp', 15),
#  ('finalise.php', 15),
#  ('confirm', 15),
#  ('thankyou', 15),
#  ('index.php', 14),
#  ('en_usd', 13),
#  ('Corolla-HB', 12),
#  ('Yaris', 12),
#  ('au', 11),
#  ('en_au', 11),
#  ('Sites-spacenkgb-Site', 10),
#  ('FULL999', 10),
#  ('Sites-en-CA-Site', 10),
#  ('C-HR', 9),
#  ('mileage', 9),
#  ('booking', 9),
#  ('COSummary-ShowConfirmation', 8),
#  ('cancel', 8),
#  ('appointment-cancelled', 8),
#  ('en_dkk', 8),
#  ('DIGITAL799', 8),
#  ('ACM', 8),
#  ('de', 8),
#  ('en_CA', 8),
#  ('Sites-it-IT-Site', 8),
#  ('it_IT', 8),
#  ('RAV4', 7),
#  ('thank-you', 7),
#  ('es', 7),
#  ('Sites-pl-PL-Site', 7),
#  ('pl_PL', 7),
#  ('fr_fr', 7),
#  ('v3', 6),
#  ('success', 6),
#  ('AYGO', 6),
#  ('OnePageCheckout', 6),
#  ('ThankYou', 6),
#  ('brochures', 6),
#  ('email-thank-you', 6),
#  ('it_it', 6),
#  ('contact-us', 5),
#  ('FULL99', 5),
#  ('Hilux', 5),
#  ('en_sek', 5),
#  ('re', 5),
#  ('fr-fr', 5),
#  ('sales', 5),
#  ('view', 5),
#  ('order_id', 5),
#  ('corolla-ts', 5),
#  ('ae', 5),
#  ('zh_CN', 4),
#  ('bookingalreadydone', 4),
#  ('jp', 4),
#  ('ja', 4),
#  ('onepage', 4),
#  ('en_de', 4),
#  ('pd', 4),
#  ('en-gb', 4),
#  ('eu', 4),
#  ('en_eu', 4),
#  ('english', 4),
#  ('orderconfirm', 4),
#  ('de_ch', 3),
#  ('Proace', 3),
#  ('nl', 3),
#  ('alternateorderconfirmation', 3),
#  ('Adyen-AuthorizeWithForm', 3),
#  ('Mirai', 3),
#  ('kr', 3),
#  ('ko', 3),
#  ('fi_fi', 3),
#  ('Land Cruiser 150', 3),
#  ('COSummary-ConfirmationPage', 3),
#  ('nl-be', 2),
#  ('mytoyota-register', 2),
#  ('register', 2),
#  ('make-a-payment', 2),
#  ('gapInsuranceValue', 2),
#  ('su', 2),
#  ('fr_CA', 2),
#  ('Sites-IKKS_DE-Site', 2),
#  ('en_nok', 2),
#  ('Sites-RLEU_Sterling-Site', 2),
#  ('pf', 2),
#  ('Sites-nl-NL-Site', 2),
#  ('nl_NL', 2),
#  ('bromsgrove', 2),
#  ('Adyen-ShowConfirmation', 2),
#  ('cs_cz', 2),
#  ('en_IE', 2),
#  ('b02a1e09-5e2f-4628-8bb1-f1d4360e9f5d', 1),
#  ('31562522216', 1),
#  ('27451292494', 1),
#  ('5196726', 1),
#  ('18328127683', 1),
#  ('18349896983', 1),
#  ('922952810', 1),
#  ('18326255923', 1),
#  ('27407760104', 1),
#  ('26379344735', 1),
#  ('30758481400', 1),
#  ('30732160090', 1),
#  ('27389129094', 1),
#  ('30757734270', 1),
#  ('18326544443', 1),
#  ('30713910650', 1),
#  ('18346345473', 1),
#  ('18319280993', 1),
#  ('b1878960-b9d6-4ad3-ad9b-7bea5913f0b1', 1),
#  ('30764333960', 1),
#  ('27442152164', 1),
#  ('888H531479', 1),
#  ('27458189704', 1),
#  ('27441260464', 1),
#  ('30718078010', 1),
#  ('923108940', 1),
#  ('30761765320', 1),
#  ('US46092481', 1),
#  ('R465120504', 1),
#  ('26408626335', 1),
#  ('27426168624', 1),
#  ('924300590', 1),
#  ('27426537484', 1),
#  ('30742780900', 1),
#  ('0f0f840d-f5fc-406d-b2e6-ae3de12979b6', 1),
#  ('31554446156', 1),
#  ('31582246916', 1),
#  ('18313141613', 1),
#  ('30759651700', 1),
#  ('30406086901', 1),
#  ('27423269734', 1),
#  ('27372098584', 1),
#  ('es_es', 1),
#  ('31535956906', 1),
#  ('30731525360', 1),
#  ('31580163956', 1),
#  ('27413897794', 1),
#  ('18347870263', 1),
#  ('f33744f8e8d0eeca1ffe112c9c187786_cs_', 1),
#  ('27430664504', 1),
#  ('27418015524', 1),
#  ('27431772304', 1),
#  ('31586615416', 1),
#  ('27455387854', 1),
#  ('18319222193', 1),
#  ('30730416680', 1),
#  ('30723928150', 1),
#  ('18328583153', 1),
#  ('27372591644', 1),
#  ('923753090', 1),
#  ('27435981214', 1),
#  ('5191674', 1),
#  ('27412241014', 1),
#  ('27416114824', 1),
#  ('27462224024', 1),
#  ('18321327303', 1),
#  ('18347272343', 1),
#  ('27371250104', 1),
#  ('27427437964', 1),
#  ('27398617814', 1),
#  ('1310989036', 1),
#  ('31539004036', 1),
#  ('5196091', 1),
#  ('H00212404390', 1),
#  ('27442964754', 1),
#  ('27433433084', 1),
#  ('30723851260', 1),
#  ('df8d0363-2f39-47ba-b60d-c1d5faae9cc8', 1),
#  ('27386760194', 1),
#  ('R562389939', 1),
#  ('27398542814', 1),
#  ('31549030546', 1),
#  ('30713584170', 1),
#  ('27408541754', 1),
#  ('27451487314', 1),
#  ('27423617354', 1),
#  ('26392709575', 1),
#  ('CH', 1),
#  ('shop', 1),
#  ('op', 1),
#  ('confirmationPage.html', 1),
#  ('30673886870', 1),
#  ('27456727744', 1),
#  ('31599399656', 1),
#  ('924123460', 1),
#  ('18348890093', 1),
#  ('26404593755', 1),
#  ('27457900244', 1),
#  ('30710890370', 1),
#  ('30711071100', 1),
#  ('27458510594', 1),
#  ('18338993073', 1),
#  ('31539347126', 1),
#  ('R329210797', 1),
#  ('2f05ad4b90daafc2556d9d0ac3342530_cs_', 1),
#  ('27423610754', 1),
#  ('31555416046', 1),
#  ('31523649926', 1),
#  ('16067003142', 1),
#  ('27431660224', 1),
#  ('30724069230', 1),
#  ('31599349816', 1),
#  ('5192844', 1),
#  ('30374931261', 1),
#  ('18324531173', 1),
#  ('30739152010', 1),
#  ('31546555216', 1),
#  ('27418006704', 1),
#  ('31580671146', 1),
#  ('30721301910', 1),
#  ('30716751360', 1),
#  ('27409318264', 1),
#  ('27371573044', 1),
#  ('27418543204', 1),
#  ('26384332095', 1),
#  ('30749888200', 1),
#  ('30733509560', 1),
#  ('31597766246', 1),
#  ('18330086573', 1),
#  ('27432362764', 1),
#  ('27370564604', 1),
#  ('27412369104', 1),
#  ('30699286480', 1),
#  ('26395223465', 1),
#  ('30706882660', 1),
#  ('31567588966', 1),
#  ('27420846634', 1),
#  ('b826419c-1b44-41d0-b22b-4ec5d8571975', 1),
#  ('18319009413', 1),
#  ('27404038704', 1),
#  ('31547906586', 1),
#  ('27413977524', 1),
#  ('wimbledon', 1),
#  ('31524325806', 1),
#  ('30718309860', 1),
#  ('30701762730', 1),
#  ('27370247484', 1),
#  ('27415360464', 1),
#  ('26398950795', 1),
#  ('31585382746', 1),
#  ('R253720449', 1),
#  ('30711700500', 1),
#  ('30725260520', 1),
#  ('31548036636', 1),
#  ('924260860', 1),
#  ('no_no', 1),
#  ('27384639724', 1),
#  ('18350055693', 1),
#  ('924123970', 1),
#  ('27404487594', 1),
#  ('30718924160', 1),
#  ('26410733245', 1),
#  ('30763147880', 1),
#  ('30730377260', 1),
#  ('30734445400', 1),
#  ('30723140620', 1),
#  ('30722472530', 1),
#  ('27397584664', 1),
#  ('18251891993', 1),
#  ('26378862495', 1),
#  ('27464112194', 1),
#  ('27463862204', 1),
#  ('30737181250', 1),
#  ('18321254593', 1),
#  ('30369060801', 1),
#  ('27460048144', 1),
#  ('31550958706', 1),
#  ('31598873306', 1),
#  ('922971570', 1),
#  ('27438292234', 1),
#  ('27457209604', 1),
#  ('31600508816', 1),
#  ('27398059224', 1),
#  ('27445423594', 1),
#  ('924012700', 1),
#  ('31574015606', 1),
#  ('27425136654', 1),
#  ('27370446884', 1),
#  ('31557787046', 1),
#  ('27453636894', 1),
#  ('30733965900', 1),
#  ('30749965330', 1),
#  ('74a17cbea3cb2149de519c0488d0eee6_cs_', 1),
#  ('924010860', 1),
#  ('18347331223', 1),
#  ('30753887640', 1),
#  ('27422198444', 1),
#  ('31584909036', 1),
#  ('18344135733', 1),
#  ('18322557053', 1),
#  ('30703784230', 1),
#  ('4e6f5689c30ccb5f634b62a594b39db5_cs_', 1),
#  ('27457676274', 1),
#  ('27430803094', 1),
#  ('dudley', 1),
#  ('26401226515', 1),
#  ('27407623784', 1),
#  ('7b7adc35-7cbc-4f8c-a7c3-1c05e7d33d0f', 1),
#  ('27392566554', 1),
#  ('27395281654', 1),
#  ('19606918', 1),
#  ('18349432203', 1),
#  ('18339787373', 1),
#  ('31601627736', 1),
#  ('923588980', 1),
#  ('30716288300', 1),
#  ('8d0cb4b6-b4f7-4625-9304-c5cc382078f7', 1),
#  ('923716290', 1),
#  ('27407139984', 1),
#  ('18327154223', 1),
#  ('27418206014', 1),
#  ('30710920530', 1),
#  ('30750744860', 1),
#  ('18336435203', 1),
#  ('27458835544', 1),
#  ('27430118224', 1),
#  ('27403991484', 1),
#  ('31600457136', 1),
#  ('27429945924', 1),
#  ('30756369630', 1),
#  ('18338914593', 1),
#  ('1709458', 1),
#  ('923150640', 1),
#  ('27436456384', 1),
#  ('18319600693', 1),
#  ('30753421630', 1),
#  ('27388597794', 1),
#  ('30744068770', 1),
#  ('31572628666', 1),
#  ('18340164983', 1),
#  ('923653430', 1),
#  ('18341978263', 1),
#  ('30761711090', 1),
#  ('924384320', 1),
#  ('27449253544', 1),
#  ('30760271410', 1),
#  ('30359653661', 1),
#  ('31588270636', 1),
#  ('30703980100', 1),
#  ('31585687006', 1),
#  ('18348080183', 1),
#  ('basingstoke', 1),
#  ('spalding', 1),
#  ('924200770', 1),
#  ('8384c4c3-5ae3-4478-bb68-4def41023412', 1),
#  ('31548141016', 1),
#  ('27396136774', 1),
#  ('30370520471', 1),
#  ('26422126025', 1),
#  ('18327075483', 1),
#  ('27429154444', 1),
#  ('30705981170', 1),
#  ('31598364216', 1),
#  ('27431655354', 1),
#  ('31553174836', 1),
#  ('23aa0316-a545-44f5-81fa-cb8015aa608f', 1),
#  ('30733097790', 1),
#  ('18322594613', 1),
#  ('30764940820', 1),
#  ('31548341656', 1),
#  ('30707674560', 1),
#  ('US46097870', 1),
#  ('31550740856', 1),
#  ('18321341333', 1),
#  ('31557829516', 1),
#  ('27435718894', 1),
#  ('30750461030', 1),
#  ('27436178654', 1),
#  ('31584400206', 1),
#  ('31554468666', 1),
#  ('18325868643', 1),
#  ('28968a31-476d-4bfb-bcda-36296aa2c377', 1),
#  ('27405271074', 1),
#  ('18350643363', 1),
#  ('27420712904', 1),
#  ('1310989691', 1),
#  ('27383725734', 1),
#  ('27451605684', 1),
#  ('31569500076', 1),
#  ('27405036544', 1),
#  ('27371954924', 1),
#  ('26414798935', 1),
#  ('19606902%7CEUF', 1),
#  ('19606901', 1),
#  ('16050283702', 1),
#  ('18334916953', 1),
#  ('31546016566', 1),
#  ('30723162750', 1),
#  ('30382096171', 1),
#  ('27434907384', 1),
#  ('31591983566', 1),
#  ('30730160830', 1),
#  ('0b8db144565f8fd5ed9786f2c81e7497_cs_', 1),
#  ('27411220484', 1),
#  ('30743825260', 1),
#  ('27386027514', 1),
#  ('31595379936', 1),
#  ('bloxwich', 1),
#  ('31585507686', 1),
#  ('Sites-RalphLauren_GB-Site', 1),
#  ('31565167926', 1),
#  ('18333281593', 1),
#  ('bearwood', 1),
#  ('18333454273', 1),
#  ('31581006516', 1),
#  ('27434014224', 1),
#  ('18350094963', 1),
#  ('18326341943', 1),
#  ('27394010304', 1),
#  ('30753253980', 1),
#  ('27406862644', 1),
#  ('30749956590', 1),
#  ('30759440660', 1),
#  ('18342898353', 1),
#  ('30730559190', 1),
#  ('30703285310', 1),
#  ('924291890', 1),
#  ('26382399805', 1),
#  ('31580477526', 1),
#  ('27422329294', 1),
#  ('18320570303', 1),
#  ('31567562466', 1),
#  ('31576344706', 1),
#  ('923717470', 1),
#  ('31550524546', 1),
#  ('f4de4f1122c06e9adc4abe06463749ea_cs_', 1),
#  ('27370598944', 1),
#  ('27378956444', 1),
#  ('31580707596', 1),
#  ('H00212348875', 1),
#  ('18330405713', 1),
#  ('eu_en', 1),
#  ('30740274160', 1),
#  ('18333905673', 1),
#  ('US46092232', 1),
#  ('30331616521', 1),
#  ('27434261614', 1),
#  ('30732543290', 1),
#  ('27439361064', 1),
#  ('31572082416', 1),
#  ('31603234436', 1),
#  ('18346353573', 1),
#  ('27453672244', 1),
#  ('923973710', 1),
#  ('27420763994', 1),
#  ('18343441333', 1),
#  ('30760161870', 1),
#  ('31604026176', 1),
#  ('31596686036', 1),
#  ('27373122534', 1),
#  ('b41c2afe-8449-46fd-9800-baabc8573ecc', 1),
#  ('30718658570', 1),
#  ('31544269816', 1),
#  ('18329771763', 1),
#  ('31581541256', 1),
#  ('31554611856', 1),
#  ('pontypool', 1),
#  ('31580953626', 1),
#  ('30731318240', 1),
#  ('18320043813', 1),
#  ('26400583225', 1),
#  ('31565022146', 1),
#  ('30732325130', 1),
#  ('18322686653', 1),
#  ('31582308006', 1),
#  ('31560829566', 1),
#  ('antrim', 1),
#  ('27439135624', 1),
#  ('923716360', 1),
#  ('923220040', 1),
#  ('27436627014', 1),
#  ('31585082076', 1),
#  ('27385796234', 1),
#  ('5197118', 1),
#  ('18350999383', 1),
#  ('30738860540', 1),
#  ('ie', 1),
#  ('18339390893', 1),
#  ('30717536820', 1),
#  ('30715066000', 1),
#  ('27430299224', 1),
#  ('en_BE', 1),
#  ('922963080', 1),
#  ('27394288534', 1),
#  ('923084530', 1),
#  ('R602386954', 1),
#  ('30716409000', 1),
#  ('US46100072', 1),
#  ('924106320', 1),
#  ('16046479642', 1),
#  ('US46102150', 1),
#  ('27370845074', 1),
#  ('1310987867', 1),
#  ('16061816802', 1),
#  ('30751612460', 1),
#  ('27409044754', 1),
#  ('27461483314', 1),
#  ('27453413504', 1),
#  ('27411689234', 1),
#  ('31554165446', 1),
#  ('31579778836', 1),
#  ('GB46090231', 1),
#  ('27415468134', 1),
#  ('27418921924', 1),
#  ('18344245603', 1),
#  ('31563721816', 1),
#  ('27412557494', 1),
#  ('30753371970', 1),
#  ('31576017536', 1),
#  ('swadlincote', 1),
#  ('18324240783', 1),
#  ('27371308634', 1),
#  ('27436817444', 1),
#  ('18339970233', 1),
#  ('27455789374', 1),
#  ('30757406700', 1),
#  ('27420455094', 1),
#  ('923114840', 1),
#  ('27411756204', 1),
#  ('30754547220', 1),
#  ('27407354904', 1),
#  ('27438989904', 1),
#  ('blackheath', 1),
#  ('18339500873', 1),
#  ('18322784213', 1),
#  ('18346182683', 1),
#  ('78af5b27-43c7-481e-a09b-7fdc6dc0f400', 1),
#  ('27410514824', 1),
#  ('R224789436', 1),
#  ('27450877964', 1),
#  ('30715954880', 1),
#  ('27424726274', 1),
#  ('923747520', 1),
#  ('27426719834', 1),
#  ('30410286941', 1),
#  ('30762379970', 1),
#  ('27403592874', 1),
#  ('26400178975', 1),
#  ('30752636860', 1),
#  ('US46103935', 1),
#  ('30738536180', 1),
#  ('27393059174', 1),
#  ('30733905970', 1),
#  ('26413363915', 1),
#  ('widnes', 1),
#  ('18322977923', 1),
#  ('1310989648', 1),
#  ('27393540494', 1),
#  ('30400728681', 1),
#  ('b1d573e5-b17a-44a1-ad68-e355c041e9eb', 1),
#  ('923185290', 1),
#  ('ashford', 1),
#  ('18319252803', 1),
#  ('30360576631', 1),
#  ('5194581', 1),
#  ('30377747391', 1),
#  ('peterborough', 1),
#  ('18322936703', 1),
#  ('18346939513', 1),
#  ('30731748260', 1),
#  ('30709936820', 1),
#  ('18340003683', 1),
#  ('31571703086', 1),
#  ('27385139304', 1),
#  ('30739072410', 1),
#  ('27436876294', 1),
#  ('30394662591', 1),
#  ('27409512224', 1),
#  ('30741105530', 1),
#  ('1705758', 1),
#  ('30720035270', 1),
#  ('8c204bac-7b00-431d-bcc9-82716ef0c8e5', 1),
#  ('31595426516', 1),
#  ('31556740966', 1),
#  ('31563441216', 1),
#  ('27413373144', 1),
#  ('26398495395', 1),
#  ('30380066551', 1),
#  ('6c9b44f8ac13a58d25d2d8824826714e_cs_', 1),
#  ('31544624656', 1),
#  ('30729648000', 1),
#  ('30717751570', 1),
#  ('27452325424', 1),
#  ('27460736664', 1),
#  ('27423042164', 1),
#  ('31596691096', 1),
#  ('30694520280', 1),
#  ('18329253333', 1),
#  ('27383510874', 1),
#  ('30725592010', 1),
#  ('bathgate', 1),
#  ('30760142090', 1),
#  ('27393757154', 1),
#  ('27392965204', 1),
#  ('27443084044', 1),
#  ('27421113294', 1),
#  ('27403176424', 1),
#  ('27449996124', 1),
#  ('19608080', 1),
#  ('d1712d05-e02c-4c70-9997-1993ded1d1ee', 1),
#  ('a2979bdd-fb7d-47e3-9392-fe0fc1d099d7', 1),
#  ('123671', 1),
#  ('30749643180', 1),
#  ('18321614673', 1),
#  ('30751139490', 1),
#  ('31555952856', 1),
#  ('26405100425', 1),
#  ('31598416006', 1),
#  ('27454303124', 1),
#  ('31568847946', 1),
#  ('27452999664', 1),
#  ('27371016174', 1),
#  ('30761477280', 1),
#  ('18333364143', 1),
#  ('31547845956', 1),
#  ('26376591855', 1),
#  ('b1ced4df-77a2-4cf7-9a9d-78cfefbac54f', 1),
#  ('27406471094', 1),
#  ('18315542423', 1),
#  ('a0e30efe-cf9d-4163-84e4-2b7b6008c108', 1),
#  ('27424236844', 1),
#  ('30729250580', 1),
#  ('27382221784', 1),
#  ('27412307294', 1),
#  ('26409937995', 1),
#  ('27382513844', 1),
#  ('KR46101805', 1),
#  ('27436332894', 1),
#  ('31599422416', 1),
#  ('27407105114', 1),
#  ('27463785004', 1),
#  ('31586106886', 1),
#  ('27368436844', 1),
#  ('27387495824', 1),
#  ('386292e876dd2f6d61333ce125a8b269_cs_', 1),
#  ('09bd0f57-3dae-40fa-9ed4-1f4af812b7be', 1),
#  ('26388952625', 1),
#  ('27438074284', 1),
#  ('31576411596', 1),
#  ('26412406625', 1),
#  ('30720879680', 1),
#  ('18318018243', 1),
#  ('30711409990', 1),
#  ('31552931076', 1),
#  ('30760337980', 1),
#  ('27392908774', 1),
#  ('5191438', 1),
#  ('27431914994', 1),
#  ('27408109774', 1),
#  ('27407507624', 1),
#  ('30764663970', 1),
#  ('18320320003', 1),
#  ('31583197116', 1),
#  ('6740e891-e5a8-4fb5-980f-79e752d9d34d', 1),
#  ('26406901835', 1),
#  ('18329976683', 1),
#  ('30736271310', 1),
#  ('7bb5f74c-ef05-40e7-9ad4-ce9e8312ff32', 1),
#  ('31581331326', 1),
#  ('923957350', 1),
#  ('30718516590', 1),
#  ('27458478174', 1),
#  ('31579202396', 1),
#  ('31537240466', 1),
#  ('31575363716', 1),
#  ('30368331711', 1),
#  ('27398749514', 1),
#  ('1cda763a-f026-439c-ba8b-b38fad4fe303', 1),
#  ('18334607783', 1),
#  ('30759400590', 1),
#  ('31545042516', 1),
#  ('30736431220', 1),
#  ('103200', 1),
#  ('18327097463', 1),
#  ('18323430313', 1),
#  ('27406332844', 1),
#  ('27389268044', 1),
#  ('27411456204', 1),
#  ('27444838144', 1),
#  ('30721273300', 1),
#  ('31572954676', 1),
#  ('5192500', 1),
#  ('27370201264', 1),
#  ('31598381816', 1),
#  ('ead04ee9-fa27-4e91-983b-d8b0ec77fcfb', 1),
#  ('27387682274', 1),
#  ('924047150', 1),
#  ('30758182910', 1),
#  ('18325698253', 1),
#  ('31537516356', 1),
#  ('31554424946', 1),
#  ('31576225226', 1),
#  ('18318885163', 1),
#  ('18351560923', 1),
#  ('31600193526', 1),
#  ('31571610686', 1),
#  ('30762672120', 1),
#  ('bb4a5a42-b5ee-4256-a3f2-db137a625e4d', 1),
#  ('30761991780', 1),
#  ('31592186796', 1),
#  ('27462474334', 1),
#  ('27420581324', 1),
#  ('18350422333', 1),
#  ('30731410000', 1),
#  ('1c3f333e-7902-432e-85ac-8cc17daddca7', 1),
#  ('27436154624', 1),
#  ('27428892664', 1),
#  ('c97ef25c-0498-48c2-b9e3-fa4620bb0e1f', 1),
#  ('31586127936', 1),
#  ('30669177380', 1),
#  ('31564314286', 1),
#  ('27410397204', 1),
#  ('27441826824', 1),
#  ('27434370564', 1),
#  ('27386262134', 1),
#  ('27438488364', 1),
#  ('30399705271', 1),
#  ('18338735993', 1),
#  ('US46094842', 1),
#  ('31603663686', 1),
#  ('924027510', 1),
#  ('31568755976', 1),
#  ('31565986986', 1),
#  ('27421259074', 1),
#  ('18345945803', 1),
#  ('31563969846', 1),
#  ('31566526876', 1),
#  ('30753722950', 1),
#  ('31583853226', 1),
#  ('27370815524', 1),
#  ('30d2ca91652f78b8a727ae87d4c91848_cs_', 1),
#  ('26419885085', 1),
#  ('31552237426', 1),
#  ('27402916854', 1),
#  ('1708842', 1),
#  ('27433552644', 1),
#  ('31591844236', 1),
#  ('27410389584', 1),
#  ('d985e66d-2e46-49d8-87e3-b6e3c89acbd7', 1),
#  ('27459422654', 1),
#  ('31595807056', 1),
#  ('30753037880', 1),
#  ('31546565366', 1),
#  ('27424960674', 1),
#  ('18327876053', 1),
#  ('27439434084', 1),
#  ('US46102502', 1),
#  ('26401928575', 1),
#  ('923953970', 1),
#  ('27441184824', 1),
#  ('31584831376', 1),
#  ('31566642306', 1),
#  ('27416515404', 1),
#  ('18340359963', 1),
#  ('30762289560', 1),
#  ('27368142294', 1),
#  ('31564226386', 1),
#  ('27449105994', 1),
#  ('ab6cbc1c-0b19-4bce-8c7e-e7233a58dd24', 1),
#  ('31581714726', 1),
#  ('5196340', 1),
#  ('27387448324', 1),
#  ('30395122911', 1),
#  ('30757235380', 1),
#  ('18348699833', 1),
#  ('27408223614', 1),
#  ('26402569565', 1),
#  ('247299f03f77643b9be6cf1c4db422a3_cs_', 1),
#  ('27369874674', 1),
#  ('27361811684', 1),
#  ('924271800', 1),
#  ('R007186973', 1),
#  ('30359976101', 1),
#  ('27379661204', 1),
#  ('27431527654', 1),
#  ('30715178160', 1),
#  ('b46d6e9a-c1bf-4b86-a78b-4183460e2ddf', 1),
#  ('27461959414', 1),
#  ('27371430314', 1),
#  ('31538845276', 1),
#  ('27457804164', 1),
#  ('31600750296', 1),
#  ('5193670', 1),
#  ('27407216634', 1),
#  ('922941860', 1),
#  ('31600868926', 1),
#  ('GB46090960', 1),
#  ('27391889334', 1),
#  ('27373232864', 1),
#  ('blackwood', 1),
#  ('923237120', 1),
#  ('27383473584', 1),
#  ('18330146283', 1),
#  ('uk_en', 1),
#  ('26393569445', 1),
#  ('12bdc2bc-1998-4abb-aefc-8c3040ba0d5e', 1),
#  ('27382813674', 1),
#  ('de-at', 1),
#  ('fr-ca', 1),
#  ('R757097057', 1),
#  ('31569529476', 1),
#  ('31579336096', 1),
#  ('27384605164', 1),
#  ('18324226833', 1),
#  ('27368981054', 1),
#  ('f250829e-32f9-49f8-9f6d-06ab4e449520', 1),
#  ('31550744606', 1),
#  ('27423335974', 1),
#  ('31575760086', 1),
#  ('30729044100', 1),
#  ('18341694753', 1),
#  ('30760313750', 1),
#  ('30760107530', 1),
#  ('30727388360', 1),
#  ('1c94c87a-1499-4e85-b0cd-df4f856fab1e', 1),
#  ('18305398493', 1),
#  ('27422107814', 1),
#  ('31600991526', 1),
#  ('27405581214', 1),
#  ('30356056771', 1),
#  ('31562899836', 1),
#  ('30738042910', 1),
#  ('923790820', 1),
#  ('30738589380', 1),
#  ('30719665760', 1),
#  ('18350276003', 1),
#  ('5193278', 1),
#  ('18343536473', 1),
#  ('31567561396', 1),
#  ('26402677775', 1),
#  ('b0528165-879f-4992-a082-be5aa0defa9e', 1),
#  ('27378903034', 1),
#  ('31547241366', 1),
#  ('0b1c7015-f19c-42e3-88b2-626e2d675673', 1),
#  ('27406755804', 1),
#  ('923684780', 1),
#  ('31581072156', 1),
#  ('31562225966', 1),
#  ('4f718c16-e683-4d2f-b53c-2f058ac59774', 1),
#  ('30761839080', 1),
#  ('27398583904', 1),
#  ('27419441304', 1),
#  ('10397438', 1),
#  ('27458435674', 1),
#  ('31538678296', 1),
#  ('18342420513', 1),
#  ('923231400', 1),
#  ('30717220530', 1),
#  ('30740910060', 1),
#  ('GB46091974', 1),
#  ('30751280260', 1),
#  ('30409901901', 1),
#  ('923231200', 1),
#  ('18336714493', 1),
#  ('18340001483', 1),
#  ('27462915834', 1),
#  ('26398492265', 1),
#  ('26389827645', 1),
#  ('30391900411', 1),
#  ('27389325384', 1),
#  ('e9edbe1e-9dd5-4b53-b94f-10b470b07e51', 1),
#  ('31603096736', 1),
#  ('27432294894', 1),
#  ('1310990217', 1),
#  ('31566530206', 1),
#  ('18343326523', 1),
#  ('30753386980', 1),
#  ('18325635153', 1),
#  ('31577093796', 1),
#  ('27445686154', 1),
#  ('27421733514', 1),
#  ('18341018043', 1),
#  ('19608220%7CEUF', 1),
#  ('19608219', 1),
#  ('5192801', 1),
#  ('27431890364', 1),
#  ('30718979250', 1),
#  ('31537706106', 1),
#  ('18322957573', 1),
#  ('R811332711', 1),
#  ('27463808534', 1),
#  ('30753747660', 1),
#  ('18319837003', 1),
#  ('27415619084', 1),
#  ('27387840464', 1),
#  ('27380509004', 1),
#  ('26407246175', 1),
#  ('1707418', 1),
#  ('922982990', 1),
#  ('27411570994', 1),
#  ('27389830834', 1),
#  ('18343620653', 1),
#  ('18340897523', 1),
#  ('27413319974', 1),
#  ('H00212466550', 1),
#  ('30694054750', 1),
#  ('18328891503', 1),
#  ('16073697212', 1),
#  ('31582344776', 1),
#  ('18317827473', 1),
#  ('30720911850', 1),
#  ('26413648605', 1),
#  ('31584183266', 1),
#  ('612531b5-283d-43a3-a139-e52bad72c1d7', 1),
#  ('27379410724', 1),
#  ('18342961333', 1),
#  ('27441281894', 1),
#  ('30715737310', 1),
#  ('31578979636', 1),
#  ('31563795586', 1),
#  ('18313636713', 1),
#  ('27438927364', 1),
#  ('30750437860', 1),
#  ('27429899144', 1),
#  ('27430561274', 1),
#  ('27393329354', 1),
#  ('18348439713', 1),
#  ('18349226493', 1),
#  ('31546846246', 1),
#  ('31577239066', 1),
#  ('27389669184', 1),
#  ('18289361523', 1),
#  ('27462153574', 1),
#  ('31600342206', 1),
#  ('923980610', 1),
#  ('30734491190', 1),
#  ('27370841874', 1),
#  ('31584010846', 1),
#  ('31547969886', 1),
#  ('27414816334', 1),
#  ('30388177631', 1),
#  ('18351065163', 1),
#  ('27338730234', 1),
#  ('27464674044', 1),
#  ('27427072414', 1),
#  ('30742965680', 1),
#  ('18320497043', 1),
#  ('27456420914', 1),
#  ('27429609514', 1),
#  ('30742977840', 1),
#  ('27440840444', 1),
#  ('c11cd80489ac3cd4fe2c0ffc7a4836be_cs_', 1),
#  ('923096800', 1),
#  ('30740134740', 1),
#  ('18348531823', 1),
#  ('30740082630', 1),
#  ('27411816104', 1),
#  ('197eba96-d748-45ba-8a5c-15eb5e0f6f05', 1),
#  ('381b196bd44df364a15ed33b219a097c_cs_', 1),
#  ('10400670', 1),
#  ('30712671960', 1),
#  ('27387483934', 1),
#  ('27395296644', 1),
#  ('30749209730', 1),
#  ('27425066334', 1),
#  ('30719649230', 1),
#  ('31545293536', 1),
#  ('27378939884', 1),
#  ('27412548464', 1),
#  ('c282e61a209d89bd24a11fa5c1f6cdb3_cs_', 1),
#  ('27443727814', 1),
#  ('27437080584', 1),
#  ('31566573266', 1),
#  ('18345877943', 1),
#  ('31589990296', 1),
#  ('924054530', 1),
#  ('27413027914', 1),
#  ('gy', 1),
#  ('27397068894', 1),
#  ('30331515811', 1),
#  ('27404697024', 1),
#  ('31603241966', 1),
#  ('27446848244', 1),
#  ('30374585321', 1),
#  ('18329614863', 1),
#  ('5194951', 1),
#  ('31545982926', 1),
#  ('924007200', 1),
#  ('27383188894', 1),
#  ('27462837004', 1),
#  ('62760f5a-bf9c-4fcd-918d-4d64c83dcaa0', 1),
#  ('27397164434', 1),
#  ('30647671520', 1),
#  ('657861dd-f224-4a31-8f12-46d0ccdb1a46', 1),
#  ('922939340', 1),
#  ('27441355624', 1),
#  ('27396820534', 1),
#  ('6dba0e16-28ef-4527-aa27-3246a926aa07', 1),
#  ('1707471', 1),
#  ('30736264570', 1),
#  ('30729803640', 1),
#  ('30736652490', 1),
#  ('30397725311', 1),
#  ('32996dab-0e77-4a75-91cd-2635ff407770', 1),
#  ('30738307970', 1),
#  ('30366326681', 1),
#  ('27458595424', 1),
#  ('27427495584', 1),
#  ('27419298974', 1),
#  ('7c92fb34-e6e5-457a-be6a-f1f7184f11c9', 1),
#  ('27425394604', 1),
#  ('79b8ca64-ea39-4d3d-a523-7bcbb1d40eb0', 1),
#  ('30722842440', 1),
#  ('27459570944', 1),
#  ('30702113220', 1),
#  ('18348646943', 1),
#  ('27434532974', 1),
#  ('26379136175', 1),
#  ('30749082420', 1),
#  ('26422043265', 1),
#  ('18342079723', 1),
#  ('27430673074', 1),
#  ('4898b491-3a04-4f15-9a9f-0417a9dcf4ca', 1),
#  ('31563975746', 1),
#  ('Prius Plug-in Hybrid', 1),
#  ('18339946073', 1),
#  ('27406890924', 1),
#  ('27423425754', 1),
#  ('11441fd5-5228-48ec-ba72-a48281160f33', 1),
#  ('27372791874', 1),
#  ('27398482774', 1),
#  ('7e0eabf3-9243-4ca6-a9fe-38ab9e45ba11', 1),
#  ('30703697800', 1),
#  ('27388110044', 1),
#  ('27436240764', 1),
#  ('30702617520', 1),
#  ('R771247002', 1),
#  ('30718282550', 1),
#  ('27418167884', 1),
#  ('26414892515', 1),
#  ('30754665660', 1),
#  ('27431995474', 1),
#  ('923701140', 1),
#  ('30711870350', 1),
#  ('1707430', 1),
#  ('31569565936', 1),
#  ('27392682734', 1),
#  ('923776770', 1),
#  ('27453453794', 1),
#  ('27439849414', 1),
#  ('30703279170', 1),
#  ('923931470', 1),
#  ('27459645104', 1),
#  ('18342387603', 1),
#  ('923165250', 1),
#  ('27397884614', 1),
#  ('26381594725', 1),
#  ('31554243906', 1),
#  ('888T489745', 1),
#  ('27455219754', 1),
#  ('31585738896', 1),
#  ('30710905620', 1),
#  ('18327506913', 1),
#  ('26404414785', 1),
#  ('27370339544', 1),
#  ('18321881123', 1),
#  ('31569824356', 1),
#  ('27456692874', 1),
#  ('31589708526', 1),
#  ('31589246486', 1),
#  ('923117470', 1),
#  ('27419216014', 1),
#  ('18331415373', 1),
#  ('30724925840', 1),
#  ('27433696194', 1),
#  ('R016920407', 1),
#  ('26413681505', 1),
#  ('30754438000', 1),
#  ('30741431250', 1),
#  ('30698994760', 1),
#  ('5192066', 1),
#  ('31518285156', 1),
#  ('27418353574', 1),
#  ('923741350', 1),
#  ('18329346423', 1),
#  ('18322608173', 1),
#  ('27431222674', 1),
#  ('18318402383', 1),
#  ('31540221066', 1),
#  ('R983611548', 1),
#  ('923119120', 1),
#  ('27415892414', 1),
#  ('30730604640', 1),
#  ('26384655885', 1),
#  ('27386493884', 1),
#  ('923996110', 1),
#  ('18338939953', 1),
#  ('31579733476', 1),
#  ('30718365150', 1),
#  ('27379359414', 1),
#  ('30700805390', 1),
#  ('18321566763', 1),
#  ('27398818514', 1),
#  ('31549019506', 1),
#  ('923793620', 1),
#  ('ch_de', 1),
#  ('31564641236', 1),
#  ('18323899473', 1),
#  ('18329655653', 1),
#  ('27403818534', 1),
#  ('27324251374', 1),
#  ('31590890686', 1),
#  ('26422198735', 1),
#  ('18329010903', 1),
#  ('30757196700', 1),
#  ('27371488544', 1),
#  ('18338796313', 1),
#  ('31581972496', 1),
#  ('27394596534', 1),
#  ('27439173644', 1),
#  ('26398747125', 1),
#  ('18350595433', 1),
#  ('31554669986', 1),
#  ('923138040', 1),
#  ('27426301974', 1),
#  ('30764148810', 1),
#  ('27461470374', 1),
#  ('27442032874', 1),
#  ('30749004860', 1),
#  ('27368192794', 1),
#  ('27432539004', 1),
#  ('924330550', 1),
#  ('30759517950', 1),
#  ('27427160674', 1),
#  ('31589424786', 1),
#  ('27460426944', 1),
#  ('31573109596', 1),
#  ('27397111064', 1),
#  ('27417622324', 1),
#  ('27399910664', 1),
#  ('26381234365', 1),
#  ('R638102084', 1),
#  ('27421075864', 1),
#  ('27420079684', 1),
#  ('30724635840', 1),
#  ('27432403474', 1),
#  ('e1aecb83fbe79103ec5a7236fdfc2bbe_cs_', 1),
#  ('27391977864', 1),
#  ('27372479164', 1),
#  ('30702096110', 1),
#  ('27443052794', 1),
#  ('27458550504', 1),
#  ('27462501664', 1),
#  ('923774700', 1),
#  ('30723115940', 1),
#  ('31602203406', 1),
#  ('30743115260', 1),
#  ('30753326580', 1),
#  ('923104340', 1),
#  ('19607455', 1),
#  ('30735489450', 1),
#  ('31548400736', 1),
#  ('923634520', 1),
#  ('18334473103', 1),
#  ('922963010', 1),
#  ('923622510', 1),
#  ('31595895056', 1),
#  ('66941db1-05bf-417d-8d0c-6c2633b0e5b8', 1),
#  ('d5024dc62a3ae87470a90907093cecac_cs_', 1),
#  ('27455059464', 1),
#  ('27415561094', 1),
#  ('30759902940', 1),
#  ('18318410953', 1),
#  ('peterlee', 1),
#  ('924092630', 1),
#  ('923797970', 1),
#  ('31580830446', 1),
#  ('18327035493', 1),
#  ('27392144884', 1),
#  ('27436107474', 1),
#  ('30761056720', 1),
#  ('27412360634', 1),
#  ('27416658774', 1),
#  ('27404700234', 1),
#  ('18330113153', 1),
#  ('31568553286', 1),
#  ('31599641356', 1),
#  ('31543113096', 1),
#  ('31579473826', 1),
#  ('R754532431', 1),
#  ('30699446860', 1),
#  ('7317d97b-84fd-40f8-9f30-50603eaf7408', 1),
#  ('923205930', 1),
#  ('18339976873', 1),
#  ('27422927374', 1),
#  ('31576462746', 1),
#  ('923087140', 1),
#  ('27371599024', 1),
#  ('18342308483', 1),
#  ('27441395424', 1),
#  ('18313943083', 1),
#  ('6ae0f9fe-bc91-48c2-9f86-3d46eb049aa8', 1),
#  ('31586489066', 1),
#  ('27427816804', 1),
#  ('31586285056', 1),
#  ('31565266826', 1),
#  ('844123d4-a53c-4613-ae92-59e51bc7b7e6', 1),
#  ('largs', 1),
#  ('26402125355', 1),
#  ('27414659964', 1),
#  ('31548379816', 1),
#  ('27458975784', 1),
#  ('31603293856', 1),
#  ('27462930584', 1),
#  ('18349959083', 1),
#  ('27431206084', 1),
#  ('924007060', 1),
#  ('27373706244', 1),
#  ('888H529857', 1),
#  ('27414516294', 1),
#  ('27457921694', 1),
#  ('27447034054', 1),
#  ('27416395734', 1),
#  ('27461314304', 1),
#  ('18318411993', 1),
#  ('27373736844', 1),
#  ('5196454', 1),
#  ('30739633090', 1),
#  ('27384609824', 1),
#  ('US46092840', 1),
#  ('27417087584', 1),
#  ('27380713484', 1),
#  ('21d8f138-a0c8-429c-b967-76a17144f9c4', 1),
#  ('31556215316', 1),
#  ('30756519380', 1),
#  ('pocklington', 1),
#  ('27421497244', 1),
#  ('18349682063', 1),
#  ('27406417404', 1),
#  ('27405188234', 1),
#  ('26389932175', 1),
#  ('31558135396', 1),
#  ('18331765433', 1),
#  ('27395509214', 1),
#  ('31571882896', 1),
#  ('27399854144', 1),
#  ('18331561463', 1),
#  ('30751041690', 1),
#  ('30744325340', 1),
#  ('30721500350', 1),
#  ('27367708174', 1),
#  ('27458093454', 1),
#  ('30654037100', 1),
#  ('27452988674', 1),
#  ('27385293634', 1),
#  ('27372741644', 1),
#  ('27362066494', 1),
#  ('27387029494', 1),
#  ('beeston', 1),
#  ('18327135683', 1),
#  ('30739304670', 1),
#  ('31600476256', 1),
#  ('27436350194', 1),
#  ('30755850510', 1),
#  ('30713283810', 1),
#  ('31595650536', 1),
#  ('923361080', 1),
#  ('924038240', 1),
#  ('26412877695', 1),
#  ('e0254230-03d2-43ae-86e2-c962dd430ddb', 1),
#  ('lowestoft', 1),
#  ('923751180', 1),
#  ('31575908296', 1),
#  ('27441810084', 1),
#  ('30734579850', 1),
#  ('US46098866', 1),
#  ('158486', 1),
#  ('27440192654', 1),
#  ('30751383450', 1),
#  ('16071127522', 1),
#  ('30751468770', 1),
#  ('18331590013', 1),
#  ('30395907301', 1),
#  ('27393344804', 1),
#  ('30739296820', 1),
#  ('wembley', 1),
#  ('99c3b4f43398f364198c76d4539961ff_cs_', 1),
#  ('warminster', 1),
#  ('8227915d-59c2-4864-87dd-2a9678c39a7f', 1),
#  ('27396803634', 1),
#  ('30761649770', 1),
#  ('26377692065', 1),
#  ('27413876774', 1),
#  ('31586819896', 1),
#  ('30748277770', 1),
#  ('30738341570', 1),
#  ('coatbridge', 1),
#  ('30750370930', 1),
#  ('31553117506', 1),
#  ('c26bc876a802a4e3ce12c9f97a32615d_cs_', 1),
#  ('26415547095', 1),
#  ('27407397614', 1),
#  ('31561757316', 1),
#  ('19607755%7CEUF', 1),
#  ('19607754', 1),
#  ('30754600030', 1),
#  ('30338677211', 1),
#  ('musselburgh', 1),
#  ('26413483095', 1),
#  ('27408605754', 1),
#  ('923747010', 1),
#  ('27433955934', 1),
#  ('27447723664', 1),
#  ('31571954436', 1),
#  ('14da728e-9671-4dd0-b708-d2f9874cf893', 1),
#  ('18339036133', 1),
#  ('18350894513', 1),
#  ('27413564914', 1),
#  ('27378927514', 1),
#  ('18343727353', 1),
#  ('27405714524', 1),
#  ('newtonabbot', 1),
#  ('30752865710', 1),
#  ('27408279254', 1),
#  ('27408755554', 1),
#  ('30396709081', 1),
#  ('18348362053', 1),
#  ('1705580', 1),
#  ('27439621664', 1),
#  ('30717693320', 1),
#  ('31568443156', 1),
#  ('de-de', 1),
#  ('27371830634', 1),
#  ('18350644823', 1),
#  ('27437451854', 1),
#  ('18340477143', 1),
#  ('57cccb22-45ad-4eae-8da3-3d603d7a775a', 1),
#  ('27454458704', 1),
#  ('beec1ecb-01f9-466b-afae-fe10738fc195', 1),
#  ('27440608564', 1),
#  ('31586233036', 1),
#  ('30749328710', 1),
#  ('922593160', 1),
#  ('27426784634', 1),
#  ('27389467234', 1),
#  ('R802783428', 1),
#  ('30740225660', 1),
#  ('31597031216', 1),
#  ('31538059836', 1),
#  ('5196009', 1),
#  ('27439845314', 1),
#  ('26405180905', 1),
#  ('26404135105', 1),
#  ('5195242', 1),
#  ('1d433587-e052-4292-960e-6518289d455e', 1),
#  ('27393304914', 1),
#  ('30756992350', 1),
#  ('924120610', 1),
#  ('30731402890', 1),
#  ('26418031705', 1),
#  ('30754963300', 1),
#  ('18320512743', 1),
#  ('30353052761', 1),
#  ('30701257570', 1),
#  ('27436322304', 1),
#  ('31572534656', 1),
#  ('18327718953', 1),
#  ('27442951304', 1),
#  ('27457570444', 1),
#  ('31576019286', 1),
#  ('5193116', 1),
#  ('31548936936', 1),
#  ('31573985316', 1),
#  ('26381644775', 1),
#  ('27442705844', 1),
#  ('30724538230', 1),
#  ('30755304180', 1),
#  ('923938730', 1),
#  ('18342460373', 1),
#  ('27421466154', 1),
#  ('1310989346', 1),
#  ('30704074620', 1),
#  ('31600875576', 1),
#  ('30719503210', 1),
#  ('althorp', 1),
#  ('30740617860', 1),
#  ('30701863480', 1),
#  ('30744510780', 1),
#  ('27412015804', 1),
#  ('27409059284', 1),
#  ('30750937440', 1),
#  ('30755086240', 1),
#  ('27447368514', 1),
#  ('31602109376', 1),
#  ('27415565464', 1),
#  ('18349825913', 1),
#  ('18327885473', 1),
#  ('31573294606', 1),
#  ('30405907401', 1),
#  ('31603644266', 1),
#  ('27464271094', 1),
#  ('30740900970', 1),
#  ('18342716663', 1),
#  ('dccf4be4-fb35-4913-ae46-dfda4d0f0774', 1),
#  ('27386862704', 1),
#  ('27388321774', 1),
#  ('26415832125', 1),
#  ('27391602284', 1),
#  ('27395690184', 1),
#  ('27456189394', 1),
#  ('chesterfield', 1),
#  ('30711303170', 1),
#  ('27413867204', 1),
#  ('5195383', 1),
#  ('18329338543', 1),
#  ('27399044714', 1),
#  ('59e2741e-e21e-48fa-822b-32acd2fd529f', 1),
#  ('27436121514', 1),
#  ('30723260320', 1),
#  ('923618760', 1),
#  ('31584973086', 1),
#  ('30730049050', 1),
#  ('18338738063', 1),
#  ('31599360526', 1),
#  ('27460259024', 1),
#  ('30752572940', 1),
#  ('31554393716', 1),
#  ('30739939760', 1),
#  ('30741950250', 1),
#  ('27383948314', 1),
#  ('18344316293', 1),
#  ('18333182933', 1),
#  ('27393635784', 1),
#  ('30756527760', 1),
#  ('27385771284', 1),
#  ('en_SE', 1),
#  ('31547634896', 1),
#  ('30712668330', 1),
#  ('18338392723', 1),
#  ('31539346456', 1),
#  ('176487', 1),
#  ('27314744264', 1),
#  ('18348659963', 1),
#  ('30721043140', 1),
#  ('27413785134', 1),
#  ('31583837056', 1),
#  ('31538534876', 1),
#  ('27430985484', 1),
#  ('18330003993', 1),
#  ('18326742763', 1),
#  ('922944260', 1),
#  ('GB46085941', 1),
#  ('26387179645', 1),
#  ('923705000', 1),
#  ('30759690900', 1),
#  ('30752291910', 1),
#  ('31574952146', 1),
#  ('1709356', 1),
#  ('18330586773', 1),
#  ('27403017354', 1),
#  ('31545637026', 1),
#  ('suttoncoldfield', 1),
#  ('27452200904', 1),
#  ('clevedon', 1),
#  ('27415497174', 1),
#  ('923093370', 1),
#  ('26389073355', 1),
#  ('5191373', 1),
#  ('18339841663', 1),
#  ('27449249824', 1),
#  ('18330388183', 1),
#  ('27455977114', 1),
#  ('18340443593', 1),
#  ('923180970', 1),
#  ('18314466193', 1),
#  ('923936170', 1),
#  ('26412226845', 1),
#  ('30699464380', 1),
#  ('27443769514', 1),
#  ('27458269334', 1),
#  ('27437032514', 1),
#  ('59670ae1d3d77e62d31302a9f770babb_cs_', 1),
#  ('16f80fbb-bec6-4659-894b-e2d3740bce12', 1),
#  ('26398801525', 1),
#  ('27370819544', 1),
#  ('26421265565', 1),
#  ('27367622234', 1),
#  ('30764751340', 1),
#  ('30756800420', 1),
#  ('30739124730', 1),
#  ('31588760666', 1),
#  ('30758762890', 1),
#  ('31564830806', 1),
#  ('27390814864', 1),
#  ('31581562726', 1),
#  ('27459119444', 1),
#  ('27411590004', 1),
#  ('R870369797', 1),
#  ('27392235694', 1),
#  ('30732925040', 1),
#  ('16067915562', 1),
#  ('27408926654', 1),
#  ('18346112793', 1),
#  ('27407043614', 1),
#  ('newtownards', 1),
#  ('30754339930', 1),
#  ('27411425794', 1),
#  ('27420066114', 1),
#  ('26419849985', 1),
#  ('retford', 1),
#  ('30708979740', 1),
#  ('streatham', 1),
#  ('H00212410712', 1),
#  ('31555943886', 1),
#  ('f57ec999-6a67-44aa-8b78-6c60f55cd0e9', 1),
#  ('31535314476', 1),
#  ('30724484600', 1),
#  ('31548704256', 1),
#  ('5195818', 1),
#  ('31575202386', 1),
#  ('31564895826', 1),
#  ('18333883293', 1),
#  ('27391587464', 1),
#  ('31574346286', 1),
#  ('ashtonunderlyne', 1),
#  ('c0aedff1-5cef-46fc-948e-8714452802a2', 1),
#  ('922983580', 1),
#  ('27433374044', 1),
#  ('27373340484', 1),
#  ('26402638425', 1),
#  ('5192295', 1),
#  ('27405669064', 1),
#  ('30757306620', 1),
#  ('27435210264', 1),
#  ('27431912474', 1),
#  ('27383999934', 1),
#  ('31556836716', 1),
#  ('18337996243', 1),
#  ('26382584065', 1),
#  ('31599854966', 1),
#  ('27441918594', 1),
#  ('27449187604', 1),
#  ('5196093', 1),
#  ('27431149864', 1),
#  ('27417992574', 1),
#  ('27409911874', 1),
#  ('26419063845', 1),
#  ('30693539470', 1),
#  ('30757521530', 1),
#  ('26391589085', 1),
#  ('27418234984', 1),
#  ('27453053754', 1),
#  ('27384081384', 1),
#  ('30728657460', 1),
#  ('27435544174', 1),
#  ('R296952593', 1),
#  ('26396105775', 1),
#  ('0db1343b-e58f-4749-ae6e-ab974e16a23f', 1),
#  ('26420323235', 1),
#  ('27391499904', 1),
#  ('a73d5450b1fac18cecf17a5bb1c2df39_cs_', 1),
#  ('27465604514', 1),
#  ('923759660', 1),
#  ('31549491876', 1),
#  ('1310989175', 1),
#  ('31557049006', 1),
#  ('27393544954', 1),
#  ('27378938604', 1),
#  ('16047186342', 1),
#  ('27417116674', 1),
#  ('H00212434308', 1),
#  ('31583796286', 1),
#  ('79884013-dd69-453b-90d6-f0db84fe7ae6', 1),
#  ('18322236913', 1),
#  ('1310988126', 1),
#  ('31567096716', 1),
#  ('18336134883', 1),
#  ('19608662', 1),
#  ('30732811000', 1),
#  ('18332806773', 1),
#  ('6e01a933-b904-44b3-9487-828c3a62972f', 1),
#  ('27436080314', 1),
#  ('31597748306', 1),
#  ('31576309026', 1),
#  ('e2968c43-badb-49ab-b440-0d9c0c195bb2', 1),
#  ('d7aeb75b-f548-4181-9ea7-7f4af7d4309b', 1),
#  ('27371441214', 1),
#  ('27457338134', 1),
#  ('31547212756', 1),
#  ('31579742926', 1),
#  ('c9e65d62-daae-48df-a752-134e9dca0aa1', 1),
#  ('27407513634', 1),
#  ('1310988858', 1),
#  ('27402752874', 1),
#  ('27373772934', 1),
#  ('31584477956', 1),
#  ('18346629543', 1),
#  ('27458761914', 1),
#  ('30336816341', 1),
#  ('KR46094443', 1),
#  ('US46096894', 1),
#  ('30722596490', 1),
#  ('26407881545', 1),
#  ('27423500394', 1),
#  ('27440472684', 1),
#  ('f059c40b-b0af-40e7-8d4a-75eef5600989', 1),
#  ('31553811056', 1),
#  ('27440573824', 1),
#  ('30692370040', 1),
#  ('a168b21b-eec8-48cd-9980-8edf5df15cee', 1),
#  ('27461298064', 1),
#  ('18326543743', 1),
#  ('27457522174', 1),
#  ('31559106816', 1),
#  ('27452900804', 1),
#  ('31568186696', 1),
#  ('26400377885', 1),
#  ('31530839086', 1),
#  ('923740080', 1),
#  ('30718617360', 1),
#  ('30717954720', 1),
#  ('18329280103', 1),
#  ('08e74368-659e-4031-9881-208930fb0d08', 1),
#  ('30719727790', 1),
#  ('31549037866', 1),
#  ('18339679823', 1),
#  ('30743597930', 1),
#  ('30733993840', 1),
#  ('c07a80b7-d981-4164-9193-5da55a543beb', 1),
#  ('30739309900', 1),
#  ('R478072138', 1),
#  ('30365954021', 1),
#  ('30755288250', 1),
#  ('31558355416', 1),
#  ('30759152630', 1),
#  ('27411308464', 1),
#  ('27411892744', 1),
#  ('924075110', 1),
#  ('18329858063', 1),
#  ('31547242296', 1),
#  ('18321282663', 1),
#  ('H00212345506', 1),
#  ('27373433514', 1),
#  ('27411185084', 1),
#  ('5191244', 1),
#  ('27437455214', 1),
#  ('27383167224', 1),
#  ('26415304755', 1),
#  ('31566607376', 1),
#  ('30755757160', 1),
#  ('30395555571', 1),
#  ('27399548514', 1),
#  ('18318051953', 1),
#  ('27456623174', 1),
#  ('30760889480', 1),
#  ('4cda0ebc-07cc-4c36-935b-fd69010abefd', 1),
#  ('924008860', 1),
#  ('R075887982', 1),
#  ('30711884960', 1),
#  ('31601958266', 1),
#  ('30725121980', 1),
#  ('b4f9d5e5-bdb5-488f-8edd-da9dbcb1975a', 1),
#  ('27417999684', 1),
#  ('ec20377b-a978-4260-b266-5651f5ac476a', 1),
#  ('18344161013', 1),
#  ('31583579246', 1),
#  ('26378944725', 1),
#  ('31566153676', 1),
#  ('31575903176', 1),
#  ('s', 1),
#  ('ja-JP', 1),
#  ('Sites-en-SG-Site', 1),
#  ('en_SG', 1),
#  ('5191654', 1),
#  ('04c6b05b-88a6-479e-892e-a24a22537ab8', 1),
#  ('18348059843', 1),
#  ('27424152284', 1),
#  ('30737408490', 1),
#  ('31551282636', 1),
#  ('27405067334', 1),
#  ('31585261326', 1),
#  ('westwoodcrosssainsburys', 1),
#  ('31536072146', 1),
#  ('58dcf8b4-7bac-4c20-a9e7-c9d36b1135ea', 1),
#  ('27459925364', 1),
#  ('18346689333', 1),
#  ('31584399606', 1),
#  ('31548484176', 1),
#  ('31566404956', 1),
#  ('16051555332', 1),
#  ('26422347175', 1),
#  ('18328452643', 1),
#  ('27358124724', 1),
#  ('27373046814', 1),
#  ('27337428004', 1),
#  ('18350842963', 1),
#  ('27398331954', 1),
#  ('27460040244', 1),
#  ('b8962a12-c1ff-4410-a6bd-9acc130dc236', 1),
#  ('18337644703', 1),
#  ('27432467324', 1),
#  ('27368689004', 1),
#  ('30703963260', 1),
#  ('30733969720', 1),
#  ('18340027693', 1),
#  ('923612910', 1),
#  ('5190757', 1),
#  ('31553354926', 1),
#  ('30717366700', 1),
#  ('31572665226', 1),
#  ('26378750205', 1),
#  ('30720814480', 1),
#  ('18324382283', 1),
#  ('18331142113', 1),
#  ('4b1d7ad9-5cb6-42a1-b333-19506ae6a7d1', 1),
#  ('1277bca1-9dbd-4237-97b0-e73a8e58d6ed', 1),
#  ('31569193166', 1),
#  ('31548035096', 1),
#  ('31568686346', 1),
#  ('30708132590', 1),
#  ('30751707090', 1),
#  ('18314999783', 1),
#  ('31580660736', 1),
#  ('30743063680', 1),
#  ('27448515834', 1),
#  ('30743126270', 1),
#  ('30759891730', 1),
#  ('31599199286', 1),
#  ('924017610', 1),
#  ('26401878125', 1),
#  ('19b8dd31-275c-4355-886e-efb6a91b0d3c', 1),
#  ('924383330', 1),
#  ('1e52e699-5dc2-4dbf-a96c-0ca677870707', 1),
#  ('eastdereham', 1),
#  ('923593010', 1),
#  ('27405846344', 1),
#  ('30371561931', 1),
#  ('922939430', 1),
#  ('30749110980', 1),
#  ('8e5218ba-ddd7-46a8-b951-74ce7dfa5d39', 1),
#  ('27371707134', 1),
#  ('27425040794', 1),
#  ('923992540', 1),
#  ('1310988949', 1),
#  ('27395134944', 1),
#  ('30748149380', 1),
#  ('30738431630', 1),
#  ('30760802620', 1),
#  ('923188190', 1),
#  ('924002220', 1),
#  ('31565508126', 1),
#  ('27421853754', 1),
#  ('30737476510', 1),
#  ('ja_JP', 1),
#  ('a40cdd0d-1ce9-4f0d-ba14-7b2ddefa17ec', 1),
#  ('southport', 1),
#  ('31567930226', 1),
#  ('18345510533', 1),
#  ('26383588075', 1),
#  ('30752541350', 1),
#  ('18351374813', 1),
#  ('30716829540', 1),
#  ('31587741056', 1),
#  ('30721672460', 1),
#  ('27395944214', 1),
#  ('27394015964', 1),
#  ('31562685606', 1),
#  ('26410538045', 1),
#  ('1707859', 1),
#  ('3d1c6bd5-18f4-4f47-a3b5-cebea2bb4509', 1),
#  ('18345766683', 1),
#  ('e4c5196b-6641-4f06-aadf-b55ba60730b0', 1),
#  ('27418885434', 1),
#  ('923718470', 1),
#  ('31546242316', 1),
#  ('5195812', 1),
#  ('26420070455', 1),
#  ('fada670c-1fa8-4461-915b-3c75dd6d6cd1', 1),
#  ('31545664536', 1),
#  ('27438901894', 1),
#  ('30756101140', 1),
#  ('27386935294', 1),
#  ('3d478893-aa34-4134-93c3-5b900cbfc14d', 1),
#  ('30723715790', 1),
#  ('30756630950', 1),
#  ('27433288694', 1),
#  ('924106360', 1),
#  ('31583940616', 1),
#  ('30762266460', 1),
#  ('27432784664', 1),
#  ('27389091354', 1),
#  ('31538858896', 1),
#  ('bda6f0f8-6a79-40c4-b925-a9342c0abc0f', 1),
#  ('27453441844', 1),
#  ('27388610184', 1),
#  ('30744265490', 1),
#  ('30745933510', 1),
#  ('26388981115', 1),
#  ('16070139172', 1),
#  ('18340788003', 1),
#  ('30709750220', 1),
#  ('31551724256', 1),
#  ('18329462853', 1),
#  ('27385461014', 1),
#  ('79bca242-1c12-46d3-9279-b9dc670b6801', 1),
#  ('27454422784', 1),
#  ('18322761933', 1),
#  ('27413313394', 1),
#  ('30735505830', 1),
#  ('923217630', 1),
#  ('334f28d6-614b-43cd-8285-dfd2096ef634', 1),
#  ('30713656400', 1),
#  ('31602316146', 1),
#  ('26386452225', 1),
#  ('30756915270', 1),
#  ('27459219714', 1),
#  ('30735933680', 1),
#  ('30738195760', 1),
#  ('27372422704', 1),
#  ('18327384293', 1),
#  ('31595448316', 1),
#  ('27410250004', 1),
#  ('31565304846', 1),
#  ('27391778984', 1),
#  ('31544490186', 1),
#  ('31565766286', 1),
#  ('27445248224', 1),
#  ('923712080', 1),
#  ('27395871754', 1),
#  ('30744700320', 1),
#  ('27388133014', 1),
#  ('30366122281', 1),
#  ('31529139396', 1),
#  ('31576056656', 1),
#  ('31563424836', 1),
#  ('18329421323', 1),
#  ('31548114896', 1),
#  ('27402947504', 1),
#  ('18317198373', 1),
#  ('31568091686', 1),
#  ('adc5f9bb-437b-4766-ab53-5936a75e8718', 1),
#  ('27437466044', 1),
#  ('18339632503', 1),
#  ('27402502564', 1),
#  ('30365227031', 1),
#  ('30711506940', 1),
#  ('30701166640', 1),
#  ('a3bca94f-9b90-48e0-94af-597dfedeb775', 1),
#  ('31603058456', 1),
#  ('924373640', 1),
#  ('27440161024', 1),
#  ('923948110', 1),
#  ('1709578', 1),
#  ('27462161444', 1),
#  ('a59ee850-9775-41e2-83bb-8990127dd7fa', 1),
#  ('d0a93972-e16d-48cc-beac-ea9b13892999', 1),
#  ('27412175024', 1),
#  ('30692167240', 1),
#  ('26413643265', 1),
#  ('27461454304', 1),
#  ('9ebab41ce509c2b2507dbc83ada445e4_cs_', 1),
#  ('27407454044', 1),
#  ('31542055026', 1),
#  ('a1d44784-6496-418a-aac7-de1817619d7e', 1),
#  ('96940d96-03e2-4798-a7ff-2b4a0bfb6bc5', 1),
#  ('30723530500', 1),
#  ('18346367203', 1),
#  ('US46089891', 1),
#  ('27374471114', 1),
#  ('26401958045', 1),
#  ('18341107823', 1),
#  ('27409920714', 1),
#  ('27399771564', 1),
#  ('30721514550', 1),
#  ('27436715874', 1),
#  ('5193708', 1),
#  ('18323473583', 1),
#  ('27433046804', 1),
#  ('27420594004', 1),
#  ('30753102920', 1),
#  ('30744447960', 1),
#  ('18333601433', 1),
#  ('31583636606', 1),
#  ('31583529846', 1),
#  ('27436827334', 1),
#  ('31537939216', 1),
#  ('30736563300', 1),
#  ('30737430150', 1),
#  ('27406263204', 1),
#  ('27382273054', 1),
#  ('18316060353', 1),
#  ('30751656950', 1),
#  ('31604213406', 1),
#  ('cambridgefitzroystreet', 1),
#  ('haverhill', 1),
#  ('18331701373', 1),
#  ('18334269443', 1),
#  ('18326046553', 1),
#  ('30722580840', 1),
#  ('27412194994', 1),
#  ('18319527383', 1),
#  ('27441431864', 1),
#  ('30369348641', 1),
#  ('18327402973', 1),
#  ('30745470450', 1),
#  ('31561998106', 1),
#  ('30753945750', 1),
#  ('16071134122', 1),
#  ('1707997', 1),
#  ('27416511474', 1),
#  ('18319003783', 1),
#  ('1707498', 1),
#  ('30753572850', 1),
#  ('18344160183', 1),
#  ('31557576586', 1),
#  ('924272800', 1),
#  ('30712183350', 1),
#  ('27421511634', 1),
#  ('5195448', 1),
#  ('924025390', 1),
#  ('924221510', 1),
#  ('26399133475', 1),
#  ('30753090510', 1),
#  ('30749248610', 1),
#  ('30755615770', 1),
#  ('27436058954', 1),
#  ('27447326724', 1),
#  ('31575357216', 1),
#  ('R663923950', 1),
#  ('18343044313', 1),
#  ('27458783214', 1),
#  ('27417673804', 1),
#  ('31566658326', 1),
#  ('31563022746', 1),
#  ('27437910834', 1),
#  ('30701579360', 1),
#  ('27455068544', 1),
#  ('923624150', 1),
#  ('27463134364', 1),
#  ('27433967644', 1),
#  ('18344091853', 1),
#  ('27442500094', 1),
#  ('18345690213', 1),
#  ('8bca8fa4-d15c-4c7c-aff4-6c71597487c8', 1),
#  ('30722749820', 1),
#  ('27408729274', 1),
#  ('31570811696', 1),
#  ('H00212133588', 1),
#  ('27409528344', 1),
#  ('31596110636', 1),
#  ('27439022434', 1),
#  ('27421153324', 1),
#  ('27423272994', 1),
#  ('18323426243', 1),
#  ('27396549574', 1),
#  ('30724293000', 1),
#  ('18319250023', 1),
#  ('30760167630', 1),
#  ('1310991452', 1),
#  ('18338085213', 1),
#  ('30347823301', 1),
#  ('31585320146', 1),
#  ('30751123600', 1),
#  ('31597661646', 1),
#  ('30735807500', 1),
#  ('18331959013', 1),
#  ('5189bf85-bc92-40f3-b29f-a5edfd2ff5bf', 1),
#  ('18342197453', 1),
#  ('27454982024', 1),
#  ('27393747404', 1),
#  ('31580726256', 1),
#  ('27377114394', 1),
#  ('26406126775', 1),
#  ('fareham', 1),
#  ('27420863594', 1),
#  ('27435262774', 1),
#  ('27435852934', 1),
#  ('27461124014', 1),
#  ('5194126', 1),
#  ('18316789393', 1),
#  ('e655656e-db1f-4383-919a-1beb1b74260d', 1),
#  ('27437186704', 1),
#  ('30357827661', 1),
#  ('30714325130', 1),
#  ('c180dcfd-2505-4f07-a6f7-944332273a97', 1),
#  ('00b34236-b77a-42d9-975f-6341fe4cca6e', 1),
#  ('18331841783', 1),
#  ('18346155113', 1),
#  ('31564357116', 1),
#  ('18348876533', 1),
#  ('R394101344', 1),
#  ('exmouth', 1),
#  ('27417036534', 1),
#  ('922975320', 1),
#  ('30747801870', 1),
#  ('30756460370', 1),
#  ('31562104166', 1),
#  ('31554999226', 1),
#  ('26392455815', 1),
#  ('19605140', 1),
#  ('5194245', 1),
#  ('31570171716', 1),
#  ('31584251276', 1),
#  ('18331958533', 1),
#  ('motherwell', 1),
#  ('30730383220', 1),
#  ('31586520446', 1),
#  ('C205407423', 1),
#  ('31602563196', 1),
#  ('26387967865', 1),
#  ('923634360', 1),
#  ('31549008616', 1),
#  ('18337743013', 1),
#  ('27409259704', 1),
#  ('27445426834', 1),
#  ('923679310', 1),
#  ('27389135384', 1),
#  ('27431315104', 1),
#  ('27418032674', 1),
#  ('31584608396', 1),
#  ('30732412440', 1),
#  ('18322258913', 1),
#  ('923656080', 1),
#  ('30377896991', 1),
#  ('31572028016', 1),
#  ('30751535270', 1),
#  ('923947370', 1),
#  ('30743859830', 1),
#  ('27408937804', 1),
#  ('31603006056', 1),
#  ('31585234706', 1),
#  ('18338593103', 1),
#  ('b4167054-f57e-4bd8-8191-824d61eae10d', 1),
#  ('R757451630', 1),
#  ('30721498850', 1),
#  ('30723745600', 1),
#  ('30755855180', 1),
#  ('30382295201', 1),
#  ('923261330', 1),
#  ('crouchend', 1),
#  ('27369650634', 1),
#  ('924273690', 1),
#  ('27403122624', 1),
#  ('31536514186', 1),
#  ('GB46090922', 1),
#  ('31564869346', 1),
#  ('31569664126', 1),
#  ('27424893594', 1),
#  ('27380097724', 1),
#  ('27389121034', 1),
#  ('30374047751', 1),
#  ('27368328574', 1),
#  ('18304987913', 1),
#  ('26371831535', 1),
#  ('31543459546', 1),
#  ('becktonsainsburys', 1),
#  ('31554788086', 1),
#  ('31575155506', 1),
#  ('27403917104', 1),
#  ('18328879393', 1),
#  ('923949920', 1),
#  ('31539469576', 1),
#  ('30702195340', 1),
#  ('26413118455', 1),
#  ('18345588013', 1),
#  ('it-ru', 1),
#  ('30690068330', 1),
#  ('27436986674', 1),
#  ('31583592406', 1),
#  ('30714762610', 1),
#  ('24b46fe8-b408-4855-bbda-773c97dae32d', 1),
#  ('18204464363', 1),
#  ('18350075403', 1),
#  ('4b8d9427-bbd2-454f-915a-b09d40693418', 1),
#  ('27370528854', 1),
#  ('31585867226', 1),
#  ('30368703751', 1),
#  ('30741515300', 1),
#  ('27412434314', 1),
#  ('EUF', 1),
#  ('19608924|ACM', 1),
#  ('19608925', 1),
#  ('27436316664', 1),
#  ('18348241133', 1),
#  ('924003790', 1),
#  ('31587660116', 1),
#  ('30351416231', 1),
#  ('5194525', 1),
#  ('26377341245', 1),
#  ('31597509396', 1),
#  ('ff6e2811-ce24-40ee-89ef-73091e3f10f4', 1),
#  ('18346097313', 1),
#  ('27427935164', 1),
#  ('923301810', 1),
#  ('ca', 1),
#  ('R244723500', 1),
#  ('30754666810', 1),
#  ('31543635676', 1),
#  ('27418172264', 1),
#  ('27412899294', 1),
#  ('923709300', 1),
#  ('27463767164', 1),
#  ('27380257454', 1),
#  ('27406485104', 1),
#  ('27412448884', 1),
#  ('923707840', 1),
#  ('27462851374', 1),
#  ('H00212435264', 1),
#  ('27411870204', 1),
#  ('26421545705', 1),
#  ('27410625474', 1),
#  ('30745094230', 1),
#  ('30396065291', 1),
#  ('31567789196', 1),
#  ('27423966744', 1),
#  ('31600669246', 1),
#  ('31585338556', 1),
#  ('924323690', 1),
#  ('0ba15c28-4daf-4202-818c-e6223d0f3454', 1),
#  ('18344036623', 1),
#  ('27373748264', 1),
#  ('31586370876', 1),
#  ('westbridgford', 1),
#  ('18334277203', 1),
#  ('31582977306', 1),
#  ('27398402614', 1),
#  ('27369904154', 1),
#  ('30671680400', 1),
#  ('30711694520', 1),
#  ('3ac9f1fd-bd37-429c-a2c2-5dbd9a02f249', 1),
#  ('R688581576', 1),
#  ('30700547450', 1),
#  ('27416690204', 1),
#  ('26384748545', 1),
#  ('31590109896', 1),
#  ('26384483175', 1),
#  ('31561706466', 1),
#  ('31587589356', 1),
#  ('31521545566', 1),
#  ('27391537504', 1),
#  ('31568765076', 1),
#  ('922411980', 1),
#  ('31551194786', 1),
#  ('30735899870', 1),
#  ('webapp', 1),
#  ('wcs', 1),
#  ('stores', 1),
#  ('servlet', 1),
#  ('ThankYouPageView', 1),
#  ('30755141340', 1),
#  ('27426326784', 1),
#  ('5195396', 1),
#  ('26384426405', 1),
#  ('30720769630', 1),
#  ('31546135796', 1),
#  ('30749842490', 1),
#  ('30729693070', 1),
#  ('27387026324', 1),
#  ('b1180921-5d79-4bda-881d-86e12c52c1cc', 1),
#  ('30729504500', 1),
#  ('18332458083', 1),
#  ('b0789967a7d018487a068aa9e03a2835_cs_', 1),
#  ('30737731090', 1),
#  ('31470073256', 1),
#  ('18347201483', 1),
#  ('18324134163', 1),
#  ('30761448210', 1),
#  ('US46097462', 1),
#  ('31587066826', 1),
#  ('27386979324', 1),
#  ('923662070', 1),
#  ('R679755183', 1),
#  ('27398638154', 1),
#  ('11235ac1-658f-466c-8b94-9d2c32449ed0', 1),
#  ('30752933960', 1),
#  ('27419317834', 1),
#  ('31546397276', 1),
#  ('27380062334', 1),
#  ('18322049223', 1),
#  ('27395433774', 1),
#  ('26416687565', 1),
#  ('26401801245', 1),
#  ('27406045594', 1),
#  ('18330783153', 1),
#  ('30749576490', 1),
#  ('31580394846', 1),
#  ('30748825360', 1),
#  ('31584043806', 1),
#  ('30723788010', 1),
#  ('31544637956', 1),
#  ('18323031913', 1),
#  ('30747090070', 1),
#  ('27370424344', 1),
#  ('31548129716', 1),
#  ('27458498674', 1),
#  ('30716206370', 1),
#  ('kingswood', 1),
#  ('27417836244', 1),
#  ('30749510830', 1),
#  ('30737030050', 1),
#  ('27414119984', 1),
#  ('31574393816', 1),
#  ('18334674023', 1),
#  ('27440616074', 1),
#  ('18332879243', 1),
#  ('no', 1),
#  ('27388088924', 1),
#  ('923986150', 1),
#  ('31585135216', 1),
#  ('31579444036', 1),
#  ('27432480054', 1),
#  ('26411578045', 1),
#  ('c4c2ab25-b58c-403f-a250-aeca6d001ac2', 1),
#  ('31566413126', 1),
#  ('18334229323', 1),
#  ('30749905180', 1),
#  ('917187260', 1),
#  ('18287690303', 1),
#  ('30713089120', 1),
#  ('31596796636', 1),
#  ('27389134954', 1),
#  ('179124', 1),
#  ('27395804514', 1),
#  ('31586844226', 1),
#  ('31586397606', 1),
#  ('30759523300', 1),
#  ('30758689590', 1),
#  ('31603928726', 1),
#  ('18323784383', 1),
#  ('30736092000', 1),
#  ('archerroadsainsburys', 1),
#  ('30709252510', 1),
#  ('18317354933', 1),
#  ('18319202123', 1),
#  ('31555259126', 1),
#  ('31589560536', 1),
#  ('30725124550', 1),
#  ('31552299506', 1),
#  ('bedford', 1),
#  ('31601366456', 1),
#  ('18329078703', 1),
#  ('31565119906', 1),
#  ('30742640020', 1),
#  ('26418876635', 1),
#  ('27441002284', 1),
#  ('R558589745', 1),
#  ('26414445905', 1),
#  ('27408664564', 1),
#  ('30698867690', 1),
#  ('27434043314', 1),
#  ('27417997284', 1),
#  ('31547470776', 1),
#  ('30712762680', 1),
#  ('27415978864', 1),
#  ('7526c200-2499-477e-866a-223933d17458', 1),
#  ('18320508513', 1),
#  ('1705323', 1),
#  ('27428667604', 1),
#  ('31574054986', 1),
#  ('27431387234', 1),
#  ('27410829914', 1),
#  ('27397102954', 1),
#  ('27398084624', 1),
#  ('26407770125', 1),
#  ('9232ff38-5c9b-40b9-978e-41a59f6438c5', 1),
#  ('31592807186', 1),
#  ('31562271686', 1),
#  ('27433255654', 1),
#  ('31549686956', 1),
#  ('27412101584', 1),
#  ('30760114330', 1),
#  ('31599361266', 1),
#  ('30372055331', 1),
#  ('f320ba50-099e-488e-8e72-5f132f53ea96', 1),
#  ('26417248275', 1),
#  ('27407754014', 1),
#  ('31601393446', 1),
#  ('27373468014', 1),
#  ('27381088274', 1),
#  ('30712052560', 1),
#  ('30719257120', 1),
#  ('5192152', 1),
#  ('27454454814', 1),
#  ('30737418630', 1),
#  ('31573443566', 1),
#  ('26385657985', 1),
#  ('5195699', 1),
#  ('27455895904', 1),
#  ('31545057896', 1),
#  ('30723037480', 1),
#  ('26421161915', 1),
#  ('1310989034', 1),
#  ('27441739234', 1),
#  ('31557759746', 1),
#  ('924252590', 1),
#  ('27417068004', 1),
#  ('31533771236', 1),
#  ('31587810886', 1),
#  ('27436251024', 1),
#  ('30714102000', 1),
#  ('27456025644', 1),
#  ('30715482590', 1),
#  ('18339973443', 1),
#  ('30730335370', 1),
#  ('27369417594', 1),
#  ('26402928825', 1),
#  ('30721326820', 1),
#  ('30702750930', 1),
#  ('31555169006', 1),
#  ('18347251493', 1),
#  ('27425522164', 1),
#  ('27438175694', 1),
#  ('17c9c89c-0060-4325-9f39-b0a020a11868', 1),
#  ('30724075670', 1),
#  ('16041509782', 1),
#  ('27461862844', 1),
#  ('27410658024', 1),
#  ('31574995846', 1),
#  ('27418952534', 1),
#  ('18339993283', 1),
#  ('31568720396', 1),
#  ('5193994', 1),
#  ('27406199604', 1),
#  ('27389198204', 1),
#  ('31556412566', 1),
#  ('27459328064', 1),
#  ('en_ie', 1),
#  ('27384226554', 1),
#  ('27416135104', 1),
#  ('18332321993', 1),
#  ('27414111574', 1),
#  ('18342721063', 1),
#  ('30763953060', 1),
#  ('30720879510', 1),
#  ('27403717354', 1),
#  ('18349443603', 1),
#  ('da44dbb5-d036-4c15-9519-5957abad0b25', 1),
#  ('26422257295', 1),
#  ('27431618814', 1),
#  ('30736103920', 1),
#  ('31579404306', 1),
#  ('27416328244', 1),
#  ('30762315080', 1),
#  ('18320042113', 1),
#  ('18312722223', 1),
#  ('buxton', 1),
#  ('27448408954', 1),
#  ('31534157286', 1),
#  ('30730551010', 1),
#  ('27441021934', 1),
#  ('27398565324', 1),
#  ('30760342250', 1),
#  ('27463648084', 1),
#  ('e840ddce-09ce-4f81-a080-1e5f8bbbfed1', 1),
#  ('31565251256', 1),
#  ('18329052173', 1),
#  ('30723738280', 1),
#  ('31584204876', 1),
#  ('27407709484', 1),
#  ('27371719714', 1),
#  ('31547031506', 1),
#  ('31601249836', 1),
#  ('27449309834', 1),
#  ('27408822474', 1),
#  ('924016600', 1),
#  ('30758829700', 1),
#  ('27396019384', 1),
#  ('27378912614', 1),
#  ('27435956594', 1),
#  ('31589716856', 1),
#  ('27383036114', 1),
#  ('26373131475', 1),
#  ('27370169204', 1),
#  ('30718951750', 1),
#  ('924085020', 1),
#  ('26401263405', 1),
#  ('18340956033', 1),
#  ('923670230', 1),
#  ('harlesden', 1),
#  ('27409086894', 1),
#  ('31555218826', 1),
#  ('taunton', 1),
#  ('27394053734', 1),
#  ('27418825404', 1),
#  ('2f3e4281-befa-41ac-9621-adfba9abbbb9', 1),
#  ('18331401003', 1),
#  ('27440658584', 1),
#  ('31562349186', 1),
#  ('b3b77d99-1a32-4cbe-a7ce-17059452599f', 1),
#  ('30700399860', 1),
#  ('30724163940', 1),
#  ('31563093966', 1),
#  ('27395659934', 1),
#  ('18341892503', 1),
#  ('27426418494', 1),
#  ('27418621694', 1),
#  ('16048684032', 1),
#  ('27391360014', 1),
#  ('30704080600', 1),
#  ('30332057511', 1),
#  ('922977680', 1),
#  ('30740131220', 1),
#  ('27381106624', 1),
#  ('27397518834', 1),
#  ('R749430275', 1),
#  ('27399490354', 1),
#  ('30715382790', 1),
#  ('5196217', 1),
#  ('bourne', 1),
#  ('e7f6ab6d-03d0-4170-b293-cdd4dc6ec1f7', 1),
#  ('30740012250', 1),
#  ('leicesternorthsainsburys', 1),
#  ('31577520756', 1),
#  ('ee6d7fe5771a58fc27cff2af52419a1b_cs_', 1),
#  ('30756604370', 1),
#  ('18330399533', 1),
#  ('27462400184', 1),
#  ('eltham', 1),
#  ('5195036', 1),
#  ('18340136673', 1),
#  ('30704277000', 1),
#  ('edinburgh', 1),
#  ('ab7f866b-92c5-4b31-b1c8-3b155ac1dab5', 1),
#  ('31572904566', 1),
#  ('31561832706', 1),
#  ('27433432484', 1),
#  ('27406665114', 1),
#  ('923361140', 1),
#  ('30710215020', 1),
#  ('18328403423', 1),
#  ('31582311516', 1),
#  ('31571780616', 1),
#  ('27386841994', 1),
#  ('US46090009', 1),
#  ('27413697864', 1),
#  ('31592052056', 1),
#  ('5191382', 1),
#  ('27392042444', 1),
#  ('31555053686', 1),
#  ('a1f3ef9b-d6c2-4581-8eb2-ac0e16c0f19b', 1),
#  ('sidcup', 1),
#  ('dfac3b2e-c4e5-4f3a-aabe-f44d29f77148', 1),
#  ('30233378781', 1),
#  ('Highlander', 1),
#  ('30759099960', 1),
#  ('30718028620', 1),
#  ('27397272404', 1),
#  ('18348575443', 1),
#  ('27395458524', 1),
#  ('26380645145', 1),
#  ('31535288016', 1),
#  ('27430373794', 1),
#  ('26409768525', 1),
#  ('27463926154', 1),
#  ('27353535004', 1),
#  ('27445448474', 1),
#  ('924263210', 1),
#  ('30375485091', 1),
#  ('27436704794', 1),
#  ('27427295804', 1),
#  ('27451382354', 1),
#  ('31583430696', 1),
#  ('0dcdb879-b38e-4a43-a51b-63397aa5444b', 1),
#  ('5192661', 1),
#  ('30727215220', 1),
#  ('27391810904', 1),
#  ('30383609101', 1),
#  ('924031250', 1),
#  ('0614c969-6026-45b4-8571-2958959bd2a9', 1),
#  ('30732819870', 1),
#  ('27419036644', 1),
#  ('18350222943', 1),
#  ('922983210', 1),
#  ('reading', 1),
#  ('26409582055', 1),
#  ('H00212420883', 1),
#  ('27411774794', 1),
#  ('30734539440', 1),
#  ('31573333576', 1),
#  ('31576873386', 1),
#  ('27378486344', 1),
#  ('18342837713', 1),
#  ('18318077593', 1),
#  ('922970500', 1),
#  ('27413275234', 1),
#  ('31538439716', 1),
#  ('18338276573', 1),
#  ('30756243430', 1),
#  ('27432126474', 1),
#  ('31565375966', 1),
#  ('27391541454', 1),
#  ('30727429470', 1),
#  ('30737680400', 1),
#  ('31546246556', 1),
#  ('18322109413', 1),
#  ('27405149194', 1),
#  ('18330981073', 1),
#  ('31591964906', 1),
#  ('18346575743', 1),
#  ('5195102', 1),
#  ('27385485434', 1),
#  ('30754663360', 1),
#  ('26398404025', 1),
#  ('27389821664', 1),
#  ('27426476454', 1),
#  ('30706728650', 1),
#  ('18329529613', 1),
#  ('27427825774', 1),
#  ('27463293854', 1),
#  ('27404489374', 1),
#  ('27457503974', 1),
#  ('31583946356', 1),
#  ('27413915974', 1),
#  ('923722290', 1),
#  ('30754360260', 1),
#  ('30368694531', 1),
#  ('30717689360', 1),
#  ('30357843701', 1),
#  ('923648310', 1),
#  ('31573874196', 1),
#  ('27413256124', 1),
#  ('18346704173', 1),
#  ('30736447460', 1),
#  ('801fd68a-9b08-46ad-b9d2-3e2d953e5d8d', 1),
#  ('923646110', 1),
#  ('31597821006', 1),
#  ('30722575470', 1),
#  ('18333416853', 1),
#  ('26419751155', 1),
#  ('30764364330', 1),
#  ('923702830', 1),
#  ('31585585386', 1),
#  ('30715867390', 1),
#  ('30737795740', 1),
#  ('30741931570', 1),
#  ('31538878566', 1),
#  ('3d27d780-c387-47d7-9018-dae05b7b5abc', 1),
#  ('18346455703', 1),
#  ('18317276933', 1),
#  ('27388159854', 1),
#  ('27451239324', 1),
#  ('27368963944', 1),
#  ('31550562166', 1),
#  ('30381939641', 1),
#  ('perth', 1),
#  ('18331717303', 1),
#  ('readingshinfieldroad', 1),
#  ('31550688596', 1),
#  ('18323461293', 1),
#  ('27271028984', 1),
#  ('queensway', 1),
#  ('30699732190', 1),
#  ('31566433516', 1),
#  ('16057542282', 1),
#  ('27454942514', 1),
#  ('27418881504', 1),
#  ('31583702786', 1),
#  ('26392177975', 1),
#  ('30701317290', 1),
#  ('31566582776', 1),
#  ('30392642611', 1),
#  ('26415681815', 1),
#  ('27425819294', 1),
#  ('27407159124', 1),
#  ('18320252633', 1),
#  ('31538890006', 1),
#  ('18349412213', 1),
#  ('31574958816', 1),
#  ('31578825966', 1),
#  ('fi', 1),
#  ('3740d151-2c26-4a66-8636-5cf46b6eeb27', 1),
#  ('30743850180', 1),
#  ('27465025044', 1),
#  ('5abdc916-be17-4331-80d0-f714f91183a1', 1),
#  ('eb7f6230-6bda-4cae-9318-22b0d8deae9f', 1),
#  ('31578832526', 1),
#  ('18342302803', 1),
#  ('27388665114', 1),
#  ('18346974163', 1),
#  ('30716613550', 1),
#  ('31545399096', 1),
#  ('US46092237', 1),
#  ('30731437260', 1),
#  ('27422480114', 1),
#  ('31549588846', 1),
#  ('16058332692', 1),
#  ('27444051894', 1),
#  ('18351291583', 1),
#  ('27415006374', 1),
#  ('18324428083', 1),
#  ('18339076113', 1),
#  ('27399093244', 1),
#  ('31553097586', 1),
#  ('31570415776', 1),
#  ('31551666646', 1),
#  ('4b89ff7de7dc61a73e57135b72724f22_cs_', 1),
#  ('30753147400', 1),
#  ('d8427461-b7ba-405a-89aa-9d79bcf38ed5', 1),
#  ('31549306646', 1),
#  ('18326761083', 1),
#  ('30742124980', 1),
#  ('27395119184', 1),
#  ('923749500', 1),
#  ('31575025846', 1),
#  ('26413390695', 1),
#  ('27450674024', 1),
#  ('1310988169', 1),
#  ('27430450774', 1),
#  ('922983900', 1),
#  ('18331824203', 1),
#  ('31592752896', 1),
#  ('27407005864', 1),
#  ('30739588450', 1),
#  ('18349349583', 1),
#  ('26413522415', 1),
#  ('30743048730', 1),
#  ('27410335174', 1),
#  ('18323172243', 1),
#  ('27379883194', 1),
#  ('31559032646', 1),
#  ('27464640174', 1),
#  ('af7336ba-5f21-4712-9f21-9947f5c6da32', 1),
#  ('31573543816', 1),
#  ('27387964194', 1),
#  ('27432711394', 1),
#  ('1709303', 1),
#  ('27419942374', 1),
#  ('30736989940', 1),
#  ('26415185175', 1),
#  ('30719024140', 1),
#  ('923931840', 1),
#  ('922999950', 1),
#  ('6e236c09-a15b-4146-b5ca-d7abd75ef56d', 1),
#  ('27405710344', 1),
#  ('18318267233', 1),
#  ('31538373806', 1),
#  ('27394270344', 1),
#  ('923263350', 1),
#  ('31586791646', 1),
#  ('27387640124', 1),
#  ('18345059883', 1),
#  ('welshpool', 1),
#  ('27413529834', 1),
#  ('GB46101053', 1),
#  ('31558589806', 1),
#  ('27378071554', 1),
#  ('27408294124', 1),
#  ('27411708614', 1),
#  ('26401128875', 1),
#  ('18343233163', 1),
#  ('27431484744', 1),
#  ('31601312556', 1),
#  ('27369714094', 1),
#  ('27456197184', 1),
#  ('923688180', 1),
#  ('31547095636', 1),
#  ('e73b9f94-a352-4beb-bc0c-c1398d199f90', 1),
#  ('27441466484', 1),
#  ('27373957074', 1)]

# %%
# Same for "Checkout"

get_most_occurrent_path_chunks("Checkout")
# Out:
# Number of different path chunks: 1663
# [('checkout', 2658),
#  ('en_gb', 1047),
#  ('en', 895),
#  ('book', 665),
#  ('stores', 590),
#  ('order', 481),
#  ('store', 238),
#  ('checkout.html', 238),
#  ('select-a-store', 207),
#  ('appointment-type', 196),
#  ('single', 186),
#  ('appointment-triage-questionnaire', 176),
#  ('en-us', 169),
#  ('card-details', 149),
#  ('ordersummary', 147),
#  ('on', 142),
#  ('demandware.store', 142),
#  ('personal-details', 139),
#  ('date-and-time', 135),
#  ('fr', 124),
#  ('MCheckout-FormHandler', 120),
#  ('recap', 87),
#  ('de', 86),
#  ('en_GB', 81),
#  ('Sites-en-GB-Site', 80),
#  ('shipping', 78),
#  ('hearing', 70),
#  ('de_de', 63),
#  ('us', 60),
#  ('Checkout', 55),
#  ('uk', 55),
#  ('it', 48),
#  ('OnePageCheckout', 48),
#  ('Confirmation', 44),
#  ('earwax', 43),
#  ('earwax-removal', 43),
#  ('nl_nl', 40),
#  ('nl', 39),
#  ('HostedPaymentPage', 38),
#  ('pl', 38),
#  ('holidays', 36),
#  ('booking', 36),
#  ('fr_fr', 35),
#  ('location', 31),
#  ('orderConfirmation', 31),
#  ('summary', 29),
#  ('Pages', 27),
#  ('CustomerPasswordChange_WC.aspx', 26),
#  ('en_us', 23),
#  ('amend', 23),
#  ('confirmation-commande', 20),
#  ('en-ca', 20),
#  ('location-hearing', 19),
#  ('it_it', 17),
#  ('Sites-fr-FR-Site', 16),
#  ('fr_FR', 16),
#  ('s', 16),
#  ('checkout-delivery', 15),
#  ('en-gb', 15),
#  ('eu', 14),
#  ('PaymentDetailsView', 13),
#  ('RetourPaypal', 13),
#  ('payment', 13),
#  ('de_DE', 12),
#  ('your-appointment', 12),
#  ('MCheckout-Start', 12),
#  ('DeliveryDetailsView', 11),
#  ('pl_pl', 11),
#  ('it_IT', 10),
#  ('amazonpayment.aspx', 9),
#  ('delivery', 9),
#  ('checkoutflow', 9),
#  ('place-order', 9),
#  ('en-US', 9),
#  ('en_US', 8),
#  ('checkout-confirmation', 8),
#  ('Sites-it-IT-Site', 8),
#  ('INTERSHOP', 8),
#  ('web', 8),
#  ('WFS', 8),
#  ('-', 8),
#  ('EUR', 8),
#  ('ViewData-Start', 8),
#  ('manageOrderDetails', 8),
#  ('de_at', 8),
#  ('Sites-en-US-Site', 7),
#  ('gb', 7),
#  ('cancel', 7),
#  ('Sites-en-SG-Site', 7),
#  ('en_SG', 7),
#  ('orderDeliveryBooking', 6),
#  ('en_au', 6),
#  ('review', 6),
#  ('sv_se', 6),
#  ('OrderOKView', 6),
#  ('es', 6),
#  ('checkout-payment', 6),
#  ('Order-Confirm', 6),
#  ('unauthorised', 5),
#  ('cs-creation-compte', 5),
#  ('nl_be', 5),
#  ('hotels', 5),
#  ('da', 5),
#  ('manchester', 5),
#  ('no-results', 5),
#  ('pt_pt', 5),
#  ('Sites-SLP-WEUR-Site', 5),
#  ('f2', 4),
#  ('payment-result', 4),
#  ('barnsley-hearing', 4),
#  ('Sites-de-DE-Site', 4),
#  ('ThankYou', 4),
#  ('valuation', 4),
#  ('Catrice-DE-Site', 4),
#  ('acomb', 4),
#  ('de-de', 4),
#  ('Essence-DE-Site', 4),
#  ('Sites-en-HK-Site', 4),
#  ('maidstone', 4),
#  ('basingstoke', 4),
#  ('ja-JP', 4),
#  ('es_es', 4),
#  ('ashford', 4),
#  ('custom-product', 3),
#  ('alfreton', 3),
#  ('redhill-hearing', 3),
#  ('express-reorder', 3),
#  ('eastgrinstead', 3),
#  ('fr-ca', 3),
#  ('shirley', 3),
#  ('checkout-address', 3),
#  ('de_ch', 3),
#  ('burtonontrent', 3),
#  ('checkout-remove-product', 3),
#  ('es_us', 3),
#  ('your-details', 3),
#  ('billing', 3),
#  ('pre-reservation', 3),
#  ('confirmation', 3),
#  ('Sites-IKKS_COM-Site', 3),
#  ('cannock', 3),
#  ('checkout-v2', 3),
#  ('ashbydelazouch', 3),
#  ('da_dk', 3),
#  ('barking', 3),
#  ('penarth', 3),
#  ('wembley', 3),
#  ('kenilworth', 3),
#  ('ja', 3),
#  ('sv', 3),
#  ('stevenagesainsburys-hearing', 3),
#  ('staustell', 3),
#  ('checkout-your-order', 3),
#  ('ie', 3),
#  ('aylesbury', 3),
#  ('cs-login-compte', 3),
#  ('fr_be', 3),
#  ('livingston-hearing', 2),
#  ('pudsey', 2),
#  ('bournemouth', 2),
#  ('march', 2),
#  ('vangarde', 2),
#  ('northbridge', 2),
#  ('bradleystoke-hearing', 2),
#  ('loughton', 2),
#  ('lowhallsainsburys', 2),
#  ('RetourPaypalExpress', 2),
#  ('westwoodcrosssainsburys', 2),
#  ('chandlersford', 2),
#  ('stone', 2),
#  ('lowestoft', 2),
#  ('southampton', 2),
#  ('505961', 2),
#  ('camdentown', 2),
#  ('cart.asp', 2),
#  ('2-118710-1', 2),
#  ('mitsis-ramira-beach-hotel', 2),
#  ('retford', 2),
#  ('hartlepool', 2),
#  ('bybrooksainsburys', 2),
#  ('middlesbrough', 2),
#  ('bristolclifton', 2),
#  ('dk', 2),
#  ('replacement-glasses', 2),
#  ('worcesterpark', 2),
#  ('crosby', 2),
#  ('blaydon', 2),
#  ('Sites-da-DK-Site', 2),
#  ('da_DK', 2),
#  ('leamingtonspa', 2),
#  ('zh_HK', 2),
#  ('woodgreen', 2),
#  ('sheffield', 2),
#  ('chichester', 2),
#  ('newtown', 2),
#  ('2-315087-1', 2),
#  ('coconut-bay-resort-and-spa', 2),
#  ('COBilling-Start', 2),
#  ('biggleswade', 2),
#  ('it-it', 2),
#  ('hastings', 2),
#  ('caterham', 2),
#  ('address', 2),
#  ('warrenheathsainsburys', 2),
#  ('wells', 2),
#  ('manageOrderPayment', 2),
#  ('lakeside', 2),
#  ('york-hearing', 2),
#  ('2-312530', 2),
#  ('atlantis-apartments', 2),
#  ('pt', 2),
#  ('Sites-pl-PL-Site', 2),
#  ('pl_PL', 2),
#  ('hilton-dalaman-sarigerme-resort-spa', 2),
#  ('hornchurch', 2),
#  ('bilston', 2),
#  ('berwick', 2),
#  ('wimbledon', 2),
#  ('en_eur', 2),
#  ('hernebaysainsburys', 2),
#  ('2-315079-1', 2),
#  ('windjammer-landing-villa-beach-resort', 2),
#  ('no', 2),
#  ('five-palm-jumeirah-dubai', 2),
#  ('cn', 2),
#  ('bedford-hearing', 2),
#  ('shandwickplace-hearing', 2),
#  ('isleofman', 2),
#  ('edgwareroad-hearing', 2),
#  ('newport', 2),
#  ('nailsea-hearing', 2),
#  ('acocksgreen', 2),
#  ('fi_fi', 2),
#  ('cambridgefitzroystreet-hearing', 2),
#  ('2-6745127-1', 2),
#  ('dukes-the-palm-a-royal-hideaway-hotel', 2),
#  ('be', 2),
#  ('revieworder', 2),
#  ('newtownabbey', 2),
#  ('wigan', 2),
#  ('cambridge', 2),
#  ('leedscrownpoint', 2),
#  ('miltonkeynes', 2),
#  ('leeds', 2),
#  ('ormskirk', 2),
#  ('en_ie', 2),
#  ('warrington', 2),
#  ('beaumontleys', 2),
#  ('gylecentre', 2),
#  ('leyland', 2),
#  ('cardiffleckwith', 2),
#  ('leicesternorthsainsburys', 2),
#  ('stalbans', 2),
#  ('en_HK', 2),
#  ('motherwell', 2),
#  ('edinburgh', 2),
#  ('2-6851451', 2),
#  ('cocoon-maldives', 2),
#  ('bognorregis', 2),
#  ('klarna', 2),
#  ('norwich', 2),
#  ('coventry', 2),
#  ('scunthorpe', 2),
#  ('newtonmearns', 2),
#  ('braeheadsainsburys', 2),
#  ('sittingbourne', 2),
#  ('fosseparksainsburys', 2),
#  ('holloway', 2),
#  ('ealingbroadway', 2),
#  ('porthcawl', 2),
#  ('kendalsainsburys', 2),
#  ('castlevalesainsburys', 2),
#  ('launceston', 2),
#  ('payment.aspx', 2),
#  ('stevenagesainsburys', 2),
#  ('appointment-kept', 2),
#  ('streatham', 2),
#  ('feltham', 2),
#  ('stroud', 2),
#  ('cart', 2),
#  ('wishaw', 2),
#  ('jp', 2),
#  ('bexleyheath', 2),
#  ('ca', 2),
#  ('dartford', 2),
#  ('wellington', 2),
#  ('winterstokeroadsainsburys-hearing', 2),
#  ('haywardsheath', 2),
#  ('en_nz', 2),
#  ('amazon', 2),
#  ('morecambe', 2),
#  ('camerontoll-hearing', 2),
#  ('pinner-hearing', 2),
#  ('chiswick', 2),
#  ('cz', 2),
#  ('ilkeston', 2),
#  ('brixton', 2),
#  ('validate3ds', 2),
#  ('2-2239480-1', 2),
#  ('mitsis-laguna-resort-spa', 2),
#  ('en_DE', 2),
#  ('waterlooville', 2),
#  ('walworth-hearing', 2),
#  ('elgin', 2),
#  ('lincolnmorrisons', 2),
#  ('5861125-1614029839898036', 1),
#  ('bridgendderwensainsburys', 1),
#  ('woodbridge', 1),
#  ('2701efe3-d378-4eb9-952b-737d89fe0e3a', 1),
#  ('dundee', 1),
#  ('Boundary%20Farm%20Rd%2C%20Liverpool%20L26%201TY%2C%20UK', 1),
#  ('53.358,-2.843', 1),
#  ('grantham-hearing', 1),
#  ('2-4709117-1', 1),
#  ('ikos-olivia', 1),
#  ('redruth', 1),
#  ('northfield-hearing', 1),
#  ('wrexham-hearing', 1),
#  ('1707036', 1),
#  ('newbury', 1),
#  ('twickenham', 1),
#  ('sleaford', 1),
#  ('shipley', 1),
#  ('Truro%2C%20UK', 1),
#  ('50.263,-5.051', 1),
#  ('4380d52d-c636-4894-9fa8-0b4f5984a6c7', 1),
#  ('2-2747598-1', 1),
#  ('ibis-wien-city', 1),
#  ('0OO9295CP', 1),
#  ('exmouth-hearing', 1),
#  ('Advent%20Way%2C%20Ancoats%2C%20Manchester%20M4%207FD%2C%20UK', 1),
#  ('53.478,-2.220', 1),
#  ('cookstown', 1),
#  ('barnstaple', 1),
#  ('specsavers-boost-dementia-awareness-in-march', 1),
#  ('2-4309262', 1),
#  ('green-nature-diamond-hotel', 1),
#  ('burgesshill-hearing', 1),
#  ('Maidstone%20ME17%203EQ%2C%20UK', 1),
#  ('51.217,0.592', 1),
#  ('2-125714', 1),
#  ('hotel-equatorial-ho-chi-minh-city', 1),
#  ('petersfield', 1),
#  ('tamworthsainsburys', 1),
#  ('Basing%20Rd%2C%20Leigh%20Park%2C%20Havant%20PO9%205AG%2C%20UK', 1),
#  ('50.867,-0.986', 1),
#  ('no_no', 1),
#  ('0OO9417CP', 1),
#  ('2-230135', 1),
#  ('atalaya-apartments', 1),
#  ('boltonsainsburys-hearing', 1),
#  ('windsor', 1),
#  ('wetherby', 1),
#  ('2-117459', 1),
#  ('bahia-principe-sunlight-costa-adeje', 1),
#  ('Alexander%20Dr%2C%20Bury%20BL9%208PF%2C%20UK', 1),
#  ('53.555,-2.281', 1),
#  ('Lancaster%20Rd%2C%20Salford%20M6%208NB%2C%20UK', 1),
#  ('53.497,-2.322', 1),
#  ('sutton', 1),
#  ('bicester', 1),
#  ('Unicorn%20Ave%2C%20Coventry%20CV5%207FB%2C%20UK', 1),
#  ('52.415,-1.588', 1),
#  ('westhill-hearing', 1),
#  ('harrowweald-hearing', 1),
#  ('1707180', 1),
#  ('longeaton-hearing', 1),
#  ('stratforduponavon', 1),
#  ('sthelens', 1),
#  ('thornbury', 1),
#  ('2-231291-1', 1),
#  ('hurghada-long-beach-hotel', 1),
#  ('High%20Axwell%2C%20Blaydon-on-Tyne%20NE21%205LB%2C%20UK', 1),
#  ('54.958,-1.708', 1),
#  ('grays', 1),
#  ('grays-donates-to-the-british-heart-foundation', 1),
#  ('HX0005841354', 1),
#  ('2-6684283-1', 1),
#  ('majestic-mirage', 1),
#  ('74346723', 1),
#  ('stannes', 1),
#  ('Alabama%20St%2C%20London%20SE18%202SH%2C%20UK', 1),
#  ('51.476,0.088', 1),
#  ('Markham%20Square%2C%20Stockton-on-Tees%20TS19%200TE%2C%20UK', 1),
#  ('54.572,-1.355', 1),
#  ('2-8339912-1', 1),
#  ('kandolhu-maldives', 1),
#  ('2-126015-1', 1),
#  ('globales-mimosa', 1),
#  ('billing-data', 1),
#  ('burnley', 1),
#  ('helensburgh-hearing', 1),
#  ('01bbd38d-8dd0-4ebb-a8bb-65a917521ed2', 1),
#  ('2-114081-1', 1),
#  ('marina-hotel', 1),
#  ('3574832b41490be143b4901fe0fb35cf', 1),
#  ('bourne', 1),
#  ('gerrardscross', 1),
#  ('ea7afc60-dd08-46eb-a4a8-8830bb6b7152', 1),
#  ('newmarket', 1),
#  ('havant', 1),
#  ('3fd430fa-6732-4c73-9a8e-837556cf8efe', 1),
#  ('abingdon', 1),
#  ('2-226870-1', 1),
#  ('cala-dor-apartments', 1),
#  ('killingworth', 1),
#  ('peterhead', 1),
#  ('rickmansworth', 1),
#  ('West%20Croydon%20Station%2C%20Croydon%20CR0%2C%20UK', 1),
#  ('51.378,-0.103', 1),
#  ('337A007087', 1),
#  ('Bracknell%20RG42%2C%20UK', 1),
#  ('51.439,-0.766', 1),
#  ('2-289307-1', 1),
#  ('sunrise-royal-makadi-hotel', 1),
#  ('portsmouthnorthend-hearing', 1),
#  ('batley', 1),
#  ('webapp', 1),
#  ('wcs', 1),
#  ('servlet', 1),
#  ('2-126419-1', 1),
#  ('hoposa-hotel-daina', 1),
#  ('Plover%20St%2C%20Preston%20PR1%206TT%2C%20UK', 1),
#  ('53.768,-2.689', 1),
#  ('Braunton%20EX33%2C%20UK', 1),
#  ('51.126,-4.175', 1),
#  ('au', 1),
#  ('Scott%20Cl%2C%20Ditton%2C%20Aylesford%20ME20%206QP%2C%20UK', 1),
#  ('51.295,0.453', 1),
#  ('2-114869-1', 1),
#  ('sol-don-marco-hotel', 1),
#  ('norrisgreen', 1),
#  ('Scow%20Croft%20Ln,%20Chorley%20PR6%209BY,%20UK', 1),
#  ('53.6757,-2.5848', 1),
#  ('1709525', 1),
#  ('coulbynewham-hearing', 1),
#  ('2-1670764', 1),
#  ('angsana-villas-resort-phuket', 1),
#  ('weymouth', 1),
#  ('Yarm%20TS15%209FQ%2C%20UK', 1),
#  ('54.495,-1.365', 1),
#  ('parkfarmsainsburys', 1),
#  ('payment-completion', 1),
#  ('0488a7cd-fafb-4aa1-9278-57d859f1a666', 1),
#  ('2-3389629', 1),
#  ('alkoclar-keban-hotel', 1),
#  ('nairn', 1),
#  ('cupar', 1),
#  ('Maryport%2C%20UK', 1),
#  ('54.714,-3.495', 1),
#  ('5610cf6d-ee04-4104-a513-6a83e353e3c7', 1),
#  ('calcotsainsburys', 1),
#  ('563bec1d-707e-49b4-9ecc-4c13f36222e0', 1),
#  ('Bell%20Rd%2C%20East%20Molesey%20KT8%200SS%2C%20UK', 1),
#  ('51.397,-0.354', 1),
#  ('Green%20Acres%2C%20Ponteland%2C%20Newcastle%20upon%20Tyne%20NE20%209RT%2C%20UK',
#   1),
#  ('55.028,-1.760', 1),
#  ('egham', 1),
#  ('pocklington', 1),
#  ('halifax-hearing', 1),
#  ('cleethorpes', 1),
#  ('formby', 1),
#  ('37384227', 1),
#  ('Skipton%20BD23%2C%20UK', 1),
#  ('53.963,-2.016', 1),
#  ('1709693', 1),
#  ('997e37a4-698e-4606-9df8-853862af9abf', 1),
#  ('Wakefield%20Rd%2C%20Barnsley%20S71%201NG%2C%20UK', 1),
#  ('53.568,-1.472', 1),
#  ('trowbridge', 1),
#  ('cumbernauld', 1),
#  ('e93951f4-c93e-4612-962a-756b4883538d', 1),
#  ('462219f2-fe6a-48ce-9579-6fd1291cf9c6', 1),
#  ('upminster', 1),
#  ('cheltenhamnorthwest-hearing', 1),
#  ('morden', 1),
#  ('Kensington%20Rd%2C%20Southport%20PR9%200RZ%2C%20UK', 1),
#  ('53.645,-2.992', 1),
#  ('990100010549698', 1),
#  ('Jacobean%20Cl%2C%20Crawley%20RH10%207FZ%2C%20UK', 1),
#  ('51.111,-0.153', 1),
#  ('2-117447', 1),
#  ('h10-gran-tinerfe-hotel', 1),
#  ('launceston-hearing', 1),
#  ('SO645565', 1),
#  ('tunstall', 1),
#  ('woolwich', 1),
#  ('lisburn-hearing', 1),
#  ('longwatersainsburys', 1),
#  ('halifax', 1),
#  ('en-NZ', 1),
#  ('stanmore', 1),
#  ('2-4547570-1', 1),
#  ('sunborn-gibraltar', 1),
#  ('ryde', 1),
#  ('1%20John%20Wilson%20Ct,%20Horden,%20Peterlee%20SR8%204ED,%20UK', 1),
#  ('54.76457266146624,-1.3123928626437622', 1),
#  ('2-3767143-1', 1),
#  ('sandals-barbados', 1),
#  ('hereford', 1),
#  ('Manor%20Rd%2C%20Colchester%20CO3%203LX%2C%20UK', 1),
#  ('51.888,0.892', 1),
#  ('0bcd37f0-0e7a-48e6-be8d-77ff081ea028', 1),
#  ('worcester', 1),
#  ('gorleston', 1),
#  ('5%20Woollaton%20St,%20Hucknall,%20Nottingham%20NG15%207HH,%20UK', 1),
#  ('53.0380292,-1.2013007999999998', 1),
#  ('4858468e188104ac599874d70029e723', 1),
#  ('2-1728461', 1),
#  ('rose-garden', 1),
#  ('2-3647924', 1),
#  ('splendour-resort', 1),
#  ('2-256422-1', 1),
#  ('samira-exclusive-hotel-and-apartments', 1),
#  ('Aln%20Ave%2C%20Newcastle%20upon%20Tyne%20NE3%202LS%2C%20UK', 1),
#  ('55.015,-1.638', 1),
#  ('2-1061379-1', 1),
#  ('apex-waterloo-place-edinburgh-hotel', 1),
#  ('Bentcliffe%20Gardens%2C%20Accrington%20BB5%202NX%2C%20UK', 1),
#  ('53.744,-2.355', 1),
#  ('northwalsham', 1),
#  ('Queen%20St%2C%20Newton%20Abbot%20TQ12%202EF%2C%20UK', 1),
#  ('50.530,-3.609', 1),
#  ('greenock', 1),
#  ('longeaton', 1),
#  ('1707357', 1),
#  ('edd7988d-0d9b-4a72-8cbb-c8b323881cfd-990100010539019-990100010539025', 1),
#  ('2-281596-1', 1),
#  ('mitsis-rodos-village-hotel', 1),
#  ('horsham', 1),
#  ('2-1511018-1', 1),
#  ('rixos-premium-magawish', 1),
#  ('abergavenny-hearing', 1),
#  ('faversham', 1),
#  ('dunstablesainsburys-hearing', 1),
#  ('Somers%20Town%2C%20London%20NW1%201EP%2C%20UK', 1),
#  ('51.532,-0.132', 1),
#  ('stevenage-hearing', 1),
#  ('Midhurst%20Rd%2C%20West%20Ealing%2C%20London%20W13%209XR%2C%20UK', 1),
#  ('51.501,-0.322', 1),
#  ('marketharborough', 1),
#  ('2-1620024-1', 1),
#  ('the-eleanor-rigby-hotel', 1),
#  ('bitterne', 1),
#  ('highwycombe-hearing', 1),
#  ('wallington-hearing', 1),
#  ('putney', 1),
#  ('crawley', 1),
#  ('cowbridge', 1),
#  ('Mendham%2C%20Harleston%20IP20%200PE%2C%20UK', 1),
#  ('52.387,1.345', 1),
#  ('37548248', 1),
#  ('2-113453', 1),
#  ('royal-albatros-moderna', 1),
#  ('179A026273', 1),
#  ('22%20The%20Riggs,%20Hunwick,%20Crook%20DL15%200JQ,%20UK', 1),
#  ('54.68485607889591,-1.7091802956148077', 1),
#  ('Hannan%20Rd%2C%20Kensington%2C%20Liverpool%20L6%206DA%2C%20UK', 1),
#  ('53.413,-2.949', 1),
#  ('portsmouthnorthend', 1),
#  ('Stanley%20St%20S%2C%20Bedminster%2C%20Bristol%20BS3%203PG%2C%20UK', 1),
#  ('51.436,-2.604', 1),
#  ('2-111769', 1),
#  ('grand-hyatt-dubai', 1),
#  ('hillsborough', 1),
#  ('Shirley%20High%20St%2C%20Shirley%2C%20Southampton%20SO15%203NH%2C%20UK', 1),
#  ('50.921,-1.432', 1),
#  ('enfield', 1),
#  ('HX0005848244', 1),
#  ('gosport', 1),
#  ('SO655382', 1),
#  ('galashiels', 1),
#  ('Churcher%20Cl%2C%20Gosport%20PO12%202SL%2C%20UK', 1),
#  ('50.792,-1.165', 1),
#  ('charltonriversidesainsburys', 1),
#  ('Wigan%20Rd%2C%20Bolton%20BL3%205QP%2C%20UK', 1),
#  ('53.569,-2.459', 1),
#  ('2-126037-1', 1),
#  ('sol-wave-house-all-suites', 1),
#  ('kettering', 1),
#  ('salisbury-hearing', 1),
#  ('f49ae113-2ccc-44c4-a025-cf3f59548e8b', 1),
#  ('goole', 1),
#  ('eltham-hearing', 1),
#  ('kirkcaldy-hearing', 1),
#  ('enniskillen', 1),
#  ('pt_br', 1),
#  ('Bournemouth%2C%20UK', 1),
#  ('50.719,-1.881', 1),
#  ('morningside-hearing', 1),
#  ('2-1421110', 1),
#  ('yeovil', 1),
#  ('barry', 1),
#  ('2-1094811-1', 1),
#  ('the-london-nyc', 1),
#  ('norwichststephensstreet', 1),
#  ('Walsingham%20Gardens%2C%20Epsom%20KT19%200LS%2C%20UK', 1),
#  ('51.363,-0.253', 1),
#  ('2-232557-1', 1),
#  ('butterfly-beach-hotel', 1),
#  ('2-2209676-1', 1),
#  ('jumeirah-zabeel-saray', 1),
#  ('croydon', 1),
#  ('fallowfield-hearing', 1),
#  ('5132bbea-d276-440e-9970-c3608e3f9429', 1),
#  ('2-3689164', 1),
#  ('waves-hotel-spa-by-elegant-hotels', 1),
#  ('Recorder%20Rd%2C%20Norwich%20NR1%201BP%2C%20UK', 1),
#  ('52.629,1.306', 1),
#  ('tamworth-hearing', 1),
#  ('Natal%20Rd%2C%20St%20Leonard%27s%2C%20London%20SW16%206JA%2C%20UK', 1),
#  ('51.423,-0.134', 1),
#  ('worthing-hearing', 1),
#  ('HX0005838442', 1),
#  ('kirkby', 1),
#  ('morley-hearing', 1),
#  ('990100010540188', 1),
#  ('2-5982639', 1),
#  ('fun-4-all-swingers-resort', 1),
#  ('Southwell%20Rd%2C%20Norwich%20NR1%2C%20UK', 1),
#  ('52.619,1.295', 1),
#  ('haverfordwest', 1),
#  ('74346834', 1),
#  ('specsavers-opticians-merton-borough-prepare-for-red-nose-day', 1),
#  ('login', 1),
#  ('hamilton', 1),
#  ('2-218585-1', 1),
#  ('sun-island-resort-and-spa-hotel', 1),
#  ('Ivyhouse%20Ln%2C%20Coseley%2C%20Bilston%20WV14%209JU%2C%20UK', 1),
#  ('52.543,-2.093', 1),
#  ('New%20Globe%20Walk%2C%20London%20SE1%209DS%2C%20UK', 1),
#  ('51.509,-0.096', 1),
#  ('daventry-hearing', 1),
#  ('lincoln', 1),
#  ('PE287%204UE', 1),
#  ('tooting', 1),
#  ('2-121484-1', 1),
#  ('mirachoro-praia-hotel', 1),
#  ('cardiffalbanyroad', 1),
#  ('2-4196792-1', 1),
#  ('the-soco-hotel-all-inclusive', 1),
#  ('hinckley', 1),
#  ('kingswood', 1),
#  ('kingsbury-hearing', 1),
#  ('woking', 1),
#  ('cs_cz', 1),
#  ('Cronulla%20Dr%2C%20Great%20Sankey%2C%20Warrington%20WA5%203HS%2C%20UK', 1),
#  ('53.397,-2.663', 1),
#  ('stocktonontees', 1),
#  ('Mitcheldean%20GL17%200DD%2C%20UK', 1),
#  ('51.870,-2.480', 1),
#  ('Clevedon%2C%20UK', 1),
#  ('51.428,-2.828', 1),
#  ('0OO9102CP', 1),
#  ('Oxford%20St%2C%20Cheltenham%20GL52%206DT%2C%20UK', 1),
#  ('51.897,-2.066', 1),
#  ('bury-hearing', 1),
#  ('2-125199-1', 1),
#  ('rosen-plaza-hotel', 1),
#  ('23f7867f-c355-4dc0-921b-56f21b2cab73', 1),
#  ('a70b330f-6512-48e6-b3fd-67b6b811de99', 1),
#  ('2-6175008', 1),
#  ('51.25990609999999,0.9604838000000001', 1),
#  ('altrincham', 1),
#  ('Dunoon%2C%20UK', 1),
#  ('55.951,-4.926', 1),
#  ('waterlooville-hearing', 1),
#  ('886WF634', 1),
#  ('dunstable-hearing', 1),
#  ('Lancaster%20LA1%2C%20UK', 1),
#  ('54.047,-2.791', 1),
#  ('erdington', 1),
#  ('manchesterfortpark', 1),
#  ('cobhamsainsburys-hearing', 1),
#  ('Wilkinson%20St%2C%20Broomhall%2C%20Sheffield%20S10%202GA%2C%20UK', 1),
#  ('53.379,-1.484', 1),
#  ('shandwickplace', 1),
#  ('Credenhill%20St%2C%20London%20SW16%206PR%2C%20UK', 1),
#  ('51.420,-0.144', 1),
#  ('505881', 1),
#  ('islington', 1),
#  ('basildon', 1),
#  ('ds7%206as', 1),
#  ('mansfieldsainsburys', 1),
#  ('Dudley%20Rd%2C%20Whalley%20Range%2C%20Manchester%20M16%208DE%2C%20UK', 1),
#  ('53.452,-2.262', 1),
#  ('Woodlands%20Dr%2C%20Coven%2C%20Wolverhampton%20WV9%205DR%2C%20UK', 1),
#  ('52.662,-2.139', 1),
#  ('longton', 1),
#  ('2-373631-1', 1),
#  ('stella-palace-hotel', 1),
#  ('2-322860-1', 1),
#  ('destiny-palms-maingate-west-hotel', 1),
#  ('CarteCadeau', 1),
#  ('mexborough', 1),
#  ('HX0005810756', 1),
#  ('sale-hearing', 1),
#  ('se', 1),
#  ('gerrardscross-hearing', 1),
#  ('ae528b0c-94ea-4a0d-ac3b-2ed4f5b30af1', 1),
#  ('2-122536-1', 1),
#  ('delphin-be-grand-resort', 1),
#  ('wednesfieldsainsburys', 1),
#  ('wick', 1),
#  ('musselburgh', 1),
#  ('School%20Rd%2C%20Yardley%20Wood%2C%20Birmingham%20B14%204HA%2C%20UK', 1),
#  ('52.416,-1.862', 1),
#  ('48%20Cambridge%20Rd,%20Birmingham%20B13%209UD,%20UK', 1),
#  ('52.436804106598935,-1.8851918029137655', 1),
#  ('Homestead%20Garth%2C%20Hatfield%2C%20Doncaster%20DN7%206RN%2C%20UK', 1),
#  ('53.582,-1.007', 1),
#  ('2-2242963-1', 1),
#  ('high-street-farm-house', 1),
#  ('camden-hearing', 1),
#  ('319A014013', 1),
#  ('parkgate-hearing', 1),
#  ('2-3915449-1', 1),
#  ('the-crown-hotel', 1),
#  ('ch', 1),
#  ('post-op-skills-training-for-cataracts', 1),
#  ('61657cff-2dcd-4db1-8ad6-53b21abbc0c4', 1),
#  ('54.5947251,-5.7822435', 1),
#  ('5885336-1614170223672431', 1),
#  ('Hammersmith%2C%20London%2C%20UK', 1),
#  ('51.491,-0.224', 1),
#  ('grantham', 1),
#  ('Edinburgh%20Rd%2C%20Walsall%20WS5%203PQ%2C%20UK', 1),
#  ('52.576,-1.959', 1),
#  ('eltham', 1),
#  ('doncaster', 1),
#  ('2-115460-1', 1),
#  ('cala-nova-apartments', 1),
#  ('milngavie', 1),
#  ('2-121485-1', 1),
#  ('rocha-brava-village-resort', 1),
#  ('2-2784748-1', 1),
#  ('sheraton-phoenix-downtown-hotel', 1),
#  ('Hackford%20Rd%2C%20Vassal%2C%20London%20SW9%200RG%2C%20UK', 1),
#  ('51.476,-0.115', 1),
#  ('zh-tw', 1),
#  ('checkoutlogin', 1),
#  ('brightonlondonroad-hearing', 1),
#  ('cheltenhamnorthwest', 1),
#  ('lymington', 1),
#  ('2-116896-1', 1),
#  ('jaime-i-hotel', 1),
#  ('HX0005837281', 1),
#  ('chichestersainsburys', 1),
#  ('york', 1),
#  ('2-3781976-1', 1),
#  ('anantara-dubai-the-palm-resort-spa', 1),
#  ('2-115141', 1),
#  ('riu-oliva-beach-resort-club-hotel', 1),
#  ('skelmersdale', 1),
#  ('3b6b615b-debb-45cc-9fd9-c0a1ebc55716', 1),
#  ('gateshead', 1),
#  ('wisbech-hearing', 1),
#  ('1dbdf5fb-314a-41e5-9f0a-ae8ed96501fe', 1),
#  ('watford', 1),
#  ('Hope%20Cottages%2C%20Ham%20Ln%2C%20Kingston%20Seymour%2C%20Clevedon%20BS21%206XF%2C%20UK',
#   1),
#  ('51.397,-2.867', 1),
#  ('5881414-1614108177885098', 1),
#  ('2-866692', 1),
#  ('neptun-hotel', 1),
#  ('2-290471-1', 1),
#  ('hilton-rose-hall-resort-and-spa', 1),
#  ('Hemel%20Hempstead%20HP1%2C%20UK', 1),
#  ('51.756,-0.488', 1),
#  ('37578315', 1),
#  ('Avarn%20Rd%2C%20Tooting%2C%20London%20SW17%209HA%2C%20UK', 1),
#  ('51.423,-0.163', 1),
#  ('craigavon', 1),
#  ('bedminsterlombard', 1),
#  ('bestellbestatigung', 1),
#  ('1706502', 1),
#  ('Bedworth%2C%20UK', 1),
#  ('52.481,-1.469', 1),
#  ('Wantage%20OX12%2C%20UK', 1),
#  ('51.589,-1.426', 1),
#  ('2-126034-1', 1),
#  ('globales-palmanova-palace', 1),
#  ('bethnalgreen', 1),
#  ('banstead-hearing', 1),
#  ('frome', 1),
#  ('St%20Saviour%27s%20Rd%2C%20Brixton%2C%20London%20SW2%205HD%2C%20UK', 1),
#  ('51.455,-0.121', 1),
#  ('2-277897-1', 1),
#  ('dunas-de-sal-design-hotel', 1),
#  ('firthpark', 1),
#  ('HX0005616138', 1),
#  ('uttoxeter-hearing', 1),
#  ('2-232199-1', 1),
#  ('le-royal-meridien-beach-resort-and-spa-hotel', 1),
#  ('Old%20Hall%20Rd%2C%20Chesterfield%20S40%201HG%2C%20UK', 1),
#  ('53.236,-1.453', 1),
#  ('Bryncastell%2C%20Bow%20Street%20SY24%205DF%2C%20UK', 1),
#  ('52.442,-4.035', 1),
#  ('ru-ru', 1),
#  ('Bishopbriggs%2C%20Glasgow%2C%20UK', 1),
#  ('55.904,-4.228', 1),
#  ('2-6198200', 1),
#  ('canopy-by-hilton-reykjavik', 1),
#  ('2-238381-1', 1),
#  ('sundance-resort-ex-aegean-dream-resort-hotel', 1),
#  ('Sites-en-AU-Site', 1),
#  ('en_AU', 1),
#  ('2-4141519-1', 1),
#  ('rixos-bab-al-bahr', 1),
#  ('brighton', 1),
#  ('whiterosesainsburys-hearing', 1),
#  ('06985edc-9335-4bf2-8010-52f9e1a5c73d', 1),
#  ('HX0005846268', 1),
#  ('2-117368-1', 1),
#  ('vistasur-apartments', 1),
#  ('Consett%20DH8%2C%20UK', 1),
#  ('54.852,-1.833', 1),
#  ('Cochran%20St%2C%20Paisley%20PA1%201JZ%2C%20UK', 1),
#  ('55.844,-4.414', 1),
#  ('rugeley', 1),
#  ('ruislip', 1),
#  ('Muir%20Dr%2C%20Hingham%2C%20Norwich%20NR9%204PQ%2C%20UK', 1),
#  ('52.583,0.977', 1),
#  ('Westgate%20St%2C%20Taunton%20TA1%204EX%2C%20UK', 1),
#  ('51.012,-3.109', 1),
#  ('42be5078-1083-4a51-9a28-997d7621b64f', 1),
#  ('Paignton%2C%20UK', 1),
#  ('50.435,-3.564', 1),
#  ('romford', 1),
#  ('Surbiton%20KT6%2C%20UK', 1),
#  ('51.383,-0.310', 1),
#  ('2-1421110-1', 1),
#  ('dunstable', 1),
#  ('allerton-hearing', 1),
#  ('2-2071226', 1),
#  ('club-salammbo', 1),
#  ('2-293289-1', 1),
#  ('starfish-st-lucia-resort', 1),
#  ('708bffb9-2325-47ea-81d5-08b5a364a1fe', 1),
#  ('C%20H610hq', 1),
#  ('2-2908940-1', 1),
#  ('delphin-imperial', 1),
#  ('lutterworth', 1),
#  ('hitchin', 1),
#  ('scarborough', 1),
#  ('cranleigh', 1),
#  ('wandsworth', 1),
#  ('normanton', 1),
#  ('Throxenby%20Way%2C%20Clayton%2C%20Bradford%20BD14%206EU%2C%20UK', 1),
#  ('53.783,-1.816', 1),
#  ('salisbury', 1),
#  ('chard', 1),
#  ('Epsom%20Rd%2C%20Guildford%20GU1%203JT%2C%20UK', 1),
#  ('51.238,-0.565', 1),
#  ('388c89c1-c240-491b-beb0-f5e6475e3508', 1),
#  ('Day%27s%20Ln%2C%20Biddenham%2C%20Bedford%20MK40%204AE%2C%20UK', 1),
#  ('52.141,-0.502', 1),
#  ('2a2e5ba2-e9ca-4bb5-aeb2-68b12f57b724', 1),
#  ('clactononsea-hearing', 1),
#  ('widnes', 1),
#  ('Plomer%20Green%20Ave%2C%20Downley%2C%20High%20Wycombe%20HP13%205LW%2C%20UK',
#   1),
#  ('51.645,-0.775', 1),
#  ('oakwood-hearing', 1),
#  ('2-281591-1', 1),
#  ('mitsis-summer-palace-hotel', 1),
#  ('stneots', 1),
#  ('whitby', 1),
#  ('2-274581-1', 1),
#  ('poseidon-hotel', 1),
#  ('Sussex%20Rd%2C%20Sidcup%20DA14%206LG%2C%20UK', 1),
#  ('51.421,0.110', 1),
#  ('farnham', 1),
#  ('10687df4-78b5-44c7-adfe-7010438a47d8', 1),
#  ('08c62f2c-8be9-4338-891b-2a33b7ed8c13', 1),
#  ('totnes-hearing', 1),
#  ('acton', 1),
#  ('cheltenham', 1),
#  ('Hayfield%2C%20High%20Peak%20SK22%2C%20UK', 1),
#  ('53.379,-1.946', 1),
#  ('diss-hearing', 1),
#  ('Surrey%20Mews%20%26%20Hamilton%20Road%2C%20Gipsy%20Hill%2C%20London%20SE27%209SF%2C%20UK',
#   1),
#  ('51.428,-0.088', 1),
#  ('29%20Staines%20Way,%20Louth%20LN11%200DE,%20UK', 1),
#  ('53.37476511560215,0.013622112200539476', 1),
#  ('tring', 1),
#  ('2-874612-1', 1),
#  ('rock-hotel', 1),
#  ('Ash%20Ln%2C%20Great%20Harwood%2C%20Blackburn%20BB6%207NU%2C%20UK', 1),
#  ('53.790,-2.413', 1),
#  ('2-122586-1', 1),
#  ('letoonia-golf-resort-hotel', 1),
#  ('1705651', 1),
#  ('98307f53-f244-4a21-88d1-94d86437e5c6-990100010549197-990100010549200', 1),
#  ('1193bcc32dd53ca5269008ce158f5942', 1),
#  ('belfast-hearing', 1),
#  ('2-4626852', 1),
#  ('murat-pasha-mansion', 1),
#  ('2-1357530-1', 1),
#  ('sunset-bay-club-by-diamond-resorts', 1),
#  ('fulhamwharfsainsburys', 1),
#  ('rayleigh', 1),
#  ('stratford-hearing', 1),
#  ('ilford', 1),
#  ('worthing', 1),
#  ('Shelgate%20Rd%2C%20London%20SW11%201BQ%2C%20UK', 1),
#  ('51.460,-0.163', 1),
#  ('3303ecf40265ce1bef0e48cd10b8d061', 1),
#  ('1', 1),
#  ('Peterborough%20PE1%2C%20UK', 1),
#  ('52.585,-0.232', 1),
#  ('bridgend', 1),
#  ('barnstaple-hearing', 1),
#  ('HX0005852117', 1),
#  ('rustington-hearing', 1),
#  ('2-1503669', 1),
#  ('mirabella-apartments', 1),
#  ('Kingston%20upon%20Thames%2C%20UK', 1),
#  ('51.412,-0.301', 1),
#  ('forfar', 1),
#  ('2-126517', 1),
#  ('serrano-palace-hotel', 1),
#  ('huyton', 1),
#  ('Stockett%20Ln%2C%20Coxheath%2C%20Maidstone%20ME17%204PS%2C%20UK', 1),
#  ('51.234,0.496', 1),
#  ('St%20Andrews%20Dr%2C%20Holmes%20Chapel%2C%20Crewe%20CW4%207DN%2C%20UK', 1),
#  ('53.198,-2.362', 1),
#  ('Springfields%2C%20Ticehurst%2C%20Wadhurst%20TN5%207BP%2C%20UK', 1),
#  ('51.047,0.411', 1),
#  ('reading-hearing', 1),
#  ('chippenham', 1),
#  ('cirencester', 1),
#  ('2-1606928-1', 1),
#  ('the-rose-revived-inn', 1),
#  ('urmston-hearing', 1),
#  ('ffbdfd1b-9bc5-4940-b2e3-f9f2da4f28fc', 1),
#  ('en-bg', 1),
#  ('Rackenford%2C%20Tiverton%20EX16%2C%20UK', 1),
#  ('50.951,-3.637', 1),
#  ('wellingborough', 1),
#  ('penrith', 1),
#  ('cb16b067-5727-4e4b-9935-08f90c2c3afa', 1),
#  ('38d11d10-eb22-4f0f-b35b-c80ff0c42725', 1),
#  ('506101', 1),
#  ('2-2026469-1', 1),
#  ('barcelo-corralejo-bay-adults-only', 1),
#  ('Boatman%20Dr%2C%20Stoke-on-Trent%20ST1%205PF%2C%20UK', 1),
#  ('53.017,-2.195', 1),
#  ('bradford', 1),
#  ('Oak%20Cl%2C%20Thorpe-le-Soken%2C%20Clacton-on-Sea%20CO16%200HU%2C%20UK', 1),
#  ('51.856,1.168', 1),
#  ('marlow', 1),
#  ('belfastpark', 1),
#  ('newcastleupontyne', 1),
#  ('cosham', 1),
#  ('honiton', 1),
#  ('Ayr%20KA8%2C%20UK', 1),
#  ('55.474,-4.611', 1),
#  ('en-GB', 1),
#  ('2-121578-1', 1),
#  ('paraiso-de-albufeira-apartments', 1),
#  ('2-1501874', 1),
#  ('hilton-barbados-resort', 1),
#  ('51.815606,-0.8084', 1),
#  ('largs', 1),
#  ('edgwareroad', 1),
#  ('chippenham-hearing', 1),
#  ('2-1604091-1', 1),
#  ('best-western-ipswich-hotel', 1),
#  ('hackney', 1),
#  ('Gouge%20Ave%2C%20Northfleet%2C%20Gravesend%20DA11%208DP%2C%20UK', 1),
#  ('51.436,0.346', 1),
#  ('gorseinon', 1),
#  ('ashbydelazouch-hearing', 1),
#  ('Windmill%20Ave%2C%20Kettering%20NN15%206PS%2C%20UK', 1),
#  ('52.389,-0.710', 1),
#  ('2-3778089-1', 1),
#  ('lara-park', 1),
#  ('2-3646275-1', 1),
#  ('titanic-deluxe-golf-belek', 1),
#  ('23%20Poplar%20Grove,%20Rugby%20CV21%202QR,%20UK', 1),
#  ('52.379036199999994,-1.2633503', 1),
#  ('19014e03-07c5-4a2b-a1aa-4e891d5d9fe7', 1),
#  ('2-289817-1', 1),
#  ('sunrise-holidays-resort-hotel', 1),
#  ('37518735', 1),
#  ('dunstablesainsburys', 1),
#  ('The%20Cl,%20Clifford%20Chambers,%20Stratford-upon-Avon%20CV37%208HS,%20UK',
#   1),
#  ('52.17,-1.7114', 1),
#  ('2-126066-1', 1),
#  ('deya', 1),
#  ('9c704f787e644aa57c2bbfc7ee5457e3', 1),
#  ('wilmslow-hearing', 1),
#  ('erith', 1),
#  ('talbotheathsainsburys', 1),
#  ('penge', 1),
#  ('epsom', 1),
#  ('ttf29ed', 1),
#  ('nottingham', 1),
#  ('2-230003-1', 1),
#  ('neptuno-calella-hotel-apartments', 1),
#  ('suttoncoldfield', 1),
#  ('Eighth%20Ave%2C%20Newcastle%20upon%20Tyne%20NE6%205YB%2C%20UK', 1),
#  ('54.984,-1.577', 1),
#  ('2-115467-1', 1),
#  ('natural-park-aparthotel', 1),
#  ('cowley', 1),
#  ('ipswich', 1),
#  ('Bristol%20BS5%2C%20UK', 1),
#  ('51.461,-2.553', 1),
#  ('fulham', 1),
#  ('2-114133-1', 1),
#  ('alpha-apartments', 1),
#  ('westhill', 1),
#  ('Cupar%20KY15%2C%20UK', 1),
#  ('56.320,-3.010', 1),
#  ('Alpha%20Rd%2C%20Crawley%20RH11%207BH%2C%20UK', 1),
#  ('51.115,-0.198', 1),
#  ('a633be45b8b74c5e5b687eaa26a1acf3', 1),
#  ('Plymouth%2C%20UK', 1),
#  ('50.375,-4.143', 1),
#  ('Wilderness%20Rd%2C%20Earley%2C%20Reading%20RG6%205RE%2C%20UK', 1),
#  ('51.437,-0.936', 1),
#  ('coulbynewham', 1),
#  ('Lichfield%20St%2C%20Fazeley%2C%20Tamworth%20B78%203QF%2C%20UK', 1),
#  ('52.617,-1.711', 1),
#  ('Gillingham%20ME7%2C%20UK', 1),
#  ('51.351,0.569', 1),
#  ('norwichststephensstreet-hearing', 1),
#  ('1705355', 1),
#  ('2-2004824-1', 1),
#  ('hotel-almond-holiday-village', 1),
#  ('headingley', 1),
#  ('Llangewydd%20Road%2C%20Bridgend%20CF31%204JW%2C%20UK', 1),
#  ('51.509,-3.587', 1),
#  ('2-273317', 1),
#  ('the-desert-rose-resort', 1),
#  ('egham-hearing', 1),
#  ('2-1605517-1', 1),
#  ('george-hotel-of-stamford', 1),
#  ('shipley-hearing', 1),
#  ('6191224f-e56d-4b14-8190-ba16f5e72a22', 1),
#  ('COCustomer-Start', 1),
#  ('Ruby%20Cottages%2C%20Rhydymwyn%2C%20Mold%20CH7%205QB%2C%20UK', 1),
#  ('53.199,-3.191', 1),
#  ('falmouth-hearing', 1),
#  ('51.5412621,-0.08813879999999999', 1),
#  ('bletchley', 1),
#  ('wrexham', 1),
#  ('0ebae2f41e76fb9d38ba8ca9fcbf2e9a', 1),
#  ('wokingham', 1),
#  ('newlands-hearing', 1),
#  ('reading', 1),
#  ('Keynsham%2C%20Bristol%2C%20UK', 1),
#  ('51.415,-2.503', 1),
#  ('42', 1),
#  ('667181888', 1),
#  ('completion-details', 1),
#  ('53.04304,-2.992494', 1),
#  ('2-126057-1', 1),
#  ('sol-house-the-studio-calvia-beach-adults-only', 1),
#  ('newtownards', 1),
#  ('burgesshill', 1),
#  ('horley-hearing', 1),
#  ('nuneaton-hearing', 1),
#  ('Newcastle%20upon%20Tyne%2C%20UK', 1),
#  ('54.978,-1.618', 1),
#  ('2-3771677', 1),
#  ('mabu-iloa-resort-residence', 1),
#  ('5886887-1614183156214032', 1),
#  ('Lloyd%20St%2C%20Altrincham%20WA14%202DD%2C%20UK', 1),
#  ('53.384,-2.351', 1),
#  ('Brant%20Rd%2C%20Waddington%2C%20Lincoln%20LN5%209AQ%2C%20UK', 1),
#  ('53.185,-0.559', 1),
#  ('Southway%2C%20Londonderry%20BT48%209SD%2C%20UK', 1),
#  ('54.989,-7.346', 1),
#  ('bellevale', 1),
#  ('coleraine', 1),
#  ('harrogate-hearing', 1),
#  ('hillsborough-hearing', 1),
#  ('crewe', 1),
#  ('broughton-hearing', 1),
#  ('London%20SE14%205PH%2C%20UK', 1),
#  ('51.474,-0.044', 1),
#  ('Basildon%2C%20UK', 1),
#  ('51.576,0.489', 1),
#  ('2-116892-1', 1),
#  ('medplaya-calypso', 1),
#  ('Birmingham%20B6%2C%20UK', 1),
#  ('52.512,-1.876', 1),
#  ('9%20Abbey%20Garth%20Wells%20Court%2C%20Yeadon%2C%20Leeds%20LS19%207RN%2C%20UK',
#   1),
#  ('53.865,-1.688', 1),
#  ('bridgend-hearing', 1),
#  ('990100010535027', 1),
#  ('Haymoor%2C%20Letchworth%20Garden%20City%20SG6%204HT%2C%20UK', 1),
#  ('51.986,-0.236', 1),
#  ('Bristol%20BS35%2C%20UK', 1),
#  ('51.604,-2.523', 1),
#  ('2-1389992-1', 1),
#  ('weetwood-hall-hotel', 1),
#  ('1706955', 1),
#  ('d5e81403d43b8fc0e960ab3ad5543716', 1),
#  ('2-5912400', 1),
#  ('asteria-zeus-didim', 1),
#  ('rothwell', 1),
#  ('990100010538605', 1),
#  ('a069596ab2ea49c9f3af3ed6761cab0b', 1),
#  ('7af079301a6ce5492f7e1d705e82bf2b', 1),
#  ('2-312518-1', 1),
#  ('samira-resort', 1),
#  ('holborn', 1),
#  ('2-122662-1', 1),
#  ('salmakis-resort-and-spa', 1),
#  ('bourne-hearing', 1),
#  ('droitwich', 1),
#  ('woodbridge-hearing', 1),
#  ('2-232215-1', 1),
#  ('ja-oasis-beach-tower', 1),
#  ('plymstock', 1),
#  ('br6olw', 1),
#  ('macclesfield-hearing', 1),
#  ('keighley', 1),
#  ('2-3087424', 1),
#  ('doubletree-chelsea', 1),
#  ('2-747729-1', 1),
#  ('elpida-hotel', 1),
#  ('2-314553', 1),
#  ('botel-racek-prague-hotel', 1),
#  ('peterlee', 1),
#  ('forms', 1),
#  ('test-drive-grid', 1),
#  ('surreyquays', 1),
#  ('2-1506159-1', 1),
#  ('fort-arabesque-resort-spa-villas', 1),
#  ('Saffron%20Walden%2C%20UK', 1),
#  ('52.023,0.239', 1),
#  ('2-1515492-1', 1),
#  ('nuria-sol-apartments', 1),
#  ('2-114960-1', 1),
#  ('la-jabega-apartments', 1),
#  ('colchester-hearing', 1),
#  ('2-282814-1', 1),
#  ('the-marmara-bodrum', 1),
#  ('Lawrence%20Hill%20Rd%2C%20Dartford%20DA1%203AG%2C%20UK', 1),
#  ('51.448,0.204', 1),
#  ('leicester', 1),
#  ('2-3264291', 1),
#  ('camping-village-roma', 1),
#  ('hedgeendsainsburys', 1),
#  ('purley-hearing', 1),
#  ('newmalden', 1),
#  ('burystedmunds-hearing', 1),
#  ('2-114940-1', 1),
#  ('palia-la-roca-hotel', 1),
#  ('tottenham', 1),
#  ('Shrewsbury%20SY2%2C%20UK', 1),
#  ('52.709,-2.722', 1),
#  ('derby', 1),
#  ('2-190368-1', 1),
#  ('alkyon-hotel', 1),
#  ('ba6ad260-7682-4bb3-9256-21c84a68ba4e', 1),
#  ('2-121509-1', 1),
#  ('tivoli-marina-vilamoura-hotel', 1),
#  ('worcester-hearing', 1),
#  ('feltham-hearing', 1),
#  ('1707398', 1),
#  ('bishopsgate', 1),
#  ('The%20Shires%2C%20Saint%20Helens%20WA10%203XL%2C%20UK', 1),
#  ('53.448,-2.745', 1),
#  ('gr', 1),
#  ('nelson', 1),
#  ('Ayr%2C%20UK', 1),
#  ('55.459,-4.629', 1),
#  ('Linton%20Cres%2C%20Hastings%20TN34%201TJ%2C%20UK', 1),
#  ('50.859,0.572', 1),
#  ('Darlington%20DL1%2C%20UK', 1),
#  ('54.545,-1.527', 1),
#  ('326MP0262', 1),
#  ('keynsham', 1),
#  ('cardiff', 1),
#  ('Hervey%20Cl%2C%20Finchley%2C%20London%20N3%202HD%2C%20UK', 1),
#  ('51.601,-0.190', 1),
#  ('Bede%20Cres%2C%20Benington%2C%20Boston%20PE22%200DZ%2C%20UK', 1),
#  ('52.998,0.077', 1),
#  ('huntingdon', 1),
#  ('clapham', 1),
#  ('crosby-hearing', 1),
#  ('1705769', 1),
#  ('2-4266970', 1),
#  ('laulasmaa-spa-and-conference-hotel', 1),
#  ('2-122687', 1),
#  ('liberty-hotels-oludeniz', 1),
#  ('Conolly%20Rd%2C%20Hanwell%2C%20London%20W7%203JW%2C%20UK', 1),
#  ('51.510,-0.342', 1),
#  ('d8d9f3fd23d326500adcd8a8f898c400', 1),
#  ('stonehaven', 1),
#  ('chelmsleywood', 1),
#  ('Corberry%20Park%2C%20Dumfries%20DG2%207NG%2C%20UK', 1),
#  ('55.065,-3.619', 1),
#  ('kendal-hearing', 1),
#  ('stockport', 1),
#  ('sheffield-hearing', 1),
#  ('Laurel%20St%2C%20Middlesbrough%20TS1%203DR%2C%20UK', 1),
#  ('54.572,-1.232', 1),
#  ('boltonsainsburys', 1),
#  ('serpentinegreen', 1),
#  ('2-4006676', 1),
#  ('movenpick-ambassador-hotel-accra', 1),
#  ('swindon-hearing', 1),
#  ('onestepcheckout', 1),
#  ('en-AU', 1),
#  ('belfastconnswater', 1),
#  ('woodley', 1),
#  ('990100010537147', 1),
#  ('HX0005843443', 1),
#  ('Hinckley%20LE10%2C%20UK', 1),
#  ('52.514,-1.343', 1),
#  ('2-113725-1', 1),
#  ('valle-del-este-golf-resort-hotel', 1),
#  ('Romilly%20Gardens%2C%20Ramsgate%20CT12%206TZ%2C%20UK', 1),
#  ('51.351,1.407', 1),
#  ('London%20SW15%203TX%2C%20UK', 1),
#  ('51.448,-0.230', 1),
#  ('2-116474-1', 1),
#  ('apartments-sol-parc', 1),
#  ('bf49317c-d386-4380-a987-3294a36853c4-990100010536463-990100010536701', 1),
#  ('chard-hearing', 1),
#  ('kilmarnock', 1),
#  ('burystedmunds', 1),
#  ('37373763', 1),
#  ('2-6815903-1', 1),
#  ('reethi-faru-resort', 1),
#  ('2-114976-1', 1),
#  ('pyr-fuengirola-hotel', 1),
#  ('17a%20Balham%20Grove,%20Balham,%20London%20SW12%208AZ,%20UK', 1),
#  ('51.44686174526714,-0.15204846537585587', 1),
#  ('newark-hearing', 1),
#  ('aberdare', 1),
#  ('hessle', 1),
#  ('fleet', 1),
#  ('b1675f87-b80f-4047-834c-7f4fdd84a9a7', 1),
#  ('peterborough', 1),
#  ('crawley-hearing', 1),
#  ('oadby', 1),
#  ('Castleford%20WF10%202JT%2C%20UK', 1),
#  ('53.733,-1.346', 1),
#  ('kilburn', 1),
#  ('2-323215-1', 1),
#  ('iberostar-rose-hall-beach-hotel', 1),
#  ('beverley', 1),
#  ('1705463', 1),
#  ('HX0005835415', 1),
#  ('50.508595199999995,-4.2369024', 1),
#  ('northfinchley', 1),
#  ('fe58de1d-5183-4217-993c-30d56b5bb958', 1),
#  ('Ashtree%20Ave%2C%20Mitcham%20CR4%203DS%2C%20UK', 1),
#  ('51.408,-0.175', 1),
#  ('byresroad', 1),
#  ('stourbridge', 1),
#  ('Southbrook%20Dr%2C%20Cheshunt%2C%20Waltham%20Cross%20EN8%200QJ%2C%20UK', 1),
#  ('51.714,-0.037', 1),
#  ('2-117403-1', 1),
#  ('gf-isabel', 1),
#  ('woodley-hearing', 1),
#  ('luton', 1),
#  ('Axminster%20Cres%2C%20Welling%20DA16%201HQ%2C%20UK', 1),
#  ('51.471,0.117', 1),
#  ('solihull', 1),
#  ('aberdeen', 1),
#  ('richmondkingstreet-hearing', 1),
#  ('folkestone', 1),
#  ('Wiveliscombe%2C%20Taunton%20TA4%202LW%2C%20UK', 1),
#  ('51.045,-3.310', 1),
#  ('brighton-hearing', 1),
#  ('clactononsea', 1),
#  ('2-118670', 1),
#  ('sani-asterias', 1),
#  ('falkirk', 1),
#  ('arnold', 1),
#  ('9935c401-cc5a-42e7-bffc-5fdba5dda689', 1),
#  ('westwaycross', 1),
#  ('stafford', 1),
#  ('malvern', 1),
#  ('hk', 1),
#  ('oakwood', 1),
#  ('50.817887,-0.49581', 1),
#  ('walthamcross', 1),
#  ('pembrokedock', 1),
#  ('strand', 1),
#  ('grangemouth-hearing', 1),
#  ('Compton%20Rd%2C%20Hilsea%2C%20Portsmouth%20PO2%200SP%2C%20UK', 1),
#  ('50.823,-1.066', 1),
#  ('ludlow', 1),
#  ('whiteley', 1),
#  ('Snows%20Hill%2C%20Tisbury%2C%20Salisbury%20SP3%206RY%2C%20UK', 1),
#  ('51.067,-2.075', 1),
#  ('gainsborough', 1),
#  ('reigate', 1),
#  ('2-189968-1', 1),
#  ('h10-marina-barcelona', 1),
#  ('harringaysainsburys', 1),
#  ('Stanley%20Webb%20Cl%2C%20Sawston%2C%20Cambridge%20CB22%203FE%2C%20UK', 1),
#  ('52.127,0.182', 1),
#  ('Queen%20Elizabeth%20Rd%2C%20Nuneaton%20CV10%209BU%2C%20UK', 1),
#  ('52.530,-1.510', 1),
#  ('warminster', 1),
#  ('girlington', 1),
#  ('Middlesbrough%20TS2%2C%20UK', 1),
#  ('54.609,-1.215', 1),
#  ('seaham', 1),
#  ('2-6853144-1', 1),
#  ('oblu-select-at-sangeli', 1),
#  ('fr_ch', 1),
#  ('2-312516-1', 1),
#  ('mirage-world-hotel', 1),
#  ('Cheltenham%20GL51%209RR%2C%20UK', 1),
#  ('51.918,-2.105', 1),
#  ('stonehaven-hearing', 1),
#  ('2-293288-1', 1),
#  ('st-jamess-club-morgan-bay-formerly-morgan-bay-resort', 1),
#  ('2%20Lancaster%20Terrace,%20Glasgow%20G12%200UT,%20UK', 1),
#  ('55.882,-4.3025', 1),
#  ('Cherry%20Tree%20Cl%2C%20Langstone%2C%20Newport%20NP18%202NL%2C%20UK', 1),
#  ('51.603,-2.913', 1),
#  ('sunderland', 1),
#  ('belper-hearing', 1),
#  ('2-118585-1', 1),
#  ('hermes-hotel', 1),
#  ('droitwich-hearing', 1),
#  ('f1ac82d1-a90a-43b3-acba-97d282474cf4-990100010531969-990100010531993', 1),
#  ('2-8394053', 1),
#  ('leda-suites', 1),
#  ('pages', 1),
#  ('ChooseAddressType_WC.aspx', 1),
#  ('Sites-zh-CN-Site', 1),
#  ('zh_CN', 1),
#  ('wakefield', 1),
#  ('Murray%20Rd%2C%20Rugby%20CV21%203JN%2C%20UK', 1),
#  ('52.373,-1.254', 1),
#  ('aberystwyth', 1),
#  ('11%20Western%20Rd%2C%20Romford%20RM1%203RL%2C%20UK', 1),
#  ('51.578,0.183', 1),
#  ('corby', 1),
#  ('leigh', 1),
#  ('Guisborough%20TS14%2C%20UK', 1),
#  ('54.536,-1.050', 1),
#  ('894589e2-d770-46bf-9334-ac8449015902-990100010552427-990100010552463', 1),
#  ('witham', 1),
#  ('Keighley%20Ave%2C%20Sunderland%20SR5%204BU%2C%20UK', 1),
#  ('54.931,-1.446', 1),
#  ('2-115026', 1),
#  ('aparthotel-monarque-sultan', 1),
#  ('2-2464521-1', 1),
#  ('london-blue-hotel', 1),
#  ('2-118668-1', 1),
#  ('sani-club', 1),
#  ('West%20End%2C%20London%20WC2H%2C%20UK', 1),
#  ('51.514,-0.126', 1),
#  ('newportshropshire', 1),
#  ('morden-hearing', 1),
#  ('1707859', 1),
#  ('Barnsley%2C%20UK', 1),
#  ('53.553,-1.480', 1),
#  ('northshields', 1),
#  ('romsey', 1),
#  ('Fiona%20Cl%2C%20Great%20Bookham%2C%20Leatherhead%20KT23%203JU%2C%20UK', 1),
#  ('51.286,-0.378', 1),
#  ('0e94d9331eb0af1b4199018e1876582f', 1),
#  ('1708929', 1),
#  ('wythenshawe', 1),
#  ('2-748864-1', 1),
#  ('atlantis-the-palm-dubai', 1),
#  ('burnley-hearing', 1),
#  ('bracknell', 1),
#  ('Wynyard%20Mews%2C%20Hartlepool%20TS25%203JF%2C%20UK', 1),
#  ('54.661,-1.241', 1),
#  ('HX0005842062', 1),
#  ('Fareham%20PO15%2C%20UK', 1),
#  ('50.871,-1.219', 1),
#  ('kidderminster-hearing', 1),
#  ('harlow-hearing', 1),
#  ('2-326923-1', 1),
#  ('dreams-beach-resort', 1),
#  ('larne', 1),
#  ('swinton', 1),
#  ('readingshinfieldroad-hearing', 1),
#  ('Dunnock%20Pl%2C%20Coatbridge%20ML5%204US%2C%20UK', 1),
#  ('55.847,-3.997', 1),
#  ('swansea', 1),
#  ('clear-vision-with-contact-lenses', 1),
#  ('kidderminster', 1),
#  ('Maidenhall%2C%20Luton%20LU4%208FF%2C%20UK', 1),
#  ('51.887,-0.444', 1),
#  ('tonbridge', 1),
#  ('2-5927925-1', 1),
#  ('titanic-deluxe-bodrum', 1),
#  ('2-2322157-1', 1),
#  ('vanilla-hotel', 1),
#  ('Bracknell%20RG12%2C%20UK', 1),
#  ('51.402,-0.748', 1),
#  ('atherstone', 1),
#  ('rhyl', 1),
#  ('shrewsbury', 1),
#  ('ealingbroadway-hearing', 1),
#  ('brochure-downloads', 1),
#  ('morningside', 1),
#  ('moorgate', 1),
#  ('en_FR', 1),
#  ('buxton-hearing', 1),
#  ('HX0005816118', 1),
#  ('towcester-hearing', 1),
#  ('Mycenae%20Rd%2C%20London%20SE3%207AX%2C%20UK', 1),
#  ('51.480,0.017', 1),
#  ('hull', 1),
#  ('Longbridge%2C%20Birmingham%20B31%2C%20UK', 1),
#  ('52.388,-1.978', 1),
#  ('canveyisland-hearing', 1),
#  ('2-189908-1', 1),
#  ('rixos-premium-tekirova', 1),
#  ('953556e8-8317-4112-bbe4-6fc14a986d15-990100010534196-990100010534201', 1),
#  ('990100010556007', 1),
#  ('derry', 1),
#  ('990100010535342', 1),
#  ('redditch', 1),
#  ('Bow%20Cottages%2C%20Sutton%2C%20Ely%20CB6%202RN%2C%20UK', 1),
#  ('52.387,0.133', 1),
#  ('Crowberry%20Dr%2C%20Harrogate%20HG3%202UF%2C%20UK', 1),
#  ('54.005,-1.571', 1),
#  ('heyfordhillsainsburys', 1),
#  ('chester-hearing', 1),
#  ('Whitsand%20Bay%20View%2C%20Portwrinkle%2C%20Torpoint%20PL11%203DB%2C%20UK',
#   1),
#  ('50.363,-4.312', 1),
#  ('St%20Clements%20Ct%2C%20Crooked%20Mile%2C%20Waltham%20Abbey%20EN9%201QB%2C%20UK',
#   1),
#  ('51.690,0.001', 1),
#  ('ashbournederby', 1),
#  ('newquay', 1),
#  ('Sites-RLEU_Sterling-Site', 1),
#  ('COBilling-Billing', 1),
#  ('wakefield-hearing', 1),
#  ('cleveleys', 1),
#  ('2-190074-1', 1),
#  ('los-pueblos-apartments', 1),
#  ('990100010551725', 1),
#  ('a29fa3a97b64629941ce6d5af69eff1c', 1),
#  ('purley', 1),
#  ('slough', 1),
#  ('334A006067', 1),
#  ('ayr', 1),
#  ('your-eye-health-pregnancy', 1),
#  ('enfieldsainsburys', 1),
#  ('Leigh%20Rd%2C%20Leigh%2C%20UK', 1),
#  ('53.512,-2.511', 1),
#  ('2-6828715-1', 1),
#  ('benidorm-city-olympia', 1),
#  ('westwickham', 1),
#  ('Hemel%20Hempstead%20HP1%202RR%2C%20UK', 1),
#  ('51.732,-0.538', 1),
#  ('dartford-hearing', 1),
#  ('2-6209434-1', 1),
#  ('the-st-regis-langkawi', 1),
#  ('Epsom%2C%20UK', 1),
#  ('51.336,-0.267', 1),
#  ('SO651447', 1),
#  ('13%20Watermark%20Cl,%20Sherwood,%20Nottingham%20NG5%201RL,%20UK', 1),
#  ('52.9771952,-1.1567342', 1),
#  ('Evelyn%20Rd%2C%20Bournemouth%20BH9%201SU%2C%20UK', 1),
#  ('50.750,-1.873', 1),
#  ('Worthing%20BN13%2C%20UK', 1),
#  ('50.855,-0.449', 1),
#  ('1709750', 1),
#  ('2-3278559-1', 1),
#  ('ja-ocean-view-hotel', 1),
#  ('washingtonsainsburys', 1),
#  ('Desborough%20Cres%2C%20Liverpool%20L12%207JT%2C%20UK', 1),
#  ('53.431,-2.913', 1),
#  ('2-124789-1', 1),
#  ('lexington-hotel-miami-beach', 1),
#  ('e4aee6ea-5640-4c1f-9c45-1c282f023f3f', 1),
#  ('birkenhead', 1),
#  ('Ilford%20IG1%2C%20UK', 1),
#  ('51.562,0.076', 1),
#  ('bodmin', 1),
#  ('Sandbanks%20Rd%2C%20Poole%20BH14%208JA%2C%20UK', 1),
#  ('50.705,-1.943', 1),
#  ('54.562582,-1.31237', 1),
#  ('Newcastle-under-Lyme%2C%20UK', 1),
#  ('53.013,-2.227', 1),
#  ('edit', 1),
#  ('daventry', 1),
#  ('HX0005486051', 1),
#  ('7b84ba90e3d7077190b128f237595986', 1),
#  ('2-290961-1', 1),
#  ('malhun-hotel', 1),
#  ('2-195556-1', 1),
#  ('esmeralda-beach-hotel', 1),
#  ('diss', 1),
#  ('ce9aaf82-3ff4-4402-aecd-346b317b5fc6', 1),
#  ('uxbridge', 1),
#  ('telford', 1),
#  ('brentwood', 1),
#  ('Salford%20M5%2C%20UK', 1),
#  ('53.480,-2.281', 1),
#  ('2-1490749-1', 1),
#  ('lux-south-ari-atoll', 1),
#  ('perth-hearing', 1),
#  ('armthorpe', 1),
#  ('cwmbran', 1),
#  ('Southall%20UB2%2C%20UK', 1),
#  ('51.499,-0.371', 1),
#  ('guernsey', 1),
#  ('1705404', 1),
#  ('saffronwalden', 1),
#  ('gloucester-hearing', 1),
#  ('2596a3babcda3502a716920de9d93aa8', 1),
#  ('whitechapel', 1),
#  ('whitechapel-hearing', 1),
#  ('havant-hearing', 1),
#  ('parkgate', 1),
#  ('2-2939838-1', 1),
#  ('las-americas-casa-de-playa', 1),
#  ('Canfield%20Gardens%2C%20London%20NW6%203EE%2C%20UK', 1),
#  ('51.544,-0.188', 1),
#  ('Swinton', 1),
#  ('53.512690000000,-2.338850000000', 1),
#  ('boscombe', 1),
#  ('wombwell', 1),
#  ('dcbc74d4-a343-42b2-b022-db4ffdf3bcc5', 1),
#  ('bridlington', 1),
#  ('lanark', 1),
#  ('HX0005789975', 1),
#  ('Nottingham%20NG12%2C%20UK', 1),
#  ('52.891,-1.021', 1),
#  ('beverley-hearing', 1),
#  ('Sites-SLP-NOAM-Site', 1),
#  ('37580046', 1),
#  ('Buckshaw%20Village%2C%20Chorley%20PR7%207FB%2C%20UK', 1),
#  ('53.680,-2.660', 1),
#  ('Swallownest%2C%20Sheffield%2C%20UK', 1),
#  ('53.363,-1.321', 1),
#  ('magherafelt', 1),
#  ('6d164ee6-59b5-4ac4-86fc-085b5b15b095', 1),
#  ('bishopauckland', 1),
#  ('Wylye%2C%20Warminster%20BA12%200RQ%2C%20UK', 1),
#  ('51.137,-1.989', 1),
#  ('Norwich%20NR12%2C%20UK', 1),
#  ('52.716,1.366', 1),
#  ('greenford', 1),
#  ('tottenhamcourtroad-hearing', 1),
#  ('Godalming%20GU7%2C%20UK', 1),
#  ('51.188,-0.618', 1),
#  ('CustomerLogin_WC.aspx', 1),
#  ('gravesend', 1),
#  ('harrogate', 1),
#  ('Lodge%20Ln%2C%20Romford%20RM5%202ET%2C%20UK', 1),
#  ('51.603,0.155', 1),
#  ('Eborall%20Cl%2C%20Warwick%20CV34%205QA%2C%20UK', 1),
#  ('52.297,-1.587', 1),
#  ('pontypool', 1),
#  ('fakenham', 1),
#  ('Urmston%2C%20UK', 1),
#  ('53.449,-2.375', 1),
#  ('portsmouth', 1),
#  ('derby-hearing', 1),
#  ('5%20Lennox%20Ave,%20Sidmouth%20EX10%208TX,%20UK', 1),
#  ('50.6837483,-3.2366381', 1),
#  ('springfieldsainsburys', 1),
#  ('2-126385-1', 1),
#  ('bq-alcudia-sun-village', 1),
#  ('Salford%20M50%2C%20UK', 1),
#  ('53.474,-2.294', 1),
#  ('pontypridd', 1),
#  ('solihull-hearing', 1),
#  ('uxbridge-hearing', 1),
#  ('990100010548042', 1),
#  ('15%20Bodmin%20St,%20Holsworthy%20EX22%206BB,%20UK', 1),
#  ('50.8092094,-4.3541036', 1),
#  ('poole-hearing', 1),
#  ('Fakenham%20NR21%2C%20UK', 1),
#  ('52.831,0.849', 1),
#  ('northwich-hearing', 1),
#  ('ringwood', 1),
#  ('315A022198', 1),
#  ('2-113655-1', 1),
#  ('spa-porta-maris-hotel', 1),
#  ('farnborough-hearing', 1),
#  ('b1ebe1e0-8b04-40eb-956b-7413055ffa4a', 1),
#  ('2-3691366-1', 1),
#  ('plantation-resort-residences-at-dorado-beach', 1),
#  ('accrington-hearing', 1),
#  ('brownhills-hearing', 1),
#  ('2-6175008-1', 1),
#  ('Gerrards%20Cross%2C%20UK', 1),
#  ('51.582,-0.557', 1),
#  ('1706918', 1),
#  ('en_de', 1),
#  ('bath', 1),
#  ('southport', 1),
#  ('en-pl', 1),
#  ('gylecentre-hearing', 1),
#  ('Emerson%20Way%2C%20Newton%20Aycliffe%20DL5%205HG%2C%20UK', 1),
#  ('54.615,-1.573', 1),
#  ('Pennard%20Rd%2C%20Shepherd%27s%20Bush%2C%20London%20W12%208DW%2C%20UK', 1),
#  ('51.504,-0.226', 1),
#  ('Didcot%20OX11%207HJ%2C%20UK', 1),
#  ('51.618,-1.255', 1),
#  ('midsomernorton', 1),
#  ('2-9504632-1', 1),
#  ('riu-atoll', 1),
#  ('clydebank', 1),
#  ('manchester-hearing', 1),
#  ('Fishers%20Way%2C%20Halberton%2C%20Tiverton%20EX16%207FG%2C%20UK', 1),
#  ('50.907,-3.422', 1),
#  ('2-4122339-1', 1),
#  ('augustus-village-antalya', 1),
#  ('2-120428-1', 1),
#  ('db-seabank-resort-spa-all-inclusive', 1),
#  ('2-116917-1', 1),
#  ('internacional-ii-apartments', 1),
#  ('2-1508705-1', 1),
#  ('cinnamon-hakuraa-huraa-maldives', 1),
#  ('parkfarmsainsburys-hearing', 1),
#  ('exeter', 1),
#  ('yardley', 1),
#  ('2-189657-1', 1),
#  ('the-three-corners-ocean-view-hotel', 1),
#  ('2-125177-1', 1),
#  ('comfort-inn-international-drive-hotel', 1),
#  ('05cf140cd37240187a117056c9bb86f6', 1),
#  ('longbridge', 1),
#  ('1709303', 1),
#  ('walthamstow', 1),
#  ('b03e6c5c7bda08d29842c1df469f5e4b', 1),
#  ('tewkesbury', 1),
#  ('2-316217-1', 1),
#  ('riu-palace-riviera-maya-hotel', 1),
#  ('2-7320267-1', 1),
#  ('pino-alto-apartment', 1),
#  ('ValideCommande', 1),
#  ('Moorhouses%20Rd%2C%20North%20Shields%20NE29%208BN%2C%20UK', 1),
#  ('55.019,-1.480', 1),
#  ('2-314506-1', 1),
#  ('maris-beach-hotel', 1),
#  ('Millerhill%2C%20Dalkeith%20EH22%201RZ%2C%20UK', 1),
#  ('55.915,-3.083', 1),
#  ('a9a468f53f719ca2f0d888ce410b5f63', 1),
#  ('bangor', 1),
#  ('2ff80dc9-e1b9-4daa-aff3-e69804e76612', 1),
#  ('trowbridge-hearing', 1),
#  ('didcot', 1),
#  ('hitchin-hearing', 1),
#  ('miltonkeynes-hearing', 1),
#  ('HX0005747836', 1),
#  ('2-7979979-1', 1),
#  ('vidamar-villas-apartments-and-guesthouse-sao-rafael', 1),
#  ('Quantock%20Mews%2C%20Peckham%2C%20London%20SE15%204RG%2C%20UK', 1),
#  ('51.469,-0.069', 1),
#  ('ammanford', 1),
#  ('Birmingham%20Rd%2C%20Wylde%20Green%2C%20Sutton%20Coldfield%20B72%201YJ%2C%20UK',
#   1),
#  ('52.535,-1.828', 1),
#  ('The%20St%2C%20Surlingham%2C%20Norwich%20NR14%207AJ%2C%20UK', 1),
#  ('52.609,1.424', 1),
#  ('Chelmsford%20CM2%200FW%2C%20UK', 1),
#  ('51.729,0.474', 1),
#  ('2-274391-1', 1),
#  ('starfish-jolly-beach-resort', 1)]

# %% [markdown]
# ## Feature ideas and design

# %% [markdown]
# **Idea**: there is a notion of specificity of a word with respect to a given category
#
# We will try to go through the dataset and find, for each atomic part (chunks) of the prefixes, to get the resulting distributions over all webpage categories. We might want to consider "relevant" chunks only, i.e. those that appear at least *threshold* times in the dataset. Let's set threshold=10

# %%
# Get an idea of how many meaningful path chunks there are

threshold = 10

all_path_chunks = [
        chunk
        for path, cat in zip(website_df["path"], website_df["category_name"])
        for chunk in path.split("/")
        if chunk
    ]

print(f"Total number of path chunks is {len(set(all_path_chunks))}")
filtered_path_chunks = [
    chunk
    for chunk, count in sorted(Counter(all_path_chunks).items(), key = lambda x: -x[1])
    if count >= threshold
]
print(f"Total number of relevant path chunks that occur at least 10 times is {len(filtered_path_chunks)}")
# Out:
# Total number of path chunks is 53017
# Total number of relevant path chunks that occur at least 10 times is 1651

# %%
# Proba of being a search page if "search" or "recherche" is in url is p_search("search") or p_search("recherche")
# -> could create an embedding emb("search") = [p_search("search"), p_product("search") etc]

from collections import defaultdict

chunk_to_category_counts = defaultdict(lambda: defaultdict(int))

for path, category in zip(website_df["path"], website_df["category_name"]):
    for chunk in path.split("/"):
        if not chunk or category not in ALL_CATEGORIES_SET:
            continue
        chunk_to_category_counts[chunk][category] += 1

chunk_to_category_scores = defaultdict(lambda: defaultdict(float))
for chunk, category_counts in chunk_to_category_counts.items():
    chunk_counts = sum(category_counts.values())
    if chunk_counts < 10:
        continue
    for category, count in category_counts.items():
        chunk_to_category_scores[chunk][category] = count/chunk_counts

pprint(chunk_to_category_scores)
# Out:
# defaultdict(<function <lambda> at 0x1407c4940>,
#             {'%D0%B6%D0%B5%D0%BD%D1%89%D0%B8%D0%BD%D1%8B': defaultdict(<class 'float'>,
#                                                                        {'Category': 0.1,
#                                                                         'Product': 0.9}),
#              '%D0%BC%D1%83%D0%B6%D1%87%D0%B8%D0%BD%D1%8B': defaultdict(<class 'float'>,
#                                                                        {'Category': 0.2727272727272727,
#                                                                         'Product': 0.7272727272727273}),
#              '%D0%BE%D0%B4%D0%B5%D0%B6%D0%B4%D0%B0': defaultdict(<class 'float'>,
#                                                                  {'Category': 0.08333333333333333,
#                                                                   'Product': 0.9166666666666666}),
#              '%E3%82%A6%E3%82%A3%E3%83%A1%E3%83%B3%E3%82%BA': defaultdict(<class 'float'>,
#                                                                           {'Brand image': 0.05263157894736842,
#                                                                            'Category': 0.05263157894736842,
#                                                                            'Product': 0.8947368421052632}),
#              '%E3%82%A6%E3%82%A7%E3%82%A2': defaultdict(<class 'float'>,
#                                                         {'Category': 0.22727272727272727,
#                                                          'Product': 0.7727272727272727}),
#              '%E3%82%AA%E3%83%B3%E3%83%A9%E3%82%A4%E3%83%B3%E3%82%B9%E3%83%88%E3%82%A2---%E3%82%A6%E3%82%A3%E3%83%A1%E3%83%B3%E3%82%BA': defaultdict(<class 'float'>,
#                                                                                                                                                      {'Category': 1.0}),
#              '%E3%83%90%E3%83%83%E3%82%B0': defaultdict(<class 'float'>,
#                                                         {'Category': 0.71875,
#                                                          'Product': 0.28125}),
#              '%E3%83%A1%E3%83%B3%E3%82%BA': defaultdict(<class 'float'>,
#                                                         {'Brand image': 0.030303030303030304,
#                                                          'Category': 0.5151515151515151,
#                                                          'Product': 0.45454545454545453}),
#              '%E3%83%AC%E3%82%B6%E3%83%BC%E3%82%B0%E3%83%83%E3%82%BA': defaultdict(<class 'float'>,
#                                                                                    {'Category': 1.0}),
#              '%E3%83%AC%E3%83%87%E3%82%A3%E3%83%BC%E3%82%B9': defaultdict(<class 'float'>,
#                                                                           {'Category': 0.7894736842105263,
#                                                                            'Product': 0.21052631578947367}),
#              '%E4%BA%AE%E8%82%A4': defaultdict(<class 'float'>,
#                                                {'Product': 1.0}),
#              '%E5%8C%96%E5%A6%86%E5%93%81': defaultdict(<class 'float'>,
#                                                         {'Product': 1.0}),
#              '%E5%93%81%E7%89%8C': defaultdict(<class 'float'>,
#                                                {'Category': 1.0}),
#              '%E5%A5%B3%E5%A3%AB': defaultdict(<class 'float'>,
#                                                {'Brand image': 0.041666666666666664,
#                                                 'Category': 0.5416666666666666,
#                                                 'Product': 0.4166666666666667}),
#              '%E5%A5%B3%E8%A3%9D': defaultdict(<class 'float'>,
#                                                {'Brand image': 0.07692307692307693,
#                                                 'Category': 0.23076923076923078,
#                                                 'Product': 0.6923076923076923}),
#              '%E5%AE%B6%E7%94%A8%E9%A6%99%E6%B0%B4%E9%A6%99%E6%B0%9B': defaultdict(<class 'float'>,
#                                                                                    {'Product': 1.0}),
#              '%E6%88%90%E8%A1%A3': defaultdict(<class 'float'>,
#                                                {'Category': 0.3,
#                                                 'Product': 0.7}),
#              '%E6%89%8B%E8%A2%8B': defaultdict(<class 'float'>,
#                                                {'Category': 0.5,
#                                                 'Product': 0.5}),
#              '%E6%8A%A4%E7%90%86%E4%BA%A7%E5%93%81': defaultdict(<class 'float'>,
#                                                                  {'Product': 1.0}),
#              '%E6%8A%A4%E8%82%A4%E5%93%81': defaultdict(<class 'float'>,
#                                                         {'Product': 1.0}),
#              '%E6%97%A5%E9%97%B4%E6%B6%A6%E8%82%A4%E4%B9%B3': defaultdict(<class 'float'>,
#                                                                           {'Product': 1.0}),
#              '%E6%B6%A6%E8%82%A4%E4%B9%B3': defaultdict(<class 'float'>,
#                                                         {'Product': 1.0}),
#              '%E8%B2%A1%E5%B8%83%EF%BC%86%E5%B0%8F%E7%89%A9-%E3%82%A6%E3%82%A3%E3%83%A1%E3%83%B3%E3%82%B9%E3%82%99': defaultdict(<class 'float'>,
#                                                                                                                                  {'Category': 0.6666666666666666,
#                                                                                                                                   'Product': 0.3333333333333333}),
#              '%E9%A6%99%E6%B0%B4%E9%A6%99%E6%B0%9B': defaultdict(<class 'float'>,
#                                                                  {'Product': 1.0}),
#              '%EA%B0%80%EB%B0%A9': defaultdict(<class 'float'>,
#                                                {'Category': 0.3,
#                                                 'Product': 0.7}),
#              '%EB%82%A8%EC%9E%90': defaultdict(<class 'float'>,
#                                                {'Category': 1.0}),
#              '%EC%97%AC%EC%84%B1': defaultdict(<class 'float'>,
#                                                {'Category': 0.6153846153846154,
#                                                 'Product': 0.38461538461538464}),
#              '%EC%97%AC%EC%84%B1-%EC%87%BC%ED%95%91': defaultdict(<class 'float'>,
#                                                                   {'Category': 1.0}),
#              '-': defaultdict(<class 'float'>,
#                               {'Cart': 0.64,
#                                'Checkout': 0.32,
#                                'My account': 0.04}),
#              '0': defaultdict(<class 'float'>, {'My account': 1.0}),
#              '01': defaultdict(<class 'float'>, {'Press / news': 1.0}),
#              '01000000': defaultdict(<class 'float'>,
#                                      {'Category': 0.4166666666666667,
#                                       'Product': 0.5833333333333334}),
#              '02': defaultdict(<class 'float'>, {'Press / news': 1.0}),
#              '03': defaultdict(<class 'float'>, {'Press / news': 1.0}),
#              '04150000': defaultdict(<class 'float'>,
#                                      {'Category': 0.07692307692307693,
#                                       'Product': 0.9230769230769231}),
#              '06': defaultdict(<class 'float'>, {'Press / news': 1.0}),
#              '08': defaultdict(<class 'float'>, {'Press / news': 1.0}),
#              '09': defaultdict(<class 'float'>, {'Press / news': 1.0}),
#              '1': defaultdict(<class 'float'>,
#                               {'Cart': 0.05555555555555555,
#                                'Category': 0.6296296296296297,
#                                'Checkout': 0.018518518518518517,
#                                'My account': 0.07407407407407407,
#                                'Product': 0.2222222222222222}),
#              '10': defaultdict(<class 'float'>,
#                                {'Category': 0.04395604395604396,
#                                 'Formations / services': 0.08791208791208792,
#                                 'Press / news': 0.14285714285714285,
#                                 'Product': 0.4945054945054945,
#                                 'Search': 0.23076923076923078}),
#              '10000000': defaultdict(<class 'float'>, {'Product': 1.0}),
#              '10101': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '1020': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '10201': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '10202': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '10204': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '11': defaultdict(<class 'float'>,
#                                {'Formations / services': 0.16666666666666666,
#                                 'Press / news': 0.36666666666666664,
#                                 'Product': 0.4666666666666667}),
#              '12': defaultdict(<class 'float'>,
#                                {'Formations / services': 0.14285714285714285,
#                                 'Press / news': 0.8095238095238095,
#                                 'Product': 0.047619047619047616}),
#              '155595': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '2': defaultdict(<class 'float'>,
#                               {'Category': 0.18840579710144928,
#                                'Formations / services': 0.7681159420289855,
#                                'Press / news': 0.028985507246376812,
#                                'Product': 0.014492753623188406}),
#              '2-stroke': defaultdict(<class 'float'>, {'Product': 1.0}),
#              '20101': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '2017': defaultdict(<class 'float'>, {'Press / news': 1.0}),
#              '2018': defaultdict(<class 'float'>,
#                                  {'Other': 0.04,
#                                   'Press / news': 0.96}),
#              '2019': defaultdict(<class 'float'>,
#                                  {'Information / legals': 0.02631578947368421,
#                                   'Press / news': 0.9736842105263158}),
#              '2020': defaultdict(<class 'float'>,
#                                  {'Category': 0.14925373134328357,
#                                   'Information / legals': 0.014925373134328358,
#                                   'Press / news': 0.835820895522388}),
#              '202023': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '2021': defaultdict(<class 'float'>, {'Press / news': 1.0}),
#              '21011': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '2101717': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '21033': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '290037.html': defaultdict(<class 'float'>, {'Product': 1.0}),
#              '3': defaultdict(<class 'float'>,
#                               {'Category': 0.08108108108108109,
#                                'Formations / services': 0.8378378378378378,
#                                'Press / news': 0.05405405405405406,
#                                'Product': 0.02702702702702703}),
#              '4': defaultdict(<class 'float'>,
#                               {'Category': 0.17647058823529413,
#                                'Formations / services': 0.6470588235294118,
#                                'Press / news': 0.11764705882352941,
#                                'Product': 0.058823529411764705}),
#              '4-stroke': defaultdict(<class 'float'>, {'Product': 1.0}),
#              '5': defaultdict(<class 'float'>,
#                               {'Category': 0.2903225806451613,
#                                'Formations / services': 0.6129032258064516,
#                                'Press / news': 0.0967741935483871}),
#              '6': defaultdict(<class 'float'>,
#                               {'Category': 0.2727272727272727,
#                                'Formations / services': 0.7272727272727273}),
#              '7': defaultdict(<class 'float'>,
#                               {'Category': 0.08333333333333333,
#                                'Formations / services': 0.75,
#                                'Press / news': 0.08333333333333333,
#                                'Product': 0.08333333333333333}),
#              '7-reasons-first-birthday-gift-unique-unicorn': defaultdict(<class 'float'>,
#                                                                          {'Brand image': 1.0}),
#              '70101': defaultdict(<class 'float'>, {'Category': 1.0}),
#              '911545': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'ACM': defaultdict(<class 'float'>,
#                                 {'Confirmation': 0.38095238095238093,
#                                  'Other': 0.6190476190476191}),
#              'AYGO': defaultdict(<class 'float'>,
#                                  {'Confirmation': 0.6,
#                                   'Product': 0.4}),
#              'Account': defaultdict(<class 'float'>, {'My account': 1.0}),
#              'Account-PostRegister': defaultdict(<class 'float'>,
#                                                  {'My account': 1.0}),
#              'Account-StartRegister': defaultdict(<class 'float'>,
#                                                   {'My account': 0.1,
#                                                    'Other': 0.9}),
#              'Basket': defaultdict(<class 'float'>, {'Cart': 1.0}),
#              'C-HR': defaultdict(<class 'float'>,
#                                  {'Confirmation': 0.4090909090909091,
#                                   'Product': 0.5909090909090909}),
#              'CH': defaultdict(<class 'float'>,
#                                {'Cart': 0.017432646592709985,
#                                 'Category': 0.3724247226624406,
#                                 'Confirmation': 0.001584786053882726,
#                                 'Favorites / wishlist': 0.001584786053882726,
#                                 'Home': 0.060221870047543584,
#                                 'My account': 0.006339144215530904,
#                                 'Other': 0.025356576862123614,
#                                 'Product': 0.45800316957210774,
#                                 'Search': 0.05705229793977813}),
#              'COSummary-Confirmation': defaultdict(<class 'float'>,
#                                                    {'Confirmation': 1.0}),
#              'Cart': defaultdict(<class 'float'>, {'Cart': 1.0}),
#              'Cart-AddToWishlist': defaultdict(<class 'float'>, {'Other': 1.0}),
#              'Cart-AddToWishlistAndRemove': defaultdict(<class 'float'>,
#                                                         {'Cart': 1.0}),
#              'Catrice-DE-Site': defaultdict(<class 'float'>,
#                                             {'Cart': 0.5833333333333334,
#                                              'Checkout': 0.3333333333333333,
#                                              'My account': 0.08333333333333333}),
#              'Cerca': defaultdict(<class 'float'>, {'Search': 1.0}),
#              'ChangeModeLivraison': defaultdict(<class 'float'>, {'Cart': 1.0}),
#              'Checkout': defaultdict(<class 'float'>,
#                                      {'Checkout': 0.5670103092783505,
#                                       'Confirmation': 0.422680412371134,
#                                       'Information / legals': 0.010309278350515464}),
#              'Confirmation': defaultdict(<class 'float'>,
#                                          {'Checkout': 0.5176470588235295,
#                                           'Confirmation': 0.4823529411764706}),
#              'Corolla-HB': defaultdict(<class 'float'>,
#                                        {'Confirmation': 0.5454545454545454,
#                                         'Product': 0.45454545454545453}),
#              'CreditCards-List': defaultdict(<class 'float'>, {'Other': 1.0}),
#              'CustomerPasswordChange_WC.aspx': defaultdict(<class 'float'>,
#                                                            {'Checkout': 1.0}),
#              'CustomiseCards.aspx': defaultdict(<class 'float'>,
#                                                 {'Product': 1.0}),
#              'CustomiseCardsMobile.aspx': defaultdict(<class 'float'>,
#                                                       {'Product': 1.0}),
#              'DashboardRedesign': defaultdict(<class 'float'>,
#                                               {'My account': 1.0}),
#              'Dashboardredesign': defaultdict(<class 'float'>,
#                                               {'My account': 1.0}),
#              'DeliveryDetailsView': defaultdict(<class 'float'>,
#                                                 {'Checkout': 1.0}),
#              'EUR': defaultdict(<class 'float'>,
#                                 {'Cart': 0.64,
#                                  'Checkout': 0.32,
#                                  'My account': 0.04}),
#              'Essence-DE-Site': defaultdict(<class 'float'>,
#                                             {'Cart': 0.6923076923076923,
#                                              'Checkout': 0.3076923076923077}),
#              'FULL999': defaultdict(<class 'float'>, {'Confirmation': 1.0}),
#              'Hilux': defaultdict(<class 'float'>,
#                                   {'Confirmation': 0.5,
#                                    'Product': 0.5}),
#              'Home': defaultdict(<class 'float'>, {'My account': 1.0}),
#              'HostedPaymentPage': defaultdict(<class 'float'>,
#                                               {'Checkout': 1.0}),
#              'INTERSHOP': defaultdict(<class 'float'>,
#                                       {'Cart': 0.64,
#                                        'Checkout': 0.32,
#                                        'My account': 0.04}),
#              'Index': defaultdict(<class 'float'>,
#                                   {'Category': 0.1518987341772152,
#                                    'Other': 0.004219409282700422,
#                                    'Search': 0.8438818565400844}),
#              'Login': defaultdict(<class 'float'>,
#                                   {'Cart': 0.011764705882352941,
#                                    'My account': 0.9882352941176471}),
#              'MCart-Show': defaultdict(<class 'float'>, {'Cart': 1.0}),
#              'MCheckout-FormHandler': defaultdict(<class 'float'>,
#                                                   {'Checkout': 1.0}),
#              'MCheckout-Start': defaultdict(<class 'float'>,
#                                             {'Checkout': 0.8571428571428571,
#                                              'My account': 0.14285714285714285}),
#              'MCheckout-ThankYouPage': defaultdict(<class 'float'>,
#                                                    {'Confirmation': 1.0}),
#              'My-Saved-Items': defaultdict(<class 'float'>,
#                                            {'Favorites / wishlist': 1.0}),
#              'MyOrderHistory.aspx': defaultdict(<class 'float'>,
#                                                 {'My account': 1.0}),
#              'OnePageCheckout': defaultdict(<class 'float'>,
#                                             {'Cart': 0.31645569620253167,
#                                              'Checkout': 0.6075949367088608,
#                                              'Confirmation': 0.0759493670886076}),
#              'Order-History': defaultdict(<class 'float'>, {'My account': 1.0}),
#              'Order-Orders': defaultdict(<class 'float'>,
#                                          {'My account': 0.96,
#                                           'Other': 0.04}),
#              'Order-Orderstatus': defaultdict(<class 'float'>,
#                                               {'My account': 0.9411764705882353,
#                                                'Other': 0.058823529411764705}),
#              'Pages': defaultdict(<class 'float'>,
#                                   {'Cart': 0.026785714285714284,
#                                    'Category': 0.049107142857142856,
#                                    'Checkout': 0.12053571428571429,
#                                    'My account': 0.08035714285714286,
#                                    'Other': 0.008928571428571428,
#                                    'Product': 0.7142857142857143}),
#              'PaymentDetailsView': defaultdict(<class 'float'>,
#                                                {'Checkout': 1.0}),
#              'Proace': defaultdict(<class 'float'>,
#                                    {'Confirmation': 0.21428571428571427,
#                                     'Product': 0.7857142857142857}),
#              'RAV4': defaultdict(<class 'float'>,
#                                  {'Confirmation': 0.4117647058823529,
#                                   'Product': 0.5882352941176471}),
#              'Recherche': defaultdict(<class 'float'>, {'Search': 1.0}),
#              'RequireLogin-Show': defaultdict(<class 'float'>,
#                                               {'My account': 1.0}),
#              'RetourPaypal': defaultdict(<class 'float'>, {'Checkout': 1.0}),
#              'Search': defaultdict(<class 'float'>,
#                                    {'Brand image': 0.0034071550255536627,
#                                     'Category': 0.131175468483816,
#                                     'My account': 0.005110732538330494,
#                                     'Other': 0.0017035775127768314,
#                                     'Search': 0.858603066439523}),
#              'SearchDisplay': defaultdict(<class 'float'>, {'Search': 1.0}),
#              'ShopCartDisplayView': defaultdict(<class 'float'>, {'Cart': 1.0}),
#              'Sites-IKKS_COM-Site': defaultdict(<class 'float'>,
#                                                 {'Cart': 0.3402061855670103,
#                                                  'Checkout': 0.030927835051546393,
#                                                  'Confirmation': 0.6185567010309279,
#                                                  'Other': 0.010309278350515464}),
#              'Sites-SLP-WEUR-Site': defaultdict(<class 'float'>,
#                                                 {'Brand image': 0.5333333333333333,
#                                                  'Checkout': 0.3333333333333333,
#                                                  'My account': 0.13333333333333333}),
#              'Sites-de-DE-Site': defaultdict(<class 'float'>,
#                                              {'Checkout': 0.08333333333333333,
#                                               'Confirmation': 0.4166666666666667,
#                                               'Favorites / wishlist': 0.0625,
#                                               'My account': 0.375,
#                                               'Other': 0.0625}),
#              'Sites-en-CA-Site': defaultdict(<class 'float'>,
#                                              {'Confirmation': 0.29411764705882354,
#                                               'My account': 0.47058823529411764,
#                                               'Other': 0.23529411764705882}),
#              'Sites-en-GB-Site': defaultdict(<class 'float'>,
#                                              {'Checkout': 0.3463203463203463,
#                                               'Confirmation': 0.47186147186147187,
#                                               'Favorites / wishlist': 0.004329004329004329,
#                                               'My account': 0.10822510822510822,
#                                               'Other': 0.06493506493506493,
#                                               'Store locator': 0.004329004329004329}),
#              'Sites-en-SG-Site': defaultdict(<class 'float'>,
#                                              {'Cart': 0.4444444444444444,
#                                               'Checkout': 0.3888888888888889,
#                                               'Confirmation': 0.05555555555555555,
#                                               'My account': 0.1111111111111111}),
#              'Sites-en-US-Site': defaultdict(<class 'float'>,
#                                              {'Checkout': 0.06666666666666667,
#                                               'Confirmation': 0.3238095238095238,
#                                               'Home': 0.009523809523809525,
#                                               'My account': 0.4857142857142857,
#                                               'Other': 0.11428571428571428}),
#              'Sites-fr-FR-Site': defaultdict(<class 'float'>,
#                                              {'Checkout': 0.2857142857142857,
#                                               'Confirmation': 0.375,
#                                               'My account': 0.17857142857142858,
#                                               'Other': 0.16071428571428573}),
#              'Sites-it-IT-Site': defaultdict(<class 'float'>,
#                                              {'Checkout': 0.19047619047619047,
#                                               'Confirmation': 0.19047619047619047,
#                                               'Favorites / wishlist': 0.023809523809523808,
#                                               'Home': 0.023809523809523808,
#                                               'My account': 0.38095238095238093,
#                                               'Other': 0.19047619047619047}),
#              'Sites-nl-NL-Site': defaultdict(<class 'float'>,
#                                              {'Confirmation': 0.15384615384615385,
#                                               'Home': 0.07692307692307693,
#                                               'My account': 0.6153846153846154,
#                                               'Other': 0.15384615384615385}),
#              'Sites-pl-PL-Site': defaultdict(<class 'float'>,
#                                              {'Checkout': 0.05714285714285714,
#                                               'Confirmation': 0.2,
#                                               'Favorites / wishlist': 0.11428571428571428,
#                                               'My account': 0.5142857142857142,
#                                               'Other': 0.11428571428571428}),
#              'Sites-spacenkgb-Site': defaultdict(<class 'float'>,
#                                                  {'Confirmation': 0.4,
#                                                   'Other': 0.6}),
#              'Stores': defaultdict(<class 'float'>,
#                                    {'My account': 0.03225806451612903,
#                                     'Store locator': 0.967741935483871}),
#              'ThankYou': defaultdict(<class 'float'>,
#                                      {'Checkout': 0.4,
#                                       'Confirmation': 0.6}),
#              'UI': defaultdict(<class 'float'>, {'My account': 1.0}),
#              'User': defaultdict(<class 'float'>,
#                                  {'Cart': 0.18181818181818182,
#                                   'My account': 0.8181818181818182}),
#              'ViewData-Start': defaultdict(<class 'float'>,
#                                            {'Cart': 0.64,
#                                             'Checkout': 0.32,
#                                             'My account': 0.04}),
#              'W0OO4141': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO7064S': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO7070S': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO7105S': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO9013': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO9102': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO9188': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO9208': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO9263': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO9265': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO9295': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO9406': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'W0OO9440': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'WFS': defaultdict(<class 'float'>,
#                                 {'Cart': 0.64,
#                                  'Checkout': 0.32,
#                                  'My account': 0.04}),
#              'Yaris': defaultdict(<class 'float'>,
#                                   {'Confirmation': 0.3870967741935484,
#                                    'Product': 0.6129032258064516}),
#              'Zoeken': defaultdict(<class 'float'>, {'Search': 1.0}),
#              '__': defaultdict(<class 'float'>,
#                                {'Home': 0.24248496993987975,
#                                 'Other': 0.11823647294589178,
#                                 'Product': 0.6392785571142284}),
#              '_cs_': defaultdict(<class 'float'>,
#                                  {'Formations / services': 1.0}),
#              'a': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'a-faire-pousser': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'a-faire-soi-meme': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'abbigliamento': defaultdict(<class 'float'>,
#                                           {'Brand image': 0.030303030303030304,
#                                            'Category': 0.8787878787878788,
#                                            'Product': 0.09090909090909091}),
#              'abc-for-you-book': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'about-pandora': defaultdict(<class 'float'>,
#                                           {'Brand image': 1.0}),
#              'about-us': defaultdict(<class 'float'>,
#                                      {'Category': 0.3,
#                                       'Information / legals': 0.2,
#                                       'Other': 0.1,
#                                       'Press / news': 0.2,
#                                       'Product': 0.2}),
#              'accessoires': defaultdict(<class 'float'>,
#                                         {'Cart': 0.031746031746031744,
#                                          'Category': 0.6984126984126984,
#                                          'Other': 0.015873015873015872,
#                                          'Product': 0.25396825396825395}),
#              'accessoires.html': defaultdict(<class 'float'>,
#                                              {'Category': 0.9090909090909091,
#                                               'Other': 0.09090909090909091}),
#              'accessori': defaultdict(<class 'float'>,
#                                       {'Category': 0.7142857142857143,
#                                        'Product': 0.2857142857142857}),
#              'accessories': defaultdict(<class 'float'>,
#                                         {'Category': 0.4888558692421991,
#                                          'Other': 0.0014858841010401188,
#                                          'Press / news': 0.0014858841010401188,
#                                          'Product': 0.5081723625557206}),
#              'accessories-for-men': defaultdict(<class 'float'>,
#                                                 {'Category': 0.20422535211267606,
#                                                  'Product': 0.795774647887324}),
#              'accessories-for-women': defaultdict(<class 'float'>,
#                                                   {'Category': 0.3574660633484163,
#                                                    'Product': 0.6425339366515838}),
#              'accessories.html': defaultdict(<class 'float'>,
#                                              {'Category': 0.9444444444444444,
#                                               'Other': 0.05555555555555555}),
#              'accommodation': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'account': defaultdict(<class 'float'>,
#                                     {'Cart': 0.007853403141361256,
#                                      'Form': 0.002617801047120419,
#                                      'My account': 0.9869109947643979,
#                                      'Other': 0.002617801047120419}),
#              'account-registration': defaultdict(<class 'float'>,
#                                                  {'My account': 0.3,
#                                                   'Other': 0.7}),
#              'accueil': defaultdict(<class 'float'>, {'Home': 1.0}),
#              'activewear': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'activewear.html': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'add-to-cart-popin': defaultdict(<class 'float'>, {'Cart': 1.0}),
#              'advancedsearchresults.aspx': defaultdict(<class 'float'>,
#                                                        {'Category': 1.0}),
#              'advice': defaultdict(<class 'float'>,
#                                    {'Information / legals': 1.0}),
#              'ae': defaultdict(<class 'float'>,
#                                {'Category': 0.18181818181818182,
#                                 'Confirmation': 0.11363636363636363,
#                                 'Form': 0.022727272727272728,
#                                 'Home': 0.11363636363636363,
#                                 'My account': 0.022727272727272728,
#                                 'Product': 0.5227272727272727,
#                                 'Search': 0.022727272727272728}),
#              'afa': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'afspraak': defaultdict(<class 'float'>, {'Other': 1.0}),
#              'ain': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'air-purifiers': defaultdict(<class 'float'>,
#                                           {'Formations / services': 1.0}),
#              'airbrush-flawless-finish-powder-MUK200024651.html': defaultdict(<class 'float'>,
#                                                                               {'Product': 1.0}),
#              'aisne': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'all-beds': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'all-glasses': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'all-sale': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'all-sale.html': defaultdict(<class 'float'>,
#                                           {'Cart': 0.05555555555555555,
#                                            'Category': 0.9444444444444444}),
#              'all-sunglasses': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'alle-anzeigen': defaultdict(<class 'float'>,
#                                           {'Category': 0.9583333333333334,
#                                            'Product': 0.041666666666666664}),
#              'alle-anzeigen.html': defaultdict(<class 'float'>,
#                                                {'Category': 0.971830985915493,
#                                                 'Other': 0.028169014084507043}),
#              'allier': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'alpes-de-haute-provence': defaultdict(<class 'float'>,
#                                                     {'Product': 1.0}),
#              'alpes-maritimes': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'amend': defaultdict(<class 'float'>,
#                                   {'Category': 0.10638297872340426,
#                                    'Checkout': 0.48936170212765956,
#                                    'Confirmation': 0.3404255319148936,
#                                    'Other': 0.06382978723404255}),
#              'analyze': defaultdict(<class 'float'>,
#                                     {'Home': 0.008871989860583017,
#                                      'Product': 0.991128010139417}),
#              'anniversary-cards': defaultdict(<class 'float'>,
#                                               {'Category': 1.0}),
#              'appareils-sommeil': defaultdict(<class 'float'>,
#                                               {'Product': 1.0}),
#              'apparel': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'apple': defaultdict(<class 'float'>,
#                                   {'Formations / services': 1.0}),
#              'appointment-triage-questionnaire': defaultdict(<class 'float'>,
#                                                              {'Checkout': 1.0}),
#              'appointment-type': defaultdict(<class 'float'>,
#                                              {'Category': 0.07981220657276995,
#                                               'Checkout': 0.92018779342723}),
#              'archive-sale': defaultdict(<class 'float'>,
#                                          {'Category': 0.3611111111111111,
#                                           'Product': 0.6388888888888888}),
#              'archive-sale.html': defaultdict(<class 'float'>,
#                                               {'Category': 1.0}),
#              'ardeche': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'ariege': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'armbaender': defaultdict(<class 'float'>, {'Brand image': 1.0}),
#              'art-supplies': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'article': defaultdict(<class 'float'>,
#                                     {'Formations / services': 0.8759124087591241,
#                                      'Press / news': 0.040875912408759124,
#                                      'Product': 0.08321167883211679}),
#              'articles': defaultdict(<class 'float'>,
#                                      {'Formations / services': 0.13253012048192772,
#                                       'Help / support': 0.7650602409638554,
#                                       'Information / legals': 0.0963855421686747,
#                                       'Product': 0.006024096385542169}),
#              'artist-paint': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'at': defaultdict(<class 'float'>,
#                                {'Cart': 0.010526315789473684,
#                                 'Category': 0.29473684210526313,
#                                 'Home': 0.042105263157894736,
#                                 'Information / legals': 0.021052631578947368,
#                                 'My account': 0.010526315789473684,
#                                 'Product': 0.6,
#                                 'Search': 0.021052631578947368}),
#              'attractions': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'au': defaultdict(<class 'float'>,
#                                {'Brand image': 0.05411764705882353,
#                                 'Cart': 0.004705882352941176,
#                                 'Category': 0.16,
#                                 'Checkout': 0.002352941176470588,
#                                 'Confirmation': 0.02588235294117647,
#                                 'Help / support': 0.007058823529411765,
#                                 'Home': 0.19294117647058823,
#                                 'My account': 0.011764705882352941,
#                                 'Other': 0.007058823529411765,
#                                 'Press / news': 0.004705882352941176,
#                                 'Product': 0.44941176470588234,
#                                 'Search': 0.07529411764705882,
#                                 'Store locator': 0.004705882352941176}),
#              'aude': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'australia': defaultdict(<class 'float'>,
#                                       {'Category': 0.75,
#                                        'Offers & services': 0.15,
#                                        'Product': 0.1}),
#              'autoverzekering-simuleren': defaultdict(<class 'float'>,
#                                                       {'Information / legals': 1.0}),
#              'auvergne-rhone-alpes': defaultdict(<class 'float'>,
#                                                  {'Category': 0.001584786053882726,
#                                                   'Product': 0.9984152139461173}),
#              'aveyron': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'aygo-promo': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'az-magazines': defaultdict(<class 'float'>,
#                                          {'Category': 0.03056768558951965,
#                                           'Product': 0.9694323144104804}),
#              'az-single-issues': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'b': defaultdict(<class 'float'>,
#                               {'Category': 0.15384615384615385,
#                                'Product': 0.8461538461538461}),
#              'baby': defaultdict(<class 'float'>,
#                                  {'Category': 0.28888888888888886,
#                                   'Product': 0.7111111111111111}),
#              'baby-boy-size-4m-4y.html': defaultdict(<class 'float'>,
#                                                      {'Category': 1.0}),
#              'baby-girls-size-4m-4y.html': defaultdict(<class 'float'>,
#                                                        {'Category': 0.9090909090909091,
#                                                         'Other': 0.09090909090909091}),
#              'baby-jungen-gr-68-104.html': defaultdict(<class 'float'>,
#                                                        {'Category': 1.0}),
#              'baby-maedchen-gr-68-104.html': defaultdict(<class 'float'>,
#                                                          {'Category': 1.0}),
#              'backpacks': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'bademode.html': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'bags': defaultdict(<class 'float'>,
#                                  {'Category': 0.4246575342465753,
#                                   'Product': 0.5753424657534246}),
#              'bags-and-clutches': defaultdict(<class 'float'>,
#                                               {'Category': 0.875,
#                                                'Form': 0.025,
#                                                'My account': 0.075,
#                                                'Other': 0.025}),
#              'bags-and-small-leather-goods': defaultdict(<class 'float'>,
#                                                          {'Category': 0.9142857142857143,
#                                                           'Form': 0.014285714285714285,
#                                                           'My account': 0.05714285714285714,
#                                                           'Other': 0.014285714285714285}),
#              'bags-and-wallets': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'bags-for-men': defaultdict(<class 'float'>,
#                                          {'Category': 0.09090909090909091,
#                                           'Product': 0.9090909090909091}),
#              'bags-man': defaultdict(<class 'float'>,
#                                      {'Category': 0.5,
#                                       'Product': 0.5}),
#              'bags-woman': defaultdict(<class 'float'>,
#                                        {'Category': 0.5,
#                                         'Product': 0.5}),
#              'bagues': defaultdict(<class 'float'>,
#                                    {'Category': 0.29411764705882354,
#                                     'My account': 0.058823529411764705,
#                                     'Product': 0.6470588235294118}),
#              'baguette': defaultdict(<class 'float'>,
#                                      {'Category': 0.5,
#                                       'Product': 0.5}),
#              'baking': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'balloons-and-helium': defaultdict(<class 'float'>,
#                                                 {'Category': 1.0}),
#              'bambini': defaultdict(<class 'float'>,
#                                     {'Category': 0.5,
#                                      'Product': 0.5}),
#              'barbecues': defaultdict(<class 'float'>,
#                                       {'Formations / services': 1.0}),
#              'bas-rhin': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'basics': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'basics.html': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'basket': defaultdict(<class 'float'>,
#                                    {'Cart': 0.9830508474576272,
#                                     'Formations / services': 0.01694915254237288}),
#              'basket-overview.html': defaultdict(<class 'float'>,
#                                                  {'Cart': 1.0}),
#              'bath-body': defaultdict(<class 'float'>,
#                                       {'Category': 0.09259259259259259,
#                                        'Product': 0.9074074074074074}),
#              'be': defaultdict(<class 'float'>,
#                                {'Cart': 0.05194805194805195,
#                                 'Category': 0.30735930735930733,
#                                 'Checkout': 0.008658008658008658,
#                                 'Home': 0.030303030303030304,
#                                 'My account': 0.008658008658008658,
#                                 'Product': 0.5454545454545454,
#                                 'Search': 0.04329004329004329,
#                                 'Store locator': 0.004329004329004329}),
#              'beauty': defaultdict(<class 'float'>,
#                                    {'Category': 0.3023255813953488,
#                                     'Product': 0.6976744186046512}),
#              'beds': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'bedtime-for-name-book': defaultdict(<class 'float'>,
#                                                   {'Product': 1.0}),
#              'bekleidung': defaultdict(<class 'float'>,
#                                        {'Cart': 0.01282051282051282,
#                                         'Category': 0.5641025641025641,
#                                         'Product': 0.4230769230769231}),
#              'belts': defaultdict(<class 'float'>,
#                                   {'Category': 0.8222222222222222,
#                                    'My account': 0.022222222222222223,
#                                    'Product': 0.15555555555555556}),
#              'belts-and-belt-bags': defaultdict(<class 'float'>,
#                                                 {'Category': 0.16666666666666666,
#                                                  'Product': 0.8333333333333334}),
#              'belts-for-men': defaultdict(<class 'float'>,
#                                           {'Category': 0.041666666666666664,
#                                            'Product': 0.9583333333333334}),
#              'belts-for-women': defaultdict(<class 'float'>,
#                                             {'Category': 0.025,
#                                              'Product': 0.975}),
#              'belts-for-women-c-women-accessories-belts': defaultdict(<class 'float'>,
#                                                                       {'Category': 1.0}),
#              'benefits-and-pensions': defaultdict(<class 'float'>,
#                                                   {'Formations / services': 1.0}),
# ...
#                                 'Form': 0.0006212466349140609,
#                                 'Help / support': 0.0010354110581901014,
#                                 'Home': 0.11762269621039553,
#                                 'Information / legals': 0.0012424932698281218,
#                                 'My account': 0.010975357216815076,
#                                 'Offers & services': 0.007869124042244772,
#                                 'Other': 0.010768275005177056,
#                                 'Press / news': 0.002277904328018223,
#                                 'Product': 0.47194036032304826,
#                                 'Search': 0.0898736798509008,
#                                 'Store locator': 0.010768275005177056}),
#              'us_en': defaultdict(<class 'float'>,
#                                   {'Cart': 0.10150375939849623,
#                                    'Category': 0.3458646616541353,
#                                    'My account': 0.022556390977443608,
#                                    'Product': 0.4924812030075188,
#                                    'Search': 0.03759398496240601}),
#              'usa': defaultdict(<class 'float'>,
#                                 {'Category': 0.5116279069767442,
#                                  'Offers & services': 0.3023255813953488,
#                                  'Product': 0.18604651162790697}),
#              'used-car-details': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'used-cars': defaultdict(<class 'float'>,
#                                       {'Category': 0.8,
#                                        'Store locator': 0.2}),
#              'used-ford-fiesta': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'used-ford-focus': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'used-ford-kuga': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'used-vans-results': defaultdict(<class 'float'>,
#                                               {'Category': 1.0}),
#              'user': defaultdict(<class 'float'>, {'My account': 1.0}),
#              'uvery': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'ux': defaultdict(<class 'float'>,
#                                {'Category': 0.56,
#                                 'Product': 0.44}),
#              'v3': defaultdict(<class 'float'>,
#                                {'Category': 0.48109965635738833,
#                                 'Confirmation': 0.006872852233676976,
#                                 'My account': 0.08247422680412371,
#                                 'Other': 0.004581901489117984,
#                                 'Product': 0.424971363115693}),
#              'vacuum-cleaners': defaultdict(<class 'float'>,
#                                             {'Formations / services': 1.0}),
#              'van-hire': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'var': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'vaucluse': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'veilleuses': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'vendee': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'ver-todo': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'vests': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'video': defaultdict(<class 'float'>,
#                                   {'Other': 0.00423728813559322,
#                                    'Product': 0.9957627118644068}),
#              'vienne': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'vietnam': defaultdict(<class 'float'>,
#                                     {'Category': 0.4,
#                                      'Offers & services': 0.5,
#                                      'Product': 0.1}),
#              'view': defaultdict(<class 'float'>,
#                                  {'Cart': 0.03571428571428571,
#                                   'Confirmation': 0.17857142857142858,
#                                   'My account': 0.6785714285714286,
#                                   'Other': 0.10714285714285714}),
#              'view-all': defaultdict(<class 'float'>,
#                                      {'Category': 0.9850746268656716,
#                                       'Product': 0.014925373134328358}),
#              'view-all-designer-glasses': defaultdict(<class 'float'>,
#                                                       {'Category': 1.0}),
#              'view-all.html': defaultdict(<class 'float'>,
#                                           {'Category': 0.952755905511811,
#                                            'Other': 0.047244094488188976}),
#              'vlastna-karta': defaultdict(<class 'float'>,
#                                           {'Information / legals': 0.26666666666666666,
#                                            'Product': 0.7333333333333333}),
#              'vm-vouchers': defaultdict(<class 'float'>, {'My account': 1.0}),
#              'voertuig': defaultdict(<class 'float'>,
#                                      {'Information / legals': 1.0}),
#              'voiture': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'vosges': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'vyhladavanie': defaultdict(<class 'float'>, {'Search': 1.0}),
#              'vyhledavani': defaultdict(<class 'float'>, {'Search': 1.0}),
#              'wallets-and-small-accessories-for-men': defaultdict(<class 'float'>,
#                                                                   {'Category': 0.11428571428571428,
#                                                                    'Product': 0.8857142857142857}),
#              'wallets-and-small-accessories-for-women': defaultdict(<class 'float'>,
#                                                                     {'Category': 0.06666666666666667,
#                                                                      'Product': 0.9333333333333333}),
#              'wallets-and-small-accessories-for-women-c-women-accessories-wallets': defaultdict(<class 'float'>,
#                                                                                                 {'Category': 1.0}),
#              'wallets-small-accessories': defaultdict(<class 'float'>,
#                                                       {'Product': 1.0}),
#              'washer-dryers': defaultdict(<class 'float'>,
#                                           {'Formations / services': 1.0}),
#              'washing-machines': defaultdict(<class 'float'>,
#                                              {'Formations / services': 1.0}),
#              'watch-v2': defaultdict(<class 'float'>, {'Other': 1.0}),
#              'watches': defaultdict(<class 'float'>,
#                                     {'Category': 0.275,
#                                      'Product': 0.725}),
#              'watches-for-women': defaultdict(<class 'float'>,
#                                               {'Product': 1.0}),
#              'web': defaultdict(<class 'float'>,
#                                 {'Cart': 0.64,
#                                  'Checkout': 0.32,
#                                  'My account': 0.04}),
#              'welcome.html': defaultdict(<class 'float'>, {'Home': 1.0}),
#              'whats-new': defaultdict(<class 'float'>,
#                                       {'Category': 0.9846153846153847,
#                                        'Product': 0.015384615384615385}),
#              'where-are-you-2-book': defaultdict(<class 'float'>,
#                                                  {'Product': 1.0}),
#              'where-are-you-book': defaultdict(<class 'float'>,
#                                                {'Product': 1.0}),
#              'which-best-buy-microwaves': defaultdict(<class 'float'>,
#                                                       {'Formations / services': 1.0}),
#              'which-best-buy-printers-and-ink': defaultdict(<class 'float'>,
#                                                             {'Formations / services': 1.0}),
#              'which-best-buy-washing-machines': defaultdict(<class 'float'>,
#                                                             {'Formations / services': 1.0}),
#              'which-brand-2': defaultdict(<class 'float'>,
#                                           {'Formations / services': 1.0}),
#              'which-reveals-the-best-and-worst-supermarkets-of-2021': defaultdict(<class 'float'>,
#                                                                                   {'Press / news': 1.0}),
#              'whichwills': defaultdict(<class 'float'>,
#                                        {'Formations / services': 1.0}),
#              'wi-fi-routers-and-extenders': defaultdict(<class 'float'>,
#                                                         {'Formations / services': 1.0}),
#              'wide-belts-for-women': defaultdict(<class 'float'>,
#                                                  {'Product': 1.0}),
#              'wills': defaultdict(<class 'float'>,
#                                   {'Formations / services': 1.0}),
#              'winkelzoeker': defaultdict(<class 'float'>,
#                                          {'Other': 0.045454545454545456,
#                                           'Product': 0.022727272727272728,
#                                           'Store locator': 0.9318181818181818}),
#              'wireless-and-bluetooth-speakers': defaultdict(<class 'float'>,
#                                                             {'Formations / services': 1.0}),
#              'wishlist': defaultdict(<class 'float'>,
#                                      {'Favorites / wishlist': 0.4074074074074074,
#                                       'My account': 0.1111111111111111,
#                                       'Other': 0.48148148148148145}),
#              'wishlistadd': defaultdict(<class 'float'>, {'Other': 1.0}),
#              'woman': defaultdict(<class 'float'>,
#                                   {'Brand image': 0.0625,
#                                    'Category': 0.0859375,
#                                    'Product': 0.8515625}),
#              'woman-bags': defaultdict(<class 'float'>,
#                                        {'Category': 0.48717948717948717,
#                                         'Product': 0.5128205128205128}),
#              'women': defaultdict(<class 'float'>,
#                                   {'Brand image': 0.001610305958132045,
#                                    'Cart': 0.001610305958132045,
#                                    'Category': 0.4044168391994479,
#                                    'Form': 0.00023004370830457787,
#                                    'My account': 0.002070393374741201,
#                                    'Other': 0.0027605244996549345,
#                                    'Product': 0.5866114561766735,
#                                    'Search': 0.0006901311249137336}),
#              'women.html': defaultdict(<class 'float'>,
#                                        {'Category': 0.8833333333333333,
#                                         'Home': 0.1,
#                                         'My account': 0.016666666666666666}),
#              'womens': defaultdict(<class 'float'>,
#                                    {'Category': 0.3076923076923077,
#                                     'Product': 0.6923076923076923}),
#              'womens-accessories': defaultdict(<class 'float'>,
#                                                {'Category': 0.7,
#                                                 'Product': 0.3}),
#              'womens-glasses': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'womens-handbags': defaultdict(<class 'float'>,
#                                             {'Category': 0.09090909090909091,
#                                              'Product': 0.9090909090909091}),
#              'womens-handbags-c-women-handbags': defaultdict(<class 'float'>,
#                                                              {'Category': 1.0}),
#              'womens-hobos-shoulder-bags': defaultdict(<class 'float'>,
#                                                        {'Product': 1.0}),
#              'womens-shoes': defaultdict(<class 'float'>,
#                                          {'Category': 0.2,
#                                           'Product': 0.8}),
#              'womens-small-leather-goods': defaultdict(<class 'float'>,
#                                                        {'Category': 0.23529411764705882,
#                                                         'Product': 0.7647058823529411}),
#              'womens-small-leather-goods-c-women-small-leather-goods': defaultdict(<class 'float'>,
#                                                                                    {'Category': 1.0}),
#              'womens-small-leathergoods': defaultdict(<class 'float'>,
#                                                       {'Category': 0.25,
#                                                        'Product': 0.75}),
#              'womenswear': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'wonen': defaultdict(<class 'float'>,
#                                   {'Information / legals': 1.0}),
#              'workflow': defaultdict(<class 'float'>,
#                                      {'Confirmation': 0.413265306122449,
#                                       'Product': 0.5867346938775511}),
#              'world': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'world-of-rl': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'world-of-valentino': defaultdict(<class 'float'>,
#                                                {'Brand image': 1.0}),
#              'wx': defaultdict(<class 'float'>,
#                                {'Category': 0.23076923076923078,
#                                 'Home': 0.038461538461538464,
#                                 'Product': 0.7307692307692307}),
#              'yarn': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'yoga-gym-douce': defaultdict(<class 'float'>,
#                                            {'Category': 0.02702702702702703,
#                                             'Product': 0.972972972972973}),
#              'yonne': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'you-love-mummy-book': defaultdict(<class 'float'>,
#                                                 {'Product': 1.0}),
#              'your-appointment': defaultdict(<class 'float'>,
#                                              {'Checkout': 0.8,
#                                               'Store locator': 0.2}),
#              'your-basket': defaultdict(<class 'float'>, {'Cart': 1.0}),
#              'zh': defaultdict(<class 'float'>,
#                                {'Brand image': 0.0744466800804829,
#                                 'Category': 0.01006036217303823,
#                                 'Home': 0.05432595573440644,
#                                 'My account': 0.002012072434607646,
#                                 'Press / news': 0.01609657947686117,
#                                 'Product': 0.7987927565392354,
#                                 'Search': 0.028169014084507043,
#                                 'Store locator': 0.01609657947686117}),
#              'zh_hk': defaultdict(<class 'float'>,
#                                   {'Brand image': 0.10909090909090909,
#                                    'Category': 0.21818181818181817,
#                                    'Other': 0.01818181818181818,
#                                    'Product': 0.5272727272727272,
#                                    'Search': 0.10909090909090909,
#                                    'Store locator': 0.01818181818181818}),
#              'zimmer': defaultdict(<class 'float'>, {'Category': 1.0}),
#              'zoek.html': defaultdict(<class 'float'>, {'Search': 1.0}),
#              'zoning-v2': defaultdict(<class 'float'>, {'Product': 1.0})})

# %% [markdown]
# **N.B.**<br>
# Those probabilities may be biased because categories are unbalanced. Actually, if the word "car" has been seen 250 times within the "Product" category and 100 times within the "Career & applications" category, this does not mean that "car" is a bigger clue towards "Product" because the "Product" category appears more than 2.5 times more than the "Career & applications" category. Thus, for "car", we might consider 250 vs 100 or 250/prior_proba("Product") vs 100/prior_proba("Career & applications"). This motivates the creation of two modes ("unbalanced" and "balanced") later in the notebook

# %% [markdown]
# **Idea**: could be the same for urls

# %%
# Proba of belonging to the "search" category given the website/prefix is p'_search(prefix)
# -> could create a second embedding emb'("search") = [p'_search(prefix), p'_product(prefix) etc]

from collections import defaultdict

prefix_to_category_counts = defaultdict(lambda: defaultdict(int))

for prefix, category in zip(website_df["prefix"], website_df["category_name"]):
    if not prefix or category not in all_categories:
        continue
    prefix_to_category_counts[prefix][category] += 1

prefix_to_category_scores = defaultdict(lambda: defaultdict(float))
for prefix, category_counts in prefix_to_category_counts.items():
    prefix_counts = sum(category_counts.values())
    for category, count in category_counts.items():
        prefix_to_category_scores[prefix][category] = count/prefix_counts
pprint(prefix_to_category_scores)
# Out:
# defaultdict(<function <lambda> at 0x133bee160>,
#             {'accv-www.cosstores.com': defaultdict(<class 'float'>,
#                                                    {'Product': 1.0}),
#              'action.which.co.uk': defaultdict(<class 'float'>,
#                                                {'Formations / services': 1.0}),
#              'app.contentsquare.com': defaultdict(<class 'float'>,
#                                                   {'Home': 0.24652087475149106,
#                                                    'Other': 0.1172962226640159,
#                                                    'Product': 0.6361829025844931}),
#              'archives.ikks.com': defaultdict(<class 'float'>, {'Home': 1.0}),
#              'asm.hm.com': defaultdict(<class 'float'>, {'Other': 1.0}),
#              'at.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.125,
#                                             'Cart': 0.1875,
#                                             'Checkout': 0.125,
#                                             'Home': 0.375,
#                                             'My account': 0.125,
#                                             'Search': 0.0625}),
#              'au.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.07814761215629522,
#                                             'Cart': 0.0824891461649783,
#                                             'Checkout': 0.04486251808972504,
#                                             'Confirmation': 0.01447178002894356,
#                                             'Favorites / wishlist': 0.004341534008683068,
#                                             'Home': 0.5282199710564399,
#                                             'Information / legals': 0.013024602026049204,
#                                             'My account': 0.04486251808972504,
#                                             'Other': 0.027496382054992764,
#                                             'Search': 0.15629522431259044,
#                                             'Store locator': 0.005788712011577424}),
#              'bacs.toyota.fr': defaultdict(<class 'float'>,
#                                            {'Appointments / booking': 1.0}),
#              'buy-now.trustford.co.uk': defaultdict(<class 'float'>,
#                                                     {'Checkout': 1.0}),
#              'ca.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.09270216962524655,
#                                             'Cart': 0.13214990138067062,
#                                             'Checkout': 0.11045364891518737,
#                                             'Confirmation': 0.01972386587771203,
#                                             'Favorites / wishlist': 0.0039447731755424065,
#                                             'Home': 0.3609467455621302,
#                                             'My account': 0.09467455621301775,
#                                             'Other': 0.07889546351084813,
#                                             'Search': 0.10650887573964497}),
#              'campaigns.which.co.uk': defaultdict(<class 'float'>,
#                                                   {'Formations / services': 1.0}),
#              'ccv2-d1-storefront.dreams.co.uk': defaultdict(<class 'float'>,
#                                                             {'Home': 1.0}),
#              'ccv2-s1-storefront.dreams.co.uk': defaultdict(<class 'float'>,
#                                                             {'Confirmation': 0.2222222222222222,
#                                                              'Favorites / wishlist': 0.1111111111111111,
#                                                              'Product': 0.6666666666666666}),
#              'checkout73.magazinesdirect.com': defaultdict(<class 'float'>,
#                                                            {'Confirmation': 1.0}),
#              'cm.pr-3749.staging.audleytravel.com': defaultdict(<class 'float'>,
#                                                                 {'Category': 1.0}),
#              'cn.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.08888888888888889,
#                                             'Cart': 0.022222222222222223,
#                                             'Home': 0.5777777777777777,
#                                             'My account': 0.044444444444444446,
#                                             'Other': 0.022222222222222223,
#                                             'Press / news': 0.022222222222222223,
#                                             'Search': 0.2222222222222222}),
#              'computing.which.co.uk': defaultdict(<class 'float'>,
#                                                   {'Formations / services': 1.0}),
#              'configurator.ktm.com': defaultdict(<class 'float'>,
#                                                  {'Category': 1.0}),
#              'conversation.which.co.uk': defaultdict(<class 'float'>,
#                                                      {'Formations / services': 1.0}),
#              'customerwealth.oldmutualwealth.co.uk': defaultdict(<class 'float'>,
#                                                                  {'My account': 1.0}),
#              'de.ikks.com': defaultdict(<class 'float'>,
#                                         {'Confirmation': 0.03278688524590164,
#                                          'Home': 0.01639344262295082,
#                                          'My account': 0.06557377049180328,
#                                          'Product': 0.8852459016393442}),
#              'de.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.11512415349887133,
#                                             'Cart': 0.11512415349887133,
#                                             'Checkout': 0.17155756207674944,
#                                             'Confirmation': 0.045146726862302484,
#                                             'Favorites / wishlist': 0.006772009029345372,
#                                             'Home': 0.28893905191873587,
#                                             'My account': 0.14672686230248308,
#                                             'Other': 0.045146726862302484,
#                                             'Press / news': 0.004514672686230248,
#                                             'Search': 0.05191873589164785,
#                                             'Store locator': 0.009029345372460496}),
#              'dev-au.pandora.net': defaultdict(<class 'float'>,
#                                                {'Confirmation': 1.0}),
#              'dev-de.pandora.net': defaultdict(<class 'float'>,
#                                                {'Checkout': 1.0}),
#              'dev-fr.pandora.net': defaultdict(<class 'float'>,
#                                                {'Checkout': 1.0}),
#              'dev-hk.pandora.net': defaultdict(<class 'float'>,
#                                                {'Search': 1.0}),
#              'dev-it.pandora.net': defaultdict(<class 'float'>,
#                                                {'Cart': 0.5,
#                                                 'Confirmation': 0.5}),
#              'dev-jp.pandora.net': defaultdict(<class 'float'>,
#                                                {'Confirmation': 1.0}),
#              'dev-nl.pandora.net': defaultdict(<class 'float'>, {'Cart': 1.0}),
#              'dev-nz.pandora.net': defaultdict(<class 'float'>, {'Cart': 1.0}),
#              'dev-sg.pandora.net': defaultdict(<class 'float'>,
#                                                {'Checkout': 1.0}),
#              'dev-uk.pandora.net': defaultdict(<class 'float'>,
#                                                {'Brand image': 0.1,
#                                                 'Cart': 0.3,
#                                                 'Checkout': 0.2,
#                                                 'Home': 0.3,
#                                                 'My account': 0.1}),
#              'dev-us.pandora.net': defaultdict(<class 'float'>,
#                                                {'Cart': 0.5,
#                                                 'Home': 0.5}),
#              'dev-ww.ysl.com': defaultdict(<class 'float'>,
#                                            {'Category': 0.1111111111111111,
#                                             'Checkout': 0.2222222222222222,
#                                             'Home': 0.3333333333333333,
#                                             'My account': 0.2222222222222222,
#                                             'Other': 0.1111111111111111}),
#              'dev.funkypigeon.com': defaultdict(<class 'float'>,
#                                                 {'Product': 1.0}),
#              'dev.quilter.com': defaultdict(<class 'float'>,
#                                             {'Information / legals': 1.0}),
#              'dev.quilterfinancialplanning.co.uk': defaultdict(<class 'float'>,
#                                                                {'Category': 0.6666666666666666,
#                                                                 'Information / legals': 0.3333333333333333}),
#              'dev.thereforyou.quilter.com': defaultdict(<class 'float'>,
#                                                         {'Information / legals': 1.0}),
#              'dev07-usestore-pandora.demandware.net': defaultdict(<class 'float'>,
#                                                                   {'Home': 0.5,
#                                                                    'Other': 0.5}),
#              'dev08-apacestore-pandora.demandware.net': defaultdict(<class 'float'>,
#                                                                     {'Checkout': 1.0}),
#              'dev08-pandora-pfsweb.demandware.net': defaultdict(<class 'float'>,
#                                                                 {'Cart': 1.0}),
#              'dev13-usestore-pandora.demandware.net': defaultdict(<class 'float'>,
#                                                                   {'Home': 1.0}),
#              'dev20-usestore-pandora.demandware.net': defaultdict(<class 'float'>,
#                                                                   {'Checkout': 0.5,
#                                                                    'Other': 0.5}),
#              'developer.tomtom.com': defaultdict(<class 'float'>,
#                                                  {'Checkout': 0.4444444444444444,
#                                                   'Product': 0.2222222222222222,
#                                                   'Search': 0.3333333333333333}),
#              'dk.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.14285714285714285,
#                                             'Cart': 0.02857142857142857,
#                                             'Checkout': 0.2,
#                                             'Home': 0.45714285714285713,
#                                             'My account': 0.14285714285714285,
#                                             'Store locator': 0.02857142857142857}),
#              'drm-s-www.ms.ycs.io': defaultdict(<class 'float'>,
#                                                 {'Other': 1.0}),
#              'educateurs.lumni.fr': defaultdict(<class 'float'>,
#                                                 {'Other': 1.0}),
#              'fr.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.12277227722772277,
#                                             'Cart': 0.13663366336633664,
#                                             'Checkout': 0.17623762376237623,
#                                             'Confirmation': 0.041584158415841586,
#                                             'Favorites / wishlist': 0.0019801980198019802,
#                                             'Home': 0.29108910891089107,
#                                             'My account': 0.11089108910891089,
#                                             'Other': 0.027722772277227723,
#                                             'Press / news': 0.0039603960396039604,
#                                             'Search': 0.07722772277227723,
#                                             'Store locator': 0.009900990099009901}),
#              'gardening.which.co.uk': defaultdict(<class 'float'>,
#                                                   {'Formations / services': 1.0}),
#              'help.tomtom.com': defaultdict(<class 'float'>,
#                                             {'Help / support': 1.0}),
#              'hk.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.2,
#                                             'Cart': 0.04,
#                                             'Checkout': 0.12,
#                                             'Home': 0.04,
#                                             'Information / legals': 0.08,
#                                             'My account': 0.16,
#                                             'Search': 0.36}),
#              'industrie.honda.fr': defaultdict(<class 'float'>,
#                                                {'Information / legals': 1.0}),
#              'integration.thekooples.com': defaultdict(<class 'float'>,
#                                                        {'Cart': 0.25,
#                                                         'Category': 0.25,
#                                                         'Confirmation': 0.5}),
#              'it.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.13416536661466458,
#                                             'Cart': 0.11076443057722309,
#                                             'Checkout': 0.07956318252730109,
#                                             'Confirmation': 0.0109204368174727,
#                                             'Favorites / wishlist': 0.0093603744149766,
#                                             'Home': 0.38221528861154447,
#                                             'My account': 0.11544461778471139,
#                                             'Other': 0.0421216848673947,
#                                             'Press / news': 0.0015600624024961,
#                                             'Search': 0.10764430577223089,
#                                             'Store locator': 0.0062402496099844}),
#              'jardin.honda.fr': defaultdict(<class 'float'>,
#                                             {'Information / legals': 0.8571428571428571,
#                                              'Product': 0.14285714285714285}),
#              'jobs.ktm.com': defaultdict(<class 'float'>,
#                                          {'Careers & applications': 1.0}),
#              'jobs.which.co.uk': defaultdict(<class 'float'>,
#                                              {'Careers & applications': 1.0}),
#              'join.which.co.uk': defaultdict(<class 'float'>,
#                                              {'Confirmation': 1.0}),
#              'jp.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.2972972972972973,
#                                             'Cart': 0.02702702702702703,
#                                             'Checkout': 0.08108108108108109,
#                                             'Home': 0.40540540540540543,
#                                             'My account': 0.05405405405405406,
#                                             'Press / news': 0.02702702702702703,
#                                             'Search': 0.10810810810810811}),
#              'kenai-develop.prod.marketing-az.tomtom.com': defaultdict(<class 'float'>,
#                                                                        {'Product': 1.0}),
#              'legalservice.which.co.uk': defaultdict(<class 'float'>,
#                                                      {'Formations / services': 1.0}),
#              'm.kenzo.com': defaultdict(<class 'float'>,
#                                         {'Category': 0.3333333333333333,
#                                          'Home': 0.6666666666666666}),
#              'm.ochsner-shoes.ch': defaultdict(<class 'float'>,
#                                                {'Category': 0.1,
#                                                 'Confirmation': 0.1,
#                                                 'Home': 0.1,
#                                                 'Other': 0.1,
#                                                 'Product': 0.5,
#                                                 'Search': 0.1}),
#              'm.staging.kenzo.com': defaultdict(<class 'float'>,
#                                                 {'Product': 1.0}),
#              'marine.honda.fr': defaultdict(<class 'float'>,
#                                             {'Information / legals': 0.5,
#                                              'Product': 0.5}),
#              'mobiletest.hobbycraft.co.uk': defaultdict(<class 'float'>,
#                                                         {'Category': 0.6666666666666666,
#                                                          'Product': 0.3333333333333333}),
#              'nl.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.07692307692307693,
#                                             'Cart': 0.17159763313609466,
#                                             'Checkout': 0.22485207100591717,
#                                             'Confirmation': 0.011834319526627219,
#                                             'Favorites / wishlist': 0.011834319526627219,
#                                             'Home': 0.21301775147928995,
#                                             'My account': 0.11834319526627218,
#                                             'Other': 0.05917159763313609,
#                                             'Search': 0.09467455621301775,
#                                             'Store locator': 0.01775147928994083}),
#              'nz.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.09859154929577464,
#                                             'Cart': 0.056338028169014086,
#                                             'Checkout': 0.028169014084507043,
#                                             'Confirmation': 0.028169014084507043,
#                                             'Home': 0.352112676056338,
#                                             'Information / legals': 0.028169014084507043,
#                                             'My account': 0.07042253521126761,
#                                             'Other': 0.08450704225352113,
#                                             'Search': 0.2535211267605634}),
#              'online.ybs.co.uk': defaultdict(<class 'float'>,
#                                              {'My account': 1.0}),
#              'pl.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.12234042553191489,
#                                             'Cart': 0.13829787234042554,
#                                             'Checkout': 0.10638297872340426,
#                                             'Confirmation': 0.018617021276595744,
#                                             'Favorites / wishlist': 0.010638297872340425,
#                                             'Home': 0.3882978723404255,
#                                             'My account': 0.10372340425531915,
#                                             'Other': 0.026595744680851064,
#                                             'Press / news': 0.005319148936170213,
#                                             'Search': 0.07446808510638298,
#                                             'Store locator': 0.005319148936170213}),
#              'player-dynamic3-staging.contentsquare.com': defaultdict(<class 'float'>,
#                                                                       {'Other': 1.0}),
#              'player-release-staging.contentsquare.com': defaultdict(<class 'float'>,
#                                                                      {'Other': 1.0}),
#              'player-staging.contentsquare.com': defaultdict(<class 'float'>,
#                                                              {'Other': 1.0}),
#              'player.contentsquare.com': defaultdict(<class 'float'>,
#                                                      {'Other': 1.0}),
#              'pp2.travelrepublic.co.uk': defaultdict(<class 'float'>,
#                                                      {'Category': 0.75,
#                                                       'My account': 0.25}),
#              'preprod.gites-de-france.com': defaultdict(<class 'float'>,
#                                                         {'Home': 1.0}),
#              'preprod.kenzo.com': defaultdict(<class 'float'>,
#                                               {'Other': 0.5,
#                                                'Product': 0.5}),
#              'preprod.natureetdecouvertes.com': defaultdict(<class 'float'>,
#                                                             {'Category': 0.3333333333333333,
#                                                              'Checkout': 0.3333333333333333,
#                                                              'Product': 0.3333333333333333}),
#              'promos.tomtom.com': defaultdict(<class 'float'>,
#                                               {'Product': 1.0}),
#              'promotion.tomtom.com': defaultdict(<class 'float'>,
#                                                  {'Category': 0.9902912621359223,
#                                                   'Product': 0.009708737864077669}),
#              'proxy.tomtom.com': defaultdict(<class 'float'>,
#                                              {'Category': 0.5,
#                                               'Home': 0.5}),
#              'se.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.08571428571428572,
#                                             'Cart': 0.08571428571428572,
#                                             'Checkout': 0.08571428571428572,
#                                             'Favorites / wishlist': 0.02857142857142857,
#                                             'Home': 0.3142857142857143,
#                                             'My account': 0.08571428571428572,
#                                             'Press / news': 0.02857142857142857,
#                                             'Search': 0.22857142857142856,
#                                             'Store locator': 0.05714285714285714}),
#              'search.which.co.uk': defaultdict(<class 'float'>,
#                                                {'Search': 1.0}),
#              'secure.ybonline.co.uk': defaultdict(<class 'float'>,
#                                                   {'Category': 0.125,
#                                                    'Home': 0.875}),
#              'sg.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.1388888888888889,
#                                             'Cart': 0.16666666666666666,
#                                             'Checkout': 0.08333333333333333,
#                                             'Confirmation': 0.027777777777777776,
#                                             'Home': 0.2222222222222222,
#                                             'Information / legals': 0.05555555555555555,
#                                             'My account': 0.027777777777777776,
#                                             'Other': 0.027777777777777776,
#                                             'Press / news': 0.05555555555555555,
#                                             'Search': 0.16666666666666666,
#                                             'Store locator': 0.027777777777777776}),
#              'shop.brunellocucinelli.com': defaultdict(<class 'float'>,
#                                                        {'Brand image': 0.03106508875739645,
#                                                         'Cart': 0.005917159763313609,
#                                                         'Category': 0.2514792899408284,
#                                                         'Checkout': 0.013313609467455622,
#                                                         'Confirmation': 0.004437869822485207,
#                                                         'Favorites / wishlist': 0.0029585798816568047,
#                                                         'Form': 0.0029585798816568047,
#                                                         'Home': 0.10650887573964497,
#                                                         'My account': 0.02514792899408284,
#                                                         'Other': 0.0073964497041420114,
#                                                         'Product': 0.5458579881656804,
#                                                         'Store locator': 0.0029585798816568047}),
#              'signup.which.co.uk': defaultdict(<class 'float'>, {'Form': 1.0}),
#              'stage.shop.brunellocucinelli.com': defaultdict(<class 'float'>,
#                                                              {'Category': 0.3333333333333333,
#                                                               'Checkout': 0.3333333333333333,
#                                                               'Confirmation': 0.3333333333333333}),
#              'staging-apacestore-pandora.demandware.net': defaultdict(<class 'float'>,
#                                                                       {'Brand image': 0.058823529411764705,
#                                                                        'Cart': 0.08823529411764706,
#                                                                        'Checkout': 0.29411764705882354,
#                                                                        'Confirmation': 0.029411764705882353,
#                                                                        'Favorites / wishlist': 0.029411764705882353,
#                                                                        'Home': 0.14705882352941177,
#                                                                        'My account': 0.20588235294117646,
#                                                                        'Other': 0.11764705882352941,
#                                                                        'Search': 0.029411764705882353}),
#              'staging-pandora-pfsweb.demandware.net': defaultdict(<class 'float'>,
#                                                                   {'Brand image': 0.37037037037037035,
#                                                                    'Cart': 0.1111111111111111,
#                                                                    'Checkout': 0.037037037037037035,
#                                                                    'Home': 0.2962962962962963,
#                                                                    'My account': 0.1111111111111111,
#                                                                    'Search': 0.07407407407407407}),
#              'staging-usestore-pandora.demandware.net': defaultdict(<class 'float'>,
#                                                                     {'Cart': 0.14285714285714285,
#                                                                      'Checkout': 0.38095238095238093,
#                                                                      'Home': 0.38095238095238093,
#                                                                      'My account': 0.047619047619047616,
#                                                                      'Other': 0.047619047619047616}),
#              'staging73.magazinesdirect.com': defaultdict(<class 'float'>,
#                                                           {'Product': 1.0}),
#              'stagingm2.thekooples.com': defaultdict(<class 'float'>,
#                                                      {'Cart': 1.0}),
#              'stg-eu.ysl.com': defaultdict(<class 'float'>, {'Product': 1.0}),
#              'store.bottegaveneta.cn': defaultdict(<class 'float'>,
#                                                    {'Category': 0.14184397163120568,
#                                                     'Home': 0.0425531914893617,
#                                                     'Product': 0.6879432624113475,
#                                                     'Search': 0.1276595744680851}),
#              'stores.pandora.net': defaultdict(<class 'float'>,
#                                                {'Store locator': 1.0}),
#              'subscribe.countrylife.co.uk': defaultdict(<class 'float'>,
#                                                         {'Product': 1.0}),
#              'subscribe.womanandhome.com': defaultdict(<class 'float'>,
#                                                        {'Product': 1.0}),
#              'supersearch.trustford.co.uk': defaultdict(<class 'float'>,
#                                                         {'Search': 1.0}),
#              'switch.which.co.uk': defaultdict(<class 'float'>,
#                                                {'Formations / services': 1.0}),
#              'testride.ktm.com': defaultdict(<class 'float'>, {'Form': 1.0}),
#              'thereforyou.quilter.com': defaultdict(<class 'float'>,
#                                                     {'Information / legals': 0.5,
#                                                      'Press / news': 0.5}),
#              'trustedtraders.which.co.uk': defaultdict(<class 'float'>,
#                                                        {'Formations / services': 1.0}),
#              'try.which.co.uk': defaultdict(<class 'float'>,
#                                             {'Formations / services': 1.0}),
#              'tsm.travelrepublic.co.uk': defaultdict(<class 'float'>,
#                                                      {'Other': 1.0}),
#              'tv.travelrepublic.co.uk': defaultdict(<class 'float'>,
#                                                     {'Category': 0.02857142857142857,
#                                                      'Home': 0.02857142857142857,
#                                                      'My account': 0.3142857142857143,
#                                                      'Other': 0.02857142857142857,
#                                                      'Product': 0.6}),
#              'uk.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.09083191850594227,
#                                             'Cart': 0.1494057724957555,
#                                             'Checkout': 0.2461799660441426,
#                                             'Confirmation': 0.04626485568760611,
#                                             'Favorites / wishlist': 0.005942275042444821,
#                                             'Home': 0.2567911714770798,
#                                             'Information / legals': 0.0012733446519524619,
#                                             'My account': 0.06196943972835314,
#                                             'Other': 0.03310696095076401,
#                                             'Press / news': 0.003395585738539898,
#                                             'Search': 0.10314091680814941,
#                                             'Store locator': 0.001697792869269949}),
#              'us.pandora.net': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.10119595216191353,
#                                             'Cart': 0.12603495860165592,
#                                             'Checkout': 0.11591536338546458,
#                                             'Confirmation': 0.015639374425023,
#                                             'Favorites / wishlist': 0.006439742410303588,
#                                             'Home': 0.3629254829806808,
#                                             'Information / legals': 0.0009199632014719411,
#                                             'My account': 0.08739650413983441,
#                                             'Other': 0.043698252069917204,
#                                             'Search': 0.13937442502299907,
#                                             'Store locator': 0.00045998160073597056}),
#              'wills.which.co.uk': defaultdict(<class 'float'>,
#                                               {'Formations / services': 1.0}),
#              'willsoffers.which.co.uk': defaultdict(<class 'float'>,
#                                                     {'Formations / services': 1.0}),
#              'winemaker.com': defaultdict(<class 'float'>,
#                                           {'Category': 0.4,
#                                            'Help / support': 0.2,
#                                            'Product': 0.2,
#                                            'Store locator': 0.2}),
#              'www-fix.oakley.com': defaultdict(<class 'float'>,
#                                                {'Cart': 0.18181818181818182,
#                                                 'Checkout': 0.45454545454545453,
#                                                 'My account': 0.09090909090909091,
#                                                 'Product': 0.18181818181818182,
#                                                 'Search': 0.09090909090909091}),
#              'www-origin.oakley.com': defaultdict(<class 'float'>,
#                                                   {'Category': 1.0}),
#              'www-qa.oakley.com': defaultdict(<class 'float'>,
#                                               {'Category': 1.0}),
#              'www.accordmortgages.com': defaultdict(<class 'float'>,
#                                                     {'Help / support': 0.25,
#                                                      'My account': 0.5,
#                                                      'Other': 0.25}),
#              'www.audleytravel.com': defaultdict(<class 'float'>,
#                                                  {'Category': 0.5302325581395348,
#                                                   'Confirmation': 0.02558139534883721,
#                                                   'Form': 0.004651162790697674,
#                                                   'Home': 0.03953488372093023,
#                                                   'Information / legals': 0.002325581395348837,
#                                                   'Offers & services': 0.24883720930232558,
#                                                   'Other': 0.044186046511627906,
#                                                   'Product': 0.08837209302325581,
#                                                   'Search': 0.01627906976744186}),
#              'www.backmarket.it': defaultdict(<class 'float'>,
#                                               {'Cart': 0.0012674271229404308,
#                                                'Checkout': 0.005069708491761723,
#                                                'Home': 0.022813688212927757,
#                                                'My account': 0.015209125475285171,
#                                                'Other': 0.11787072243346007,
#                                                'Product': 0.8136882129277566,
#                                                'Search': 0.024081115335868188}),
#              'www.bottegaveneta.com': defaultdict(<class 'float'>,
#                                                   {'Cart': 0.0078125,
#                                                    'Category': 0.2701822916666667,
#                                                    'Checkout': 0.007161458333333333,
#                                                    'Confirmation': 0.00390625,
#                                                    'Home': 0.07421875,
#                                                    'My account': 0.0078125,
#                                                    'Product': 0.5520833333333334,
#                                                    'Search': 0.07552083333333333,
#                                                    'Store locator': 0.0013020833333333333}),
#              'www.catrice.eu': defaultdict(<class 'float'>,
#                                            {'Cart': 0.12962962962962962,
#                                             'Category': 0.14814814814814814,
#                                             'Checkout': 0.07407407407407407,
#                                             'Home': 0.18518518518518517,
#                                             'My account': 0.037037037037037035,
#                                             'Product': 0.42592592592592593}),
#              'www.cosstores.com': defaultdict(<class 'float'>,
#                                               {'Brand image': 0.0009913258983890955,
#                                                'Cart': 0.0004956629491945477,
#                                                'Category': 0.12391573729863693,
#                                                'Checkout': 0.0007434944237918215,
#                                                'Confirmation': 0.03420074349442379,
#                                                'Help / support': 0.0007434944237918215,
#                                                'Home': 0.12143742255266418,
#                                                'My account': 0.001734820322180917,
#                                                'Other': 0.0004956629491945477,
#                                                'Product': 0.6480793060718711,
#                                                'Search': 0.06666666666666667,
#                                                'Store locator': 0.0004956629491945477}),
#              'www.csas.cz': defaultdict(<class 'float'>,
#                                         {'Category': 0.25,
#                                          'Help / support': 0.00984251968503937,
#                                          'Home': 0.03346456692913386,
#                                          'Information / legals': 0.08858267716535433,
#                                          'Other': 0.1279527559055118,
#                                          'Press / news': 0.001968503937007874,
#                                          'Product': 0.39173228346456695,
#                                          'Search': 0.09645669291338582}),
#              'www.digitalneinvestovanie.sk': defaultdict(<class 'float'>,
#                                                          {'Information / legals': 0.8823529411764706,
#                                                           'Search': 0.11764705882352941}),
#              'www.diners.hr': defaultdict(<class 'float'>,
#                                           {'Information / legals': 0.8888888888888888,
#                                            'My account': 0.1111111111111111}),
#              'www.dreams.co.uk': defaultdict(<class 'float'>,
#                                              {'Brand image': 0.0015432098765432098,
#                                               'Category': 0.45524691358024694,
#                                               'Checkout': 0.024691358024691357,
#                                               'Confirmation': 0.044753086419753084,
#                                               'Home': 0.13271604938271606,
#                                               'My account': 0.004629629629629629,
#                                               'Product': 0.21296296296296297,
#                                               'Search': 0.1111111111111111,
#                                               'Store locator': 0.012345679012345678}),
#              'www.drmartens.com': defaultdict(<class 'float'>,
#                                               {'Category': 0.07720588235294118,
#                                                'Checkout': 0.003676470588235294,
#                                                'Confirmation': 0.0625,
#                                                'Form': 0.007352941176470588,
#                                                'Help / support': 0.011029411764705883,
#                                                'Home': 0.10661764705882353,
#                                                'My account': 0.003676470588235294,
#                                                'Product': 0.5772058823529411,
#                                                'Search': 0.15073529411764705}),
#              'www.essence.eu': defaultdict(<class 'float'>,
#                                            {'Cart': 0.15517241379310345,
#                                             'Category': 0.034482758620689655,
#                                             'Checkout': 0.06896551724137931,
#                                             'Home': 0.22413793103448276,
#                                             'Information / legals': 0.017241379310344827,
#                                             'Product': 0.4827586206896552,
#                                             'Search': 0.017241379310344827}),
#              'www.fendi.com': defaultdict(<class 'float'>,
#                                           {'Brand image': 0.013235294117647059,
#                                            'Cart': 0.0007352941176470588,
#                                            'Category': 0.2073529411764706,
#                                            'Checkout': 0.003676470588235294,
#                                            'Confirmation': 0.005147058823529412,
#                                            'Help / support': 0.0125,
#                                            'Home': 0.11323529411764706,
#                                            'My account': 0.006617647058823529,
#                                            'Product': 0.5647058823529412,
#                                            'Search': 0.0713235294117647,
#                                            'Store locator': 0.0014705882352941176}),
#              'www.funkypigeon.com': defaultdict(<class 'float'>,
#                                                 {'Cart': 0.0031583103039873666,
#                                                  'Category': 0.19778918278720883,
#                                                  'Checkout': 0.011054086063955783,
#                                                  'Home': 0.17647058823529413,
#                                                  'My account': 0.008290564547966837,
#                                                  'Other': 0.0007895775759968417,
#                                                  'Product': 0.6020529016975917,
#                                                  'Search': 0.00039478878799842083}),
#              'www.gites-de-france.com': defaultdict(<class 'float'>,
#                                                     {'Category': 0.008872315803008872,
#                                                      'Checkout': 0.0050147871930050145,
#                                                      'Form': 0.00038575286100038574,
#                                                      'Home': 0.005143371480005143,
#                                                      'Information / legals': 0.00038575286100038574,
#                                                      'My account': 0.008100810081008101,
#                                                      'Product': 0.4661180403754661,
#                                                      'Search': 0.505979169345506}),
#              'www.gucci.cn': defaultdict(<class 'float'>,
#                                          {'Brand image': 0.07407407407407407,
#                                           'Press / news': 0.013888888888888888,
#                                           'Product': 0.8958333333333334,
#                                           'Store locator': 0.016203703703703703}),
#              'www.gucci.com': defaultdict(<class 'float'>,
#                                           {'Brand image': 0.050412175015852885,
#                                            'Cart': 0.0003170577045022194,
#                                            'Category': 0.21147748890298035,
#                                            'Checkout': 0.0003170577045022194,
#                                            'Confirmation': 0.03424223208623969,
#                                            'Favorites / wishlist': 0.0019023462270133164,
#                                            'Help / support': 0.0019023462270133164,
#                                            'Home': 0.1766011414077362,
#                                            'Information / legals': 0.0003170577045022194,
#                                            'Other': 0.009194673430564362,
#                                            'Press / news': 0.009511731135066582,
#                                            'Product': 0.37064045656309447,
#                                            'Search': 0.11382371591629677,
#                                            'Store locator': 0.019340519974635383}),
#              'www.hermes.com': defaultdict(<class 'float'>,
#                                            {'Brand image': 0.008986520219670495,
#                                             'Cart': 0.04992511233150274,
#                                             'Category': 0.16674987518721918,
#                                             'Checkout': 0.01547678482276585,
#                                             'Confirmation': 0.006490264603095357,
#                                             'Form': 0.000998502246630055,
#                                             'Home': 0.06739890164752871,
#                                             'Information / legals': 0.0029955067398901645,
#                                             'My account': 0.017473789316025962,
#                                             'Other': 0.012481278082875686,
#                                             'Product': 0.5491762356465302,
#                                             'Search': 0.09935097353969047,
#                                             'Store locator': 0.0024962556165751375}),
#              'www.hertz.co.uk': defaultdict(<class 'float'>,
#                                             {'Category': 0.8285714285714286,
#                                              'Home': 0.14285714285714285,
#                                              'My account': 0.02857142857142857}),
#              'www.hobbycraft.co.uk': defaultdict(<class 'float'>,
#                                                  {'Cart': 0.0008067769261799112,
#                                                   'Category': 0.5490116982654296,
#                                                   'Checkout': 0.004840661557079467,
#                                                   'Confirmation': 0.04154901169826543,
#                                                   'Home': 0.0008067769261799112,
#                                                   'Information / legals': 0.002016942315449778,
#                                                   'My account': 0.011698265429608713,
#                                                   'Other': 0.014118596208148447,
#                                                   'Product': 0.37353771682129894,
#                                                   'Store locator': 0.0016135538523598225}),
#              'www.honda.co.uk': defaultdict(<class 'float'>,
#                                             {'Category': 0.2727272727272727,
# ...
#                                                {'Cart': 0.006557377049180328,
#                                                 'Category': 0.20655737704918034,
#                                                 'Checkout': 0.003278688524590164,
#                                                 'Help / support': 0.003278688524590164,
#                                                 'Home': 0.09180327868852459,
#                                                 'My account': 0.006557377049180328,
#                                                 'Other': 0.009836065573770493,
#                                                 'Product': 0.6163934426229508,
#                                                 'Search': 0.04918032786885246,
#                                                 'Store locator': 0.006557377049180328}),
#              'www.ray-ban.com': defaultdict(<class 'float'>,
#                                             {'Cart': 0.07186858316221766,
#                                              'Category': 0.2751540041067762,
#                                              'Checkout': 0.061601642710472276,
#                                              'Confirmation': 0.002053388090349076,
#                                              'Home': 0.024640657084188913,
#                                              'Information / legals': 0.004106776180698152,
#                                              'My account': 0.028747433264887063,
#                                              'Product': 0.48459958932238195,
#                                              'Search': 0.04722792607802875}),
#              'www.simone-perele.com': defaultdict(<class 'float'>,
#                                                   {'Category': 0.27932960893854747,
#                                                    'Confirmation': 0.027932960893854747,
#                                                    'Home': 0.0111731843575419,
#                                                    'Information / legals': 0.0111731843575419,
#                                                    'Other': 0.4748603351955307,
#                                                    'Product': 0.16759776536312848,
#                                                    'Search': 0.027932960893854747}),
#              'www.slsp.sk': defaultdict(<class 'float'>,
#                                         {'Category': 0.2222222222222222,
#                                          'Help / support': 0.04678362573099415,
#                                          'Home': 0.023391812865497075,
#                                          'Information / legals': 0.11695906432748537,
#                                          'Other': 0.14035087719298245,
#                                          'Press / news': 0.04093567251461988,
#                                          'Product': 0.29239766081871343,
#                                          'Search': 0.11695906432748537}),
#              'www.slsphypoteka.sk': defaultdict(<class 'float'>,
#                                                 {'Information / legals': 0.2727272727272727,
#                                                  'Other': 0.7272727272727273}),
#              'www.spacenk.com': defaultdict(<class 'float'>,
#                                             {'Brand image': 0.006455997281685355,
#                                              'Cart': 0.2949371389738362,
#                                              'Category': 0.07713217804960924,
#                                              'Checkout': 0.021406727828746176,
#                                              'Confirmation': 0.0033978933061501867,
#                                              'Home': 0.0581039755351682,
#                                              'My account': 0.05844376486578321,
#                                              'Other': 0.014610941216445803,
#                                              'Product': 0.4108053007135576,
#                                              'Search': 0.05436629289840299,
#                                              'Store locator': 0.0003397893306150187}),
#              'www.specsavers.co.uk': defaultdict(<class 'float'>,
#                                                  {'Cart': 0.0024046719340432843,
#                                                   'Category': 0.2425283407763655,
#                                                   'Checkout': 0.5029199587770525,
#                                                   'Confirmation': 0.029543112332531776,
#                                                   'Home': 0.09927859841978702,
#                                                   'Information / legals': 0.023703194778426657,
#                                                   'My account': 0.0020611473720371005,
#                                                   'Other': 0.00790106492614222,
#                                                   'Product': 0.05530745448299553,
#                                                   'Search': 0.034352456200618345}),
#              'www.specsavers.com.au': defaultdict(<class 'float'>,
#                                                   {'Cart': 0.010582010582010581,
#                                                    'Category': 0.6155202821869489,
#                                                    'Checkout': 0.0026455026455026454,
#                                                    'Home': 0.09082892416225749,
#                                                    'Information / legals': 0.018518518518518517,
#                                                    'My account': 0.02292768959435626,
#                                                    'Search': 0.06349206349206349,
#                                                    'Store locator': 0.17548500881834214}),
#              'www.specsavers.nl': defaultdict(<class 'float'>,
#                                               {'Category': 0.3187022900763359,
#                                                'Checkout': 0.03435114503816794,
#                                                'Confirmation': 0.026717557251908396,
#                                                'Home': 0.08206106870229007,
#                                                'My account': 0.022900763358778626,
#                                                'Other': 0.2748091603053435,
#                                                'Product': 0.1297709923664122,
#                                                'Search': 0.03244274809160305,
#                                                'Store locator': 0.07824427480916031}),
#              'www.staging-eu01.ralphlauren.co.uk': defaultdict(<class 'float'>,
#                                                                {'Other': 1.0}),
#              'www.staging-eu01.ralphlauren.es': defaultdict(<class 'float'>,
#                                                             {'Other': 1.0}),
#              'www.staging-eu01.ralphlauren.fr': defaultdict(<class 'float'>,
#                                                             {'Other': 1.0}),
#              'www.testawsfp.com': defaultdict(<class 'float'>, {'Cart': 1.0}),
#              'www.thekooples.com': defaultdict(<class 'float'>,
#                                                {'Cart': 0.08183453237410072,
#                                                 'Category': 0.35701438848920863,
#                                                 'Checkout': 0.0008992805755395684,
#                                                 'Confirmation': 0.0017985611510791368,
#                                                 'Help / support': 0.0035971223021582736,
#                                                 'My account': 0.03507194244604316,
#                                                 'Product': 0.4739208633093525,
#                                                 'Search': 0.045863309352517985}),
#              'www.tomtom.com': defaultdict(<class 'float'>,
#                                            {'Cart': 0.08969607116382505,
#                                             'Category': 0.16011860637509265,
#                                             'Checkout': 0.17642698295033357,
#                                             'Confirmation': 0.054114158636026685,
#                                             'Home': 0.10378057820607858,
#                                             'Information / legals': 0.04002965159377316,
#                                             'My account': 0.21793921423276502,
#                                             'Other': 0.005189028910303929,
#                                             'Product': 0.10971089696071164,
#                                             'Search': 0.042994810971089696}),
#              'www.toyota-france.fr': defaultdict(<class 'float'>,
#                                                  {'Product': 1.0}),
#              'www.toyota.fr': defaultdict(<class 'float'>,
#                                           {'Appointments / booking': 0.015133876600698487,
#                                            'Brand image': 0.12339930151338765,
#                                            'Confirmation': 0.1280558789289872,
#                                            'Help / support': 0.01629802095459837,
#                                            'Home': 0.034924330616996506,
#                                            'My account': 0.04074505238649592,
#                                            'Offers & services': 0.013969732246798603,
#                                            'Other': 0.0011641443538998836,
#                                            'Press / news': 0.0011641443538998836,
#                                            'Product': 0.59953434225844,
#                                            'Search': 0.013969732246798603,
#                                            'Store locator': 0.011641443538998836}),
#              'www.travelrepublic.co.uk': defaultdict(<class 'float'>,
#                                                      {'Category': 0.6317722681359045,
#                                                       'Checkout': 0.06458524640342822,
#                                                       'Confirmation': 0.003979185797367615,
#                                                       'Home': 0.08570554025099479,
#                                                       'Information / legals': 0.0027548209366391185,
#                                                       'My account': 0.04071013161922253,
#                                                       'Other': 0.020508111417202327,
#                                                       'Product': 0.11019283746556474,
#                                                       'Search': 0.039791857973676154}),
#              'www.trustford.co.uk': defaultdict(<class 'float'>,
#                                                 {'Category': 0.3202247191011236,
#                                                  'Checkout': 0.02247191011235955,
#                                                  'Confirmation': 0.016853932584269662,
#                                                  'Form': 0.011235955056179775,
#                                                  'Home': 0.10112359550561797,
#                                                  'Information / legals': 0.0056179775280898875,
#                                                  'Offers & services': 0.06179775280898876,
#                                                  'Product': 0.4550561797752809,
#                                                  'Search': 0.0056179775280898875}),
#              'www.valentino.com': defaultdict(<class 'float'>,
#                                               {'Brand image': 0.03326612903225806,
#                                                'Cart': 0.055443548387096774,
#                                                'Category': 0.2752016129032258,
#                                                'Checkout': 0.037298387096774195,
#                                                'Information / legals': 0.015120967741935484,
#                                                'My account': 0.016129032258064516,
#                                                'Product': 0.501008064516129,
#                                                'Search': 0.06653225806451613}),
#              'www.which.co.uk': defaultdict(<class 'float'>,
#                                             {'Formations / services': 0.8795348837209302,
#                                              'Information / legals': 0.014883720930232559,
#                                              'My account': 0.007906976744186046,
#                                              'Press / news': 0.09767441860465116}),
#              'www.wonderbly.com': defaultdict(<class 'float'>,
#                                               {'Brand image': 0.031473533619456366,
#                                                'Cart': 0.02145922746781116,
#                                                'Category': 0.0357653791130186,
#                                                'Checkout': 0.004291845493562232,
#                                                'Confirmation': 0.05007153075822604,
#                                                'Home': 0.07439198855507868,
#                                                'Information / legals': 0.001430615164520744,
#                                                'My account': 0.06151645207439199,
#                                                'Other': 0.008583690987124463,
#                                                'Product': 0.7110157367668097}),
#              'www.wonderbox.fr': defaultdict(<class 'float'>,
#                                              {'Category': 0.3203125,
#                                               'Checkout': 0.0390625,
#                                               'Home': 0.07291666666666667,
#                                               'My account': 0.3020833333333333,
#                                               'Product': 0.265625}),
#              'www.ybs.co.uk': defaultdict(<class 'float'>,
#                                           {'Appointments / booking': 0.010752688172043012,
#                                            'Help / support': 0.043010752688172046,
#                                            'Product': 0.5161290322580645,
#                                            'Store locator': 0.43010752688172044}),
#              'www.ysl.com': defaultdict(<class 'float'>,
#                                         {'Brand image': 0.010842368640533779,
#                                          'Category': 0.4487072560467056,
#                                          'Checkout': 0.005838198498748957,
#                                          'Help / support': 0.003336113427856547,
#                                          'Home': 0.04670558798999166,
#                                          'My account': 0.0050041701417848205,
#                                          'Other': 0.007506255212677231,
#                                          'Product': 0.35446205170975814,
#                                          'Search': 0.11175979983319433,
#                                          'Store locator': 0.005838198498748957}),
#              'www2.hm.com': defaultdict(<class 'float'>,
#                                         {'Brand image': 0.0006111639277468423,
#                                          'Cart': 0.0005432568246638599,
#                                          'Category': 0.11727556702431075,
#                                          'Checkout': 0.07143827244329756,
#                                          'Confirmation': 0.13696862691837566,
#                                          'Help / support': 0.001154420752410702,
#                                          'Home': 0.03442890126307212,
#                                          'My account': 0.02023631671872878,
#                                          'Other': 0.0197609669971479,
#                                          'Product': 0.3942007333967133,
#                                          'Search': 0.20338177373353253})})

# %% [markdown]
# **Idea**: could be the same for actions too

# %% [markdown]
# ## Train a basic model and evaluate 5-fold accuracy metrics

# %% [markdown]
# ### Design a vectorizer

# %% [markdown]
# We will split the dataset into a training and a test set, and the training test will again be split between a set for probability training (i.e. a map from path chunk (resp. prefixes, actions) to category probas) and a set for model training. <br>
# We will implement a multiclass Logistic Regression with category probabilities for paths/prefixes/actions as inputs and one-hot encodings for categories as outputs

# %% [markdown]
# **Category probabilities by url chunk (website, path, actions = "c_vars") definitions**

# %%
from collections import defaultdict

def get_path_chunk_to_category_scores(paths, categories, balanced=False):
    path_chunk_to_category_counts = (
        defaultdict(lambda: defaultdict(float))
        if balanced
        else defaultdict(lambda: defaultdict(int))
    )
    

    for path, category in zip(paths, categories):
        for chunk in path.split("/"):
            if not chunk or category not in ALL_CATEGORIES_SET:
                continue
            path_chunk_to_category_counts[chunk][category] += (
                1/CATEGORY_TO_PRIOR_PROBABILITY[category]
                if balanced
                else 1
            )

    path_chunk_to_category_scores = defaultdict(lambda: defaultdict(float))
    for chunk, category_counts in path_chunk_to_category_counts.items():
        chunk_counts = sum(category_counts.values())
        if chunk_counts < 10:
            continue
        for category, count in category_counts.items():
            path_chunk_to_category_scores[chunk][category] = count/chunk_counts

    return path_chunk_to_category_scores

# %%
def get_website_to_category_scores(prefixes, categories, balanced=False):
    prefix_to_category_counts = (
        defaultdict(lambda: defaultdict(float))
        if balanced
        else defaultdict(lambda: defaultdict(int))
    )
    

    for prefix, category in zip(prefixes, categories):
        if not prefix or category not in ALL_CATEGORIES_SET:
            continue
        prefix_to_category_counts[prefix][category] += (
            1/CATEGORY_TO_PRIOR_PROBABILITY[category]
            if balanced
            else 1
        )

    prefix_to_category_scores = defaultdict(lambda: defaultdict(float))
    for prefix, category_counts in prefix_to_category_counts.items():
        prefix_counts = sum(category_counts.values())
        if prefix_counts < 10:
            continue
        for category, count in category_counts.items():
            prefix_to_category_scores[prefix][category] = count/prefix_counts

    return prefix_to_category_scores

# %%
def get_action_chunk_to_category_scores(actions, categories, balanced=False):
    action_chunk_to_category_counts = (
        defaultdict(lambda: defaultdict(float))
        if balanced
        else defaultdict(lambda: defaultdict(int))
    )
    

    for action, category in zip(actions, categories):
        for chunk in action.replace("=", "&").split("&"):
            chunk = chunk.strip()
            if not chunk or category not in ALL_CATEGORIES_SET:
                continue
            action_chunk_to_category_counts[chunk][category] += (
                1/CATEGORY_TO_PRIOR_PROBABILITY[category]
                if balanced
                else 1
            )

    action_chunk_to_category_scores = defaultdict(lambda: defaultdict(float))
    for chunk, category_counts in action_chunk_to_category_counts.items():
        chunk_counts = sum(category_counts.values())
        if chunk_counts < 10:
            continue
        for category, count in category_counts.items():
            action_chunk_to_category_scores[chunk][category] = count/chunk_counts

    return action_chunk_to_category_scores

# %% [markdown]
# **Associated vectorizers**

# %%
def vectorize_path(path, path_chunk_to_category_scores):
    return np.mean(
        [
            [
                path_chunk_to_category_scores[chunk][category]
                for category in ALL_CATEGORIES
            ]
            for chunk in path.split("/")
        ],
        axis=0
    ).tolist()

# %%
def vectorize_website(prefix, prefix_to_category_scores):
    return [
        prefix_to_category_scores[prefix][category]
        for category in ALL_CATEGORIES
    ]

# %%
def vectorize_action(action, action_chunk_to_category_scores):
    return np.mean(
        [
            [
                action_chunk_to_category_scores[chunk.strip()][category]
                for category in ALL_CATEGORIES
            ]
            for chunk in action.replace("=", "&").split("&")
        ],
        axis=0
    ).tolist()

# %% [markdown]
# ### Carry out stratified k-fold (5 folds)

# %%
from tqdm.notebook import tqdm

category_to_one_hot_embedding = {}
idx_to_category = {i: category for i, category in enumerate(ALL_CATEGORIES)}
for category in ALL_CATEGORIES:
    category_to_one_hot_embedding[category] = [
        int(i == len(category_to_one_hot_embedding))
        for i in range(len(ALL_CATEGORIES))
    ]

urls = []
paths = []
prefixes = []
actions = []
categories = []

print("Computing dataset arrays: urls, paths, prefixes, actions, categories")

for url, path, prefix, action, category in tqdm(
    zip(
        np.array(website_df["url"]),
        np.array(website_df["path"]),
        np.array(website_df["prefix"]),
        np.array(website_df["c_vars"]),
        np.array(website_df["category_name"])
    )
):
    if category not in ALL_CATEGORIES_SET:
        continue
    urls.append(url)
    paths.append(path)
    prefixes.append(prefix)
    actions.append(action)
    categories.append(category)

urls = np.array(urls)
paths = np.array(paths)
prefixes = np.array(prefixes)
actions = np.array(actions)
categories = np.array(categories)
# Out:
# Computing dataset arrays: urls, paths, prefixes, actions, categories
# 0it [00:00, ?it/s]

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression

n_splits = 5
fold_accuracy_scores = []
fold_accuracy_scores_categorywise = []

skf = StratifiedKFold(n_splits=n_splits)
for idx, (train_index, test_index) in tqdm(enumerate(skf.split(urls, categories)), leave=False):
    print(f"Preparing training and test features/targets for batch {idx + 1}/{n_splits}...")
    X_train = []
    y_train = []
    X_test = []
    y_test = []

    print(f"Splitting our data on fold {idx + 1}/{n_splits}...")
    urls_train, urls_test = urls[train_index], urls[test_index]
    categories_train, categories_test = categories[train_index], categories[test_index]
    prefixes_train, prefixes_test = prefixes[train_index], prefixes[test_index]
    paths_train, paths_test = paths[train_index], paths[test_index]
    actions_train, actions_test = actions[train_index], paths[test_index]

    print("Splitting our data into probability and model training parts...")
    batch_skf = StratifiedKFold(n_splits=2)
    for batch_train_probas_index, batch_train_model_index in tqdm(batch_skf.split(urls_train, categories_train), leave=False):
        urls_train_probas, urls_train_model = urls_train[batch_train_probas_index], urls_train[batch_train_model_index]
        categories_train_probas, categories_train_model = categories_train[batch_train_probas_index], categories_train[batch_train_model_index]
        prefixes_train_probas, prefixes_train_model = prefixes_train[batch_train_probas_index], prefixes_train[batch_train_model_index]
        paths_train_probas, paths_train_model = paths_train[batch_train_probas_index], paths_train[batch_train_model_index]
        actions_train_probas, actions_train_model = actions_train[batch_train_probas_index], actions_train[batch_train_model_index]
        
        print("Training category probabilities on half train set (probability training part)...")
        path_chunk_to_category_scores = get_path_chunk_to_category_scores(
            paths_train_probas,
            categories_train_probas,
            balanced=False
        )
        prefix_to_category_scores = get_website_to_category_scores(
            prefixes_train_probas,
            categories_train_probas,
            balanced=False
        )
        action_chunk_to_category_scores = get_action_chunk_to_category_scores(actions_train_probas, categories_train_probas)
        print(f"Computing features and targets for our model training on fold {idx + 1}/{n_splits} on the other half of the training set...")
        for path, prefix, action, category in zip(
            paths_train_model,
            prefixes_train_model,
            actions_train_model,
            categories_train_model
        ):
            X_train.append(
                vectorize_path(
                    path,
                    path_chunk_to_category_scores
                ) + vectorize_website(
                    prefix,
                    prefix_to_category_scores
                ) + vectorize_action(
                    action,
                    action_chunk_to_category_scores
                )
            )
            y_train.append(category)
        
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    print(f"Defining and training our model on fold {idx + 1}/{n_splits}...")
    model = LogisticRegression(
        penalty='l2',
        dual=False,
        tol=0.001,
        C=1.0,
        fit_intercept=True,
        intercept_scaling=1,
        class_weight="balanced", # Balance the class weights
        random_state=None,
        solver='lbfgs',
        max_iter=500,
        multi_class='auto',
        verbose=0,
        warm_start=False,
        n_jobs=None,
        l1_ratio=None
    )
    model.fit(X_train, y_train)
    
    print(f"Training category probabilities on full train set for fold {idx + 1}/{n_splits}...")
    path_chunk_to_category_scores = get_path_chunk_to_category_scores(
        paths_train,
        categories_train,
        balanced=False
    )
    prefix_to_category_scores = get_website_to_category_scores(
        prefixes_train,
        categories_train,
        balanced=False
    )
    action_chunk_to_category_scores = get_action_chunk_to_category_scores(
        actions_train,
        categories_train,
        balanced=False
    )

    print(f"Computing model predictions on test for fold {idx + 1}/{n_splits} and computing metrics...")
    for path, prefix, action, category in zip(
        paths_test,
        prefixes_test,
        actions_test,
        categories_test
    ):
        X_test.append(
            vectorize_path(
                path,
                path_chunk_to_category_scores
            ) + vectorize_website(
                prefix,
                prefix_to_category_scores
            ) + vectorize_action(
                action,
                action_chunk_to_category_scores
            )
        )
        y_test.append(category)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    y_pred = model.predict(X_test)

    print(f"Computing metrics on test for fold {idx + 1}/{n_splits}...")
    fold_accuracy_score = accuracy_score(y_pred, y_test)
    fold_accuracy_scores.append(fold_accuracy_score)
    
    true_category_to_prediction = defaultdict(list)
    category_to_accuracy_score = {}
    for pred, truth in zip(y_pred, y_test):
        true_category_to_prediction[truth].append(pred)
    for category, predictions in true_category_to_prediction.items():
        category_to_accuracy_score[category] = np.mean([int(pred == category) for pred in predictions])
    fold_accuracy_scores_categorywise.append(category_to_accuracy_score)
    print("------------------------------------------------------------------------------------------")
# Out:
# 0it [00:00, ?it/s]
# Preparing training and test features/targets for batch 1/5...
# Splitting our data on fold 1/5...
# Splitting our data into probability and model training parts...
# 0it [00:00, ?it/s]
# Training category probabilities on half train set (probability training part)...
# Computing features and targets for our model training on fold 1/5 on the other half of the training set...
# Training category probabilities on half train set (probability training part)...
# Computing features and targets for our model training on fold 1/5 on the other half of the training set...
# Defining and training our model on fold 1/5...
# Training category probabilities on full train set for fold 1/5...
# Computing model predictions on test for fold 1/5 and computing metrics...
# Computing metrics on test for fold 1/5...
# ------------------------------------------------------------------------------------------
# Preparing training and test features/targets for batch 2/5...
# Splitting our data on fold 2/5...
# Splitting our data into probability and model training parts...
# 0it [00:00, ?it/s]
# Training category probabilities on half train set (probability training part)...
# Computing features and targets for our model training on fold 2/5 on the other half of the training set...
# Training category probabilities on half train set (probability training part)...
# Computing features and targets for our model training on fold 2/5 on the other half of the training set...
# Defining and training our model on fold 2/5...
# Training category probabilities on full train set for fold 2/5...
# Computing model predictions on test for fold 2/5 and computing metrics...
# Computing metrics on test for fold 2/5...
# ------------------------------------------------------------------------------------------
# Preparing training and test features/targets for batch 3/5...
# Splitting our data on fold 3/5...
# Splitting our data into probability and model training parts...
# 0it [00:00, ?it/s]
# Training category probabilities on half train set (probability training part)...
# Computing features and targets for our model training on fold 3/5 on the other half of the training set...
# Training category probabilities on half train set (probability training part)...
# Computing features and targets for our model training on fold 3/5 on the other half of the training set...
# Defining and training our model on fold 3/5...
# Training category probabilities on full train set for fold 3/5...
# Computing model predictions on test for fold 3/5 and computing metrics...
# Computing metrics on test for fold 3/5...
# ------------------------------------------------------------------------------------------
# Preparing training and test features/targets for batch 4/5...
# Splitting our data on fold 4/5...
# Splitting our data into probability and model training parts...
# 0it [00:00, ?it/s]
# Training category probabilities on half train set (probability training part)...
# Computing features and targets for our model training on fold 4/5 on the other half of the training set...
# Training category probabilities on half train set (probability training part)...
# Computing features and targets for our model training on fold 4/5 on the other half of the training set...
# Defining and training our model on fold 4/5...
# Training category probabilities on full train set for fold 4/5...
# Computing model predictions on test for fold 4/5 and computing metrics...
# Computing metrics on test for fold 4/5...
# ------------------------------------------------------------------------------------------
# Preparing training and test features/targets for batch 5/5...
# Splitting our data on fold 5/5...
# Splitting our data into probability and model training parts...
# 0it [00:00, ?it/s]
# Training category probabilities on half train set (probability training part)...
# Computing features and targets for our model training on fold 5/5 on the other half of the training set...
# Training category probabilities on half train set (probability training part)...
# Computing features and targets for our model training on fold 5/5 on the other half of the training set...
# Defining and training our model on fold 5/5...
# Training category probabilities on full train set for fold 5/5...
# Computing model predictions on test for fold 5/5 and computing metrics...
# Computing metrics on test for fold 5/5...
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ### Results for both "unbalanced" and "balanced" modes

# %%
# Unbalanced mode

print(f"Overall accuracy: {np.mean(fold_accuracy_scores)}")
print("Accuracy by category:")
category_to_accuracy_score = {
    category: np.mean(
        [
            category_to_accuracy_score[category]
            for category_to_accuracy_score in fold_accuracy_scores_categorywise
        ]
    )
    for category in ALL_CATEGORIES
}
pprint(category_to_accuracy_score)
# Out:
# Overall accuracy: 0.5164668989402215
# Accuracy by category:
# {'Appointments / booking': 0.45,
#  'Brand image': 0.7473601718282877,
#  'Careers & applications': 1.0,
#  'Cart': 0.7816389698458119,
#  'Category': 0.6553837342497136,
#  'Checkout': 0.5120805762944707,
#  'Confirmation': 0.971321501265004,
#  'Favorites / wishlist': 0.8551282051282051,
#  'Form': 0.6499999999999999,
#  'Formations / services': 0.9704724409448818,
#  'Help / support': 0.8502615694164989,
#  'Home': 0.6244410190674144,
#  'Information / legals': 0.5911504424778762,
#  'My account': 0.6454901960784314,
#  'Offers & services': 0.9195402298850575,
#  'Other': 0.46674467708885914,
#  'Press / news': 0.8248022598870056,
#  'Product': 0.18902031135594446,
#  'Search': 0.8308021448508278,
#  'Store locator': 0.7675956542276807}

# %%
# Balanced mode

print(f"Overall accuracy: {np.mean(fold_accuracy_scores)}")
print("Accuracy by category:")
category_to_accuracy_score = {
    category: np.mean(
        [
            category_to_accuracy_score[category]
            for category_to_accuracy_score in fold_accuracy_scores_categorywise
        ]
    )
    for category in ALL_CATEGORIES
}
pprint(category_to_accuracy_score)
# Out:
# Overall accuracy: 0.5901507120350076
# Accuracy by category:
# {'Appointments / booking': 0.05,
#  'Brand image': 0.7321104112849389,
#  'Careers & applications': 1.0,
#  'Cart': 0.5852513877804771,
#  'Category': 0.4670103092783505,
#  'Checkout': 0.5226667426038872,
#  'Confirmation': 0.9546714793889934,
#  'Favorites / wishlist': 0.8705128205128206,
#  'Form': 0.5166666666666666,
#  'Formations / services': 0.9527559055118109,
#  'Help / support': 0.9180684104627768,
#  'Home': 0.6619413768019002,
#  'Information / legals': 0.7531904983698183,
#  'My account': 0.5980392156862745,
#  'Offers & services': 0.9933333333333334,
#  'Other': 0.5893520974402181,
#  'Press / news': 0.9157627118644067,
#  'Product': 0.4447710592638449,
#  'Search': 0.9408345987371582,
#  'Store locator': 0.8554558337269722}

# %% [markdown]
# Results show a clear signal in our algorithm, with more than 50% accuracy over 20 categories (random model would perform around 0.05 accuracy score). Our algorithm nevertheless sometimes performs poorly on specific categories, like "Product" for the unbalanced mode or "Appointments / booking" for the balanced mode. This has to raise our attention and could be a focus for error analysis and a reason for carrying a mixture of experts on both models.
# While averaging our accuracy score on all the categories (with same weight on every category) we find that both methods score an approximate 71.5% accuracy across categories.

# %% [markdown]
# ## Ideas of improvement

# %% [markdown]
# This algorithm could be improved in several ways:
# - Perform error analysis to improve features and focus on errors and categories with a weak accuracy score
# - Clean maps from chunks to category scores: remove figures, explicit categories of words, stop words etc
# - Create a system for merging similar words or words with the same grammatical root/meaning/translation Ex: search <-> searches, search <-> recherche, knitwear <-> sportswear etc. Is useful to handle new expressions in the url, namely actions. Use stemming or pre-trained embedding models like Word2Vec.
# - Improve the path chunk probability computations by taking into account the prior/bias on the category
# - Grid-search hyperparameters (Logistic l2 penalization, threshold on minimal occurrence for chunk relevance) etc
# - Try scaling inputs before feeding to the penalized Logistic Regression
# - Try other models: MLPClassifier, non-linear classifiers (Random Forest/Gradient Boosting etc) ...
# - Dig in the specificity of a given url chunk for a given category -> use TF-IDF-like features. For instance, chunks like ".fr" or "us" are frequent in all the different categories, there are not discriminant. Find a way of implementing this in the vecto
# - Combine our "balanced" and "unbalanced" modes to leverage the strengths of both of them. Merge them, or simply average the predict_proba of the two models
# - Correct the randomness of fold splits to be able to get perfectly comparable results (the models can still remain random during training though)
